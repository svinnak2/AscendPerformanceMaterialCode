# %%
""" This file search the google web based on search term provided and scraps 99 websites from the web.

Very Important:
    1) Make sure to execute the required libraries by either commenting/uncommenting pip
    2) Make sure to use the right API Key for the GOOGLE_CS_API_KEY variable.

"""
# Out:
# ' This file search the google web based on search term provided and scraps 99 websites from the web.\n\nVery Important:\n    1) Make sure to execute the required libraries by either commenting/uncommenting pip\n    2) Make sure to use the right API Key for the GOOGLE_CS_API_KEY variable.\n\n'

# %%
# pip install -r "/home/ec2-user/SageMaker/AscendNotebook/ascendrequirements.txt"

# %%
# Import os module for interacting with the operating system
import os

# Import pandas as pd for data manipulation and analysis
import pandas as pd

from TimeMethods import get_Date, get_DateTime, Time

from WebScraping import (search_term_directory, crawl_search_term, scrap_websites)

# %%
# Define the following NUM_RESULTS variable to determine the number of web search results to crawl for scrapping
NUM_RESULTS = 50

# Exclude Wikipedia, Reddit, and LinkedIn from search results
# exclude_sites = 'site:en.wikipedia.org OR site:reddit.com OR site:linkedin.com'

MY_API_KEY = 'XXXXXXXX' # This Sai Vinnakota personal Google API keys
# TIOT_API_KEY = 'XXXXXXXX' #'XXXXXXXX' # This is TensorIOT Google API Keys
MY_CSE_ID = 'XXXXXXXX' #'XXXXXXXX' # Replace this with the client Search Engine ID
GOOGLE_CS_API_KEY = MY_API_KEY

# Get the working directory
wrk_dir = os.getcwd()
print(f"Current working directory \"{wrk_dir}\".")

# Initialize Root Directory
ROOT_DIR = "/home/ec2-user/SageMaker/AscendNB/"
print(f"Root directory \"{ROOT_DIR}\".")

# Initialize directory to save operation execution results
Rslts_Save_Dir = "/home/ec2-user/SageMaker/AscendNB/CodeExecutionMetrics/"
print(f"Directory to save scraping execution results \"{Rslts_Save_Dir}\".")

# Initialize directory to save web scraped data
WebSC_DIR = "/home/ec2-user/SageMaker/AscendNB/WebScrapedUpdatedApproach/"
print(f"Directory to save scraped data files \"{WebSC_DIR}\".")
# Out:
# Current working directory "/home/ec2-user/SageMaker/AscendNB/WebScrapingCode".
# Root directory "/home/ec2-user/SageMaker/AscendNB/".
# Directory to save scraping execution results "/home/ec2-user/SageMaker/AscendNB/CodeExecutionMetrics/".
# Directory to save scraped data files "/home/ec2-user/SageMaker/AscendNB/WebScrapedUpdatedApproach/".

# %% [markdown]
# # Use the right Google Custom Search API Key

# %%
GOOGLE_CS_API_KEY = MY_API_KEY

# %% [markdown]
# # Chose the appropriate search term

# %%
# MY_SEARCH = "Nylon & Polyamide injection molders"
# MY_SEARCH = "Plastic Profile Extruders"
# MY_SEARCH = "Plastic Sheet extruders"
# MY_SEARCH = "Recycled carpet fibers applications"
# MY_SEARCH = "Nylon Compounders & Polyamide Compounders"
MY_SEARCH = "Revised Search Terms"

# MY_SEARCHES = ["Nylon & Polyamide injection molders", "Plastic Profile Extruders", "Plastic Sheet extruders", "Recycled carpet fibers applications", "Nylon Compounders & Polyamide Compounders"]

# %%
# Crawl_scrap_processing_status = pd.DataFrame(columns = ['Search Term','Number of Results Crawled', 'Crawl Start Time', 
#                                            'Crawl End Time', 'Crawl Exec Time in Minutes'])

# print(f"Performing Google search for \"{MY_SEARCH}\".")
# print("================================================================")
# print(" ")

# # Define search term directory to save web scrapping results
# SEARCH_TERM_DIR = search_term_directory(MY_SEARCH)

# print(f"--> Search Term directory that will be used to save results is: \"{SEARCH_TERM_DIR}\".")

# # Crawl the web to get results
# Crawl_process_stats, results = crawl_search_term(MY_SEARCH, GOOGLE_CS_API_KEY, MY_CSE_ID, NUM_RESULTS)

# print("Completed web crawling and started web scrapping.")
# print(" ")

# Metadata_DF_Final = scrap_websites(results, MY_SEARCH, WebSC_DIR, SEARCH_TERM_DIR, wrk_dir, get_Date())

# print("Completed web scrapping.")
# print(" ")

# # Saving search results summary to a csv file
# print("--> Current Working Directory:", os.getcwd())
# Metadata_DF_Final.to_csv(Rslts_Save_Dir + "/" + SEARCH_TERM_DIR +"_"+ get_DateTime() + '.csv', index=False)

# print("================================================================")
# print(" ")

# # Append the row
# Crawl_scrap_processing_status.loc[len(Crawl_scrap_processing_status)] = Crawl_process_stats

# Crawl_scrap_processing_status.to_csv(Rslts_Save_Dir + "/" + MY_SEARCH +"WebScrap_ProcessTime_"+ get_DateTime() + '.csv', index=False)

# %%
SRCH_TERMS = ["\"Medical\" products manufactured from nylon 6,6", 
"\"Medical devices\" manufactured from nylon 6,6", 
"\"Medical equipment\" manufactured from nylon 6,6", 
"\"Medical devices\" companies that use \"Nylon\" in their products", 
"\"Medical devices\" Nylon injection molders", 
"\"Medical devices\" innovations using Nylon injection molders"]

# %%
Crawl_scrap_processing_status = pd.DataFrame(columns = ['Search Term','Number of Results Crawled', 'Crawl Start Time', 
                                           'Crawl End Time', 'Crawl Exec Time in Minutes'])
SRCH_TERM_COUNT = 1
for SEARCHTERM in SRCH_TERMS:
    
    SRCH_GRP = "GRP2"
    SRCH_GRP_TERM = SRCH_GRP + "_" + str(SRCH_TERM_COUNT)
    print(f"Search Group and Term Type: {SRCH_GRP_TERM}")
    
    print(f"Performing Google search for \"{SEARCHTERM}\".")
    print("================================================================")
    print(" ")
    
    # Define search term directory to save web scrapping results
    SEARCH_TERM_DIR = search_term_directory(MY_SEARCH)
    
    print(f"--> Search Term directory that will be used to save results is: \"{SEARCH_TERM_DIR}\".")
    # Crawl the web to get results
    Crawl_process_stats, results = crawl_search_term(SEARCHTERM, GOOGLE_CS_API_KEY, MY_CSE_ID, NUM_RESULTS)
    
    print("Completed web crawling and started web scrapping.")
    print(" ")

    Metadata_DF_Final = scrap_websites(results, MY_SEARCH, WebSC_DIR, SEARCH_TERM_DIR, wrk_dir, get_Date(), SRCH_GRP_TERM)

    print("Completed web scrapping.")
    print(" ")

    # Saving search results summary to a csv file
    print("--> Current Working Directory:", os.getcwd())
    Metadata_DF_Final.to_csv(Rslts_Save_Dir + "/" + SRCH_GRP + SEARCH_TERM_DIR +"_"+ get_DateTime() + '.csv', index=False)

    print("================================================================")
    print(" ")

    # Append the row
    Crawl_scrap_processing_status.loc[len(Crawl_scrap_processing_status)] = Crawl_process_stats
    
    SRCH_TERM_COUNT+=1

Crawl_scrap_processing_status.to_csv(Rslts_Save_Dir + "/" + SRCH_GRP + MY_SEARCH +"WebScrap_ProcessTime_"+ get_DateTime() + '.csv', index=False)
# Out:
# Search Group and Term Type: GRP2_1
# Performing Google search for ""Medical" products manufactured from nylon 6,6".
# ================================================================
#
# --> Search Term directory that will be used to save results is: "Revised_Search_Terms".
# --> Starting Crawling for "Medical" products manufactured from nylon 6,6 term at: 2024-06-22 23:41:22
# Perform Custom Google Search for "Medical" products manufactured from nylon 6,6
# Perform Custom Google Search for "Medical" products manufactured from nylon 6,6
# Perform Custom Google Search for "Medical" products manufactured from nylon 6,6
# Perform Custom Google Search for "Medical" products manufactured from nylon 6,6
# Perform Custom Google Search for "Medical" products manufactured from nylon 6,6
# --> Finished Crawling for "Medical" products manufactured from nylon 6,6 term at: 2024-06-22 23:41:23
#
# Completed web crawling and started web scrapping.
#
# --> Current Working Directory: /home/ec2-user/SageMaker/AscendNB/WebScrapingCode
# Directory 'Revised_Search_Terms' already exists.
# URL counter to scrap data:  1
# Title: Companies announce medical grade nylon based products ...
# Snippet: Dec 12, 2022 ... ... products,” said Larry Johnson, president of Foster Distribution. “Nylon 6,6 has been an underused material resource in the medical device ...
# Company URL: https://www.medicalplasticsnews.com
# Company Name: Medicalplasticsnews
# Original URL: https://www.medicalplasticsnews.com/news/latest-medical-plastics-news/companies-announce-hi-dura-med-nylon-based-products/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  2
# Title: INVISTA: Home
# Snippet: That's because – from air bags to automotive parts, medical equipment to ... nylon 6,6 production facility. The highly anticipated 90,000-square-foot ...
# Company URL: https://www.invista.com
# Company Name: Invista
# Original URL: https://www.invista.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# --> Failed to fetch full content.
#
# URL counter to scrap data:  3
# Title: Nylon 66: What is it? Properties, benefits and applications
# Snippet: Medical Field: Nylon 6-6 is employed in medical devices and equipment due to its biocompatibility and resistance to sterilization processes. It is used in ...
# Company URL: https://europlas.com.vn
# Company Name: Europlas
# Original URL: https://europlas.com.vn/en-US/blog-1/nylon-66-what-is-it-properties-benefits-and-applications
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  4
# Title: Puritan 6" Sterile Thin Foam Swab w/Nylon Handle & Transport ...
# Snippet: ... products that set us apart from the rest. purtian footer logo Copyright © 2024 Puritan Medical Products. All rights reserved.Proudly Made in the USA. Privacy ...
# Company URL: https://www.puritanmedproducts.com
# Company Name: Puritanmedproducts
# Original URL: https://www.puritanmedproducts.com/25-1406-1pf-bt.html
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  5
# Title: Medical-Grade Nylon 6, Nylon 6/66, and PET | Plastics Technology
# Snippet: Apr 8, 2022 ... DSM Engineering has expanded its Medical Care portfolio of engineering materials for medical devices.
# Company URL: https://www.ptonline.com
# Company Name: Ptonline
# Original URL: https://www.ptonline.com/products/medical-grade-nylon-6-nylon-666-and-pet-
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.ptonline.com/products/medical-grade-nylon-6-nylon-666-and-pet-
# --> Failed to fetch full content.
#
# URL counter to scrap data:  6
# Title: Nylon 6 vs. nylon 6/6 | Essentra Components US
# Snippet: Oct 23, 2023 ... Medical Equipment · Renewable Energy · Telecoms & Data. Manufacturing ... Here are some examples of products made from nylon plastic. View our ...
# Company URL: https://www.essentracomponents.com
# Company Name: Essentracomponents
# Original URL: https://www.essentracomponents.com/en-us/news/solutions/fastening-components/the-differences-between-nylon-6-and-nylon-6-6
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:

# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.fosterscs.com/polymers/nylon/nylon-66/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  15
# Title: Nylon 6/6 - New Process Fibre Company, Inc.
# Snippet: With uses in markets ranging from automotive, aerospace, and medical ... NPF nylons are made with virgin materials to ensure we produce the best quality products.
# Company URL: https://www.newprocess.com
# Company Name: Newprocess
# Original URL: https://www.newprocess.com/nylon-washers/nylon-6-6/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.newprocess.com/nylon-washers/nylon-6-6/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  16
# Title: Nylon 6 - an overview | ScienceDirect Topics
# Snippet: Sastri, in Plastics in Medical Devices, 2010. 7.8.1.2 Polyamide 6 (Nylon 6). Nylon 6 is produced by the hydrolytic or catalytic ring opening polymerization of ...
# Company URL: https://www.sciencedirect.com
# Company Name: Sciencedirect
# Original URL: https://www.sciencedirect.com/topics/chemistry/nylon-6
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.sciencedirect.com/topics/chemistry/nylon-6
# --> Failed to fetch full content.
#
# URL counter to scrap data:  17
# Title: Ascend Performance Materials LLC
# Snippet: ... medical devices, smarter appliances and longer-lasting apparel and consumer goods. ... Cerene is available as polyamide 6 and 66, PET, polypropylene and calcium ...
# Company URL: https://www.ascendmaterials.com
# Company Name: Ascendmaterials
# Original URL: https://www.ascendmaterials.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  18
# Title: Force Fiber Suture (Ultra-high Molecular Weight Polyethylene ...
# Snippet: White/Black: UHMWPE and black nylon 6,6 ... As a trusted co-development partner, Teleflex Medical OEM supports industry leaders in the design and development of ...
# Company URL: https://www.teleflexmedicaloem.com
# Company Name: Teleflexmedicaloem
# Original URL: https://www.teleflexmedicaloem.com/suture-and-fiber-technologies-2/force-fiber/
# The text does not contain '.pdf'. Therefore extracting data from URL
# An error occurred: HTTPSConnectionPool(host='www.teleflexmedicaloem.com', port=443): Max retries exceeded with url: /suture-and-fiber-technologies-2/force-fiber/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fbcc98e6f50>, 'Connection to www.teleflexmedicaloem.com timed out. (connect timeout=30)'))
# --> Failed to fetch full content.
#
# URL counter to scrap data:  19
# Title: Monofilament Polyamide Suture (Nylon) - Universal Sutures
# Snippet: UNILON is composed of long chain aliphatic polymers made from 100% homo polymer of Nylon 6 and 6.6. ... Unisur lifecare an ISO & CE certified medical devices ...
# Company URL: https://www.universalsutures.com
# Company Name: Universalsutures
# Original URL: https://www.universalsutures.com/products/polyamide-suture/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  20
# Title: Nylon 3D Printing Pellet Review - JuggerBot 3D
# Snippet: ... Manufacturing market: Nylon Callouts_Nylon 66. Nylon 66 (PA66). Nylon 66 is known ... Healthcare & Medical Devices. Nylon is used to 3D print custom prosthetic ...
# Company URL: https://juggerbot3d.com
# Company Name: Juggerbot3d
# Original URL: https://juggerbot3d.com/nylon-3d-printing-pellet-review-copy/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 406 Client Error: Not Acceptable for url: https://juggerbot3d.com/nylon-3d-printing-pellet-review-copy/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  21
# Title: Summary of Color Additives for Use in the United States in Foods ...
# Snippet: Mar 4, 2022 ... Summary of Color Additives for Use in the United States in Foods, Drugs, Cosmetics, and Medical Devices. ... For coloring nylon 66, nylon 6, or ...
# Company URL: https://www.fda.gov
# Company Name: Fda
# Original URL: https://www.fda.gov/industry/color-additive-inventories/summary-color-additives-use-united-states-foods-drugs-cosmetics-and-medical-devices
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  45
# Title: 3M™ Standard Nylon Cable Ties | 3M United States
# Snippet: Medical · Office Supplies · Personal Protective Equipment · Signage & Marking ... 3M™ Standard Nylon Cable Ties are made with high-quality nylon 6/6 and designed ...
# Company URL: https://www.3m.com
# Company Name: 3m
# Original URL: https://www.3m.com/3M/en_US/p/d/b5005119001/
# The text does not contain '.pdf'. Therefore extracting data from URL
# An error occurred: HTTPSConnectionPool(host='www.3m.com', port=443): Read timed out. (read timeout=30)
# --> Failed to fetch full content.
#
# URL counter to scrap data:  46
# Title: The Dynisco Extrusion Processors Handbook
# Snippet: legend shows that the product is made from a nylon 66 material that contains ... may be used in gamma radiation sterilized medical devices. Antioxidants, and ...
# Company URL: https://www.dynisco.com
# Company Name: Dynisco
# Original URL: https://www.dynisco.com/userfiles/files/27429_Legacy_Txt.pdf
# The text contains '.pdf'.
# The pdf file name is 27429_Legacy_Txt.pdf
# URL counter to scrap data:  47
# Title: An Introduction to Polymeric Materials for Medical Devices
# Snippet: Jan 11, 2021 ... ... medical device manufacturing starting at the customer (per Six Sigma methodology) include: Final, functioning medical device; Sterilization ...
# Company URL: https://www.meddeviceonline.com
# Company Name: Meddeviceonline
# Original URL: https://www.meddeviceonline.com/doc/an-introduction-to-polymeric-materials-for-medical-devices-0001
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  48
# Title: 14 Nylon Manufacturers in 2024 | Metoree
# Snippet: Nylon 6 is made through a ring-opening reaction of ε-caprolactam, while nylon 6 ... production, construction materials, medical devices, and electronics. The ...
# Company URL: https://us.metoree.com
# Company Name: Us
# Original URL: https://us.metoree.com/categories/5366/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  49
# Title: Medical Applications for 3D Printing: Current and Projected Uses ...
# Snippet: Oct 8, 2014 ... By doing so, they can use a 3D printer to create an exact replica of a medical model or device, allowing the precise sharing of designs. Toward ...
# Company URL: https://www.ncbi.nlm.nih.gov
# Company Name: Ncbi
# Original URL: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4189697/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4189697/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  50
# Title: A Guide to the Properties and Applications of Nylon Resin | Thogus ...
# Snippet: ... goods and electronics to medical devices and aerospace applications. To find ... Nylon Copolymers — Examples include Nylon/66 and Nylon 6/12. They are blends ...
# Company URL: https://www.thogus.com
# Company Name: Thogus
# Original URL: https://www.thogus.com/blog/post/a-guide-to-the-properties-and-applications-of-nylon-resin/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# --> Current Working Directory: /home/ec2-user/SageMaker/AscendNB/WebScrapingCode
# Completed web scrapping.
#
# --> Current Working Directory: /home/ec2-user/SageMaker/AscendNB/WebScrapingCode
# ================================================================
#
# Search Group and Term Type: GRP2_2
# Performing Google search for ""Medical devices" manufactured from nylon 6,6".
# ================================================================
#
# --> Search Term directory that will be used to save results is: "Revised_Search_Terms".
# --> Starting Crawling for "Medical devices" manufactured from nylon 6,6 term at: 2024-06-22 23:42:49
# Perform Custom Google Search for "Medical devices" manufactured from nylon 6,6
# Perform Custom Google Search for "Medical devices" manufactured from nylon 6,6
# Perform Custom Google Search for "Medical devices" manufactured from nylon 6,6
# Perform Custom Google Search for "Medical devices" manufactured from nylon 6,6
# Perform Custom Google Search for "Medical devices" manufactured from nylon 6,6
# --> Finished Crawling for "Medical devices" manufactured from nylon 6,6 term at: 2024-06-22 23:42:51
#
# Completed web crawling and started web scrapping.
#
# --> Current Working Directory: /home/ec2-user/SageMaker/AscendNB/WebScrapingCode
# Directory 'Revised_Search_Terms' already exists.
# URL counter to scrap data:  1
# Title: Medical-Grade Nylon 6, Nylon 6/66, and PET | Plastics Technology
# Snippet: Apr 8, 2022 ... DSM Engineering has expanded its Medical Care portfolio of engineering materials for medical devices ... Additive Manufacturing 18 Jun 2024. A3D ...
# Company URL: https://www.ptonline.com
# Company Name: Ptonline
# Original URL: https://www.ptonline.com/products/medical-grade-nylon-6-nylon-666-and-pet-
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.sciencedirect.com/topics/chemistry/nylon-6
# --> Failed to fetch full content.
#
# URL counter to scrap data:  9
# Title: Polypropylene vs. Nylon: Material Differences and Comparisons ...
# Snippet: Jan 6, 2023 ... The chemical formula for Nylon 66 is (C12H22N2O2)n. Toothbrushes, gloves, wheels, guitar strings, strings for tennis rackets, medical devices ...
# Company URL: https://www.xometry.com
# Company Name: Xometry
# Original URL: https://www.xometry.com/resources/materials/polypropylene-vs-nylon/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  10
# Title: Summary of Color Additives for Use in the United States in Foods ...
# Snippet: Mar 4, 2022 ... Summary of Color Additives for Use in the United States in Foods, Drugs, Cosmetics, and Medical Devices. ... For coloring nylon 66, nylon 6, or ...
# Company URL: https://www.fda.gov
# Company Name: Fda
# Original URL: https://www.fda.gov/industry/color-additive-inventories/summary-color-additives-use-united-states-foods-drugs-cosmetics-and-medical-devices
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  11
# Title: Chemical Characterization of Leachables in Catheter Device - PMC
# Snippet: Dec 15, 2022 ... The main body of the investigated steerable guide catheter is made of Pebax and nylon ... medical devices manufactured with different polymer ...
# Company URL: https://www.ncbi.nlm.nih.gov
# Company Name: Ncbi
# Original URL: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9798755/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9798755/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  12
# Title: Nylon 3D Printing Pellet Review - JuggerBot 3D
# Snippet: ... Manufacturing market: Nylon Callouts_Nylon 66. Nylon 66 (PA66). Nylon 66 is known ... Healthcare & Medical Devices. Nylon is used to 3D print custom prosthetic ...
# Company URL: https://juggerbot3d.com
# Company Name: Juggerbot3d
# Original URL: https://juggerbot3d.com/nylon-3d-printing-pellet-review-copy/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 406 Client Error: Not Acceptable for url: https://juggerbot3d.com/nylon-3d-printing-pellet-review-copy/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  13
# Title: Force Fiber Suture (Ultra-high Molecular Weight Polyethylene ...
# Snippet: As a trusted co-development partner, Teleflex Medical OEM supports industry leaders in the design and development of medical devices with the unparalleled ...
# Company URL: https://www.teleflexmedicaloem.com
# Company Name: Teleflexmedicaloem
# Original URL: https://www.teleflexmedicaloem.com/suture-and-fiber-technologies-2/force-fiber/
# The text does not contain '.pdf'. Therefore extracting data from URL
# An error occurred: HTTPSConnectionPool(host='www.teleflexmedicaloem.com', port=443): Max retries exceeded with url: /suture-and-fiber-technologies-2/force-fiber/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fbcc9e36fe0>, 'Connection to www.teleflexmedicaloem.com timed out. (connect timeout=30)'))
# --> Failed to fetch full content.
#
# URL counter to scrap data:  14
# Title: An Introduction to Polymeric Materials for Medical Devices
# Snippet: Jan 11, 2021 ... ... medical devices in addition to household goods, automotive, and ... With the polyamides, most notably nylon 6 and nylon 66, amide groups lead ...
# Company URL: https://www.meddeviceonline.com
# Company Name: Meddeviceonline
# Original URL: https://www.meddeviceonline.com/doc/an-introduction-to-polymeric-materials-for-medical-devices-0001
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  15
# Title: Bushings: Nylon 6, Nylon 66, and Self-lubricating Nylon - Advanced ...
# Snippet: Feb 12, 2016 ... It has a higher melting point than nylon 6, making its continuous operating temperature somewhat higher. ... Medical Devices Medical Industry ...
# Company URL: https://advanced-emc.com
# Company Name: Advanced
# Original URL: https://advanced-emc.com/bushings-nylon-6-nylon-66-and-self-lubricating-nylon/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https

# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.medicaldesignandoutsourcing.com/make-kink-resistant-tubing-work-smaller-medical-devices/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  25
# Title: New Developments in Medical Plastics - Prospector Knowledge ...
# Snippet: Nov 30, 2022 ... ... medical devices. How to select optimal plastics for medical devices ... Medical grade nylon 6/6. Ascend Performance Materials has announced a ...
# Company URL: https://www.ulprospector.com
# Company Name: Ulprospector
# Original URL: https://www.ulprospector.com/knowledge/13886/new-developments-in-medical-plastics/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.ulprospector.com/knowledge/13886/new-developments-in-medical-plastics/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  26
# Title: Plastic Stock Shapes | High Performance Injection Molding & Plastic ...
# Snippet: ... manufacturing equipment to medical devices. We are happy to discuss your ... Nylon® 6/6 (Polyamide). Nylon 6/6 30% Glass Filled is well known for excellent ...
# Company URL: https://www.ensinger-pc.com
# Company Name: Ensinger
# Original URL: https://www.ensinger-pc.com/injection-molding-materials/our-plastic-stock-shapes/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  27
# Title: Nylon 3D Printing Guide: Compare Processes, Materials, and ...
# Snippet: ... medical devices, consumer goods, and more. Additive manufacturing processes ... Nylon 6, nylon 66, nylon 12, carbon and glass-filled nylon. Cost, Benchtop ...
# Company URL: https://formlabs.com
# Company Name: Formlabs
# Original URL: https://formlabs.com/blog/nylon-3d-printing/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  28
# Title: An Overview of the Plastic Material Selection Process for Medical ...
# Snippet: Nylon (6/6 extruded). 12,400 ... So, to summarize the table below provides basic information to initiate the selection of plastic materials for medical devices.
# Company URL: https://www.hcltech.com
# Company Name: Hcltech
# Original URL: https://www.hcltech.com/sites/default/files/documents/resources/whitepaper/files/an_overview_of_the_plastic_material_selection_process_for_medical_devices.pdf
# The text contains '.pdf'.
# The pdf file name is an_overview_of_the_plastic_material_selection_process_for_medical_devices.pdf
# URL counter to scrap data:  29
# Title: Sumen Technology Group Co., Ltd.: China PA66; Nylon 6; Polymide ...
# Snippet: ... Medical Grade Polycarbonate; PC; Gamma-Ray Grade PC; PC for ... video icon Chinese Nylon; Nylon Raw Material; Nylon 6 Made in China; Raw ...
# Company URL: https://1a71929c1db0061e.en.made-in-china.com
# Company Name: 1a71929c1db0061e
# Original URL: https://1a71929c1db0061e.en.made-in-china.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 493 Client Error:  for url: https://1a71929c1db0061e.en.made-in-china.com/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  30
# Title: 3D Printing Medical Devices Market [121+ Pages] Worth ~ US ...
# ...
#
#
# URL counter to scrap data:  23
# Title: Ascend Performance Materials LLC
# Snippet: Our customers use Ascend products to make safer vehicles, cleaner energy, better medical devices, smarter appliances and longer-lasting apparel and consumer ...
# Company URL: https://www.ascendmaterials.com
# Company Name: Ascendmaterials
# Original URL: https://www.ascendmaterials.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  24
# Title: Injection Molding LSR: Three 'M's of Innovation: Mega, Micro, and ...
# Snippet: Nov 1, 2007 ... ... medical devices, medical implants, medical gloves, and automotive seals. LSR is gaining a bigger share in electronic connectors, o-rings ...
# Company URL: https://www.ptonline.com
# Company Name: Ptonline
# Original URL: https://www.ptonline.com/articles/injection-molding-lsr-three-ms-of-innovation-mega-micro-and-multi
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.ptonline.com/articles/injection-molding-lsr-three-ms-of-innovation-mega-micro-and-multi
# --> Failed to fetch full content.
#
# URL counter to scrap data:  25
# Title: Design High Performing Medical Devices using Arkema's High ...
# Snippet: This material is well suited for demanding medical gowns, innovative medical devices and pharmaceutical packaging, among other applications. List of Pebax ...
# Company URL: https://hpp.arkema.com
# Company Name: Hpp
# Original URL: https://hpp.arkema.com/en/markets-and-applications/healthcare/healthcare-material-solutions/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  26
# Title: Medical-Grade Nylon 6, Nylon 6/66, and PET | Plastics Technology
# Snippet: Apr 8, 2022 ... DSM Engineering has expanded its Medical Care portfolio of engineering materials for medical devices.
# Company URL: https://www.ptonline.com
# Company Name: Ptonline
# Original URL: https://www.ptonline.com/products/medical-grade-nylon-6-nylon-666-and-pet-
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.ptonline.com/products/medical-grade-nylon-6-nylon-666-and-pet-
# --> Failed to fetch full content.
#
# URL counter to scrap data:  27
# Title: Application of Plastics in Medical Devices and Equipment - PMC
# Snippet: Micro-molding, two shot molding, and metal injection molding are all new ... medical devices which use PC in their construction. The level of BPA found ...
# Company URL: https://www.ncbi.nlm.nih.gov
# Company Name: Ncbi
# Original URL: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7151894/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7151894/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  28
# Title: Medical Grade Plastics: Types of Plastics Used in Medical Devices
# Snippet: May 13, 2022 ... We offer plastic injection molding services for non-medical and ... Do you have a question about the types of plastic used in medical devices?
# Company URL: https://www.rapiddirect.com
# Company Name: Rapiddirect
# Original URL: https://www.rapiddirect.com/blog/medical-grade-plastics/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  29
# Title: Micro Molding
# Snippet: Our specialized processes enable the creation of small-scale medical devices and components, empowering innovations in patient care, diagnostics, and treatment.
# Company URL: https://www.knowles.com
# Company Name: Knowles
# Original URL: https://www.knowles.com/products/miniaturization-capabilities/micro-molding
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  30
# Title: Injection Molding for Medical Devices in a Nutshell - Jaycon
# Snippet: Feb 16, 2024 ... Uncover the transformative impact of injection molding for medical devices with companies like Jaycon leading the charge.
# Company URL: https://www.jaycon.com
# Company Name: Jaycon
# Original URL: https://www.jaycon.com/injection-molding-for-medical-devices/
# The text does not contain '.pdf'. Therefore extracting data from URL
# An error occurred: HTTPSConnectionPool(host='www.jaycon.com', port=443): Max retries exceeded with url: /injection-molding-for-medical-devices/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fbcc9f5d030>, 'Connection to www.jaycon.com timed out. (connect timeout=30)'))
# --> Failed to fetch full content.
#
# URL counter to scrap data:  31
# Title: Precision Injection Molding Capabilities Blogs | Performance Plastics
# Snippet: Jan 25, 2024 ... Applications of biocompatible fluoropolymers in injection molding include the manufacturing of components for medical devices such as catheters, ...
# Company URL: https://performanceplastics.com
# Company Name: Performanceplastics
# Original URL: https://performanceplastics.com/blog/category/capabilities/precision-injection-molding/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://performanceplastics.com/blog/category/capabilities/precision-injection-molding/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  32
# Title: Injection Molding: Davies Unleashes Unmatched Expertise | Davies ...
# Snippet: We start with raw plastic material, usually in ... Medical devices such as casings and enclosures for equipment, surgical instruments, along with many other ...
# Company URL: https://daviesmolding.com
# Company Name: Daviesmolding
# Original URL: https://daviesmolding.com/resources/engineering-specifications/plastic-molding/injection-molding/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://daviesmolding.com/resources/engineering-specifications/plastic-molding/injection-molding/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  33
# Title: Med Device Online: Advancing human health by connecting people ...
# Snippet: Explore the pivotal role of micro molding in driving innovation in micro-optics applications like medical devices and AR glasses, and why expertise, precision, ...
# Company URL: https://www.meddeviceonline.com
# Company Name: Meddeviceonline
# Original URL: https://www.meddeviceonline.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  34
# Title: More Injection Molded Plastics Company Listings
# Snippet: The company specializes in providing custom plastic injection molding solutions for various industries, including automotive, consumer goods, medical devices, ...
# Company URL: https://www.injection-molded-plastics.net
# Company Name: Injection
# Original URL: https://www.injection-molded-plastics.net/more-injection-molded-plastics-company-listings/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  35
# Title: KLA Industries, Inc - Plastics Manufacturing Recruiters
# Snippet: Injection Molding · Medical Devices & Tubing · Information Technology · Nonwovens · Packaging Design & Innovation · Plastics Machinery & Equipment · Polymer ...
# Company URL: https://klaindustries.com
# Company Name: Klaindustries
# Original URL: https://klaindustries.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  36
# Title: Manufacturing for Medical Devices | Medical Device Innovation
# Snippet: Balloon blowing and tipping capabilities - manufacturing for medical devices. Injection moulding and bonding.
# Company URL: https://arrotek.com
# Company Name: Arrotek
# Original URL: https://arrotek.com/en/manufacturing-capabilities/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  37
# Title: Plastic Stock Shapes | High Performance Injection Molding & Plastic ...
# Snippet: ... with specific applications from components for manufacturing equipment to medical devices. ... with innovative technical solutions that empower them with better ...
# Company URL: https://www.ensinger-pc.com
# Company Name: Ensinger
# Original URL: https://www.ensinger-pc.com/injection-molding-materials/our-plastic-stock-shapes/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  38
# Title: 3D Printing vs Injection Molding – Which is Better?
# Snippet: ... plastic parts are manufactured using plastic injection molding. ... The value of consistently producing large quantities of defect-free, complex medical devices ...
# Company URL: https://www.kaysun.com
# Company Name: Kaysun
# Original URL: https://www.kaysun.com/blog/plastic-injection-molding-vs-3d-printing
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.kaysun.com/blog/plastic-injection-molding-vs-3d-printing
# --> Failed to fetch full content.
#
# URL counter to scrap data:  39
# Title: Makrolon® | Polycarbonates | Covestro
# Snippet: A thermoplastic with truly diverse applications, Makrolon® is used in medical devices ... using polyurethane reaction injection molding (RIM) technology. Story ...
# Company URL: https://solutions.covestro.com
# Company Name: Solutions
# Original URL: https://solutions.covestro.com/en/brands/makrolon
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  40
# Title: MDG Engineering Leverages Xometry To Build Medical Devices ...
# Snippet: This is because the medtech startup, which specialises in medical devices ... Injection Molding · Die Casting · Vacuum Casting · Compression Molding. Follow us on ...
# Company URL: https://xometry.pro
# Company Name: Xometry
# Original URL: https://xometry.pro/en-eu/stories/mdg-engineering-medical-devices/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  41
# Title: 3D Systems & EMS-GRILTECH Enter Strategic Partnership to ...
# Snippet: Jun 28, 2022 ... ... in high-performance polymers for injection molding and powder-based applications. ... Medical Devices · Bioprinting · Resources · Webinars ...
# Company URL: https://www.3dsystems.com
# Company Name: 3dsystems
# Original URL: https://www.3dsystems.com/press-releases/3d-systems-ems-griltech-enter-strategic-partnership-advance-materials-innovation
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  42
# Title: TORAY PLASTICS | TORAY
# Snippet: Before injection-molding a nylon resin · Injection-molding apparatus · Mold · Gate design ... medical devices and household items. Here we will introduce these ...
# Company URL: https://www.plastics.toray
# Company Name: Plastics
# Original URL: https://www.plastics.toray/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  43
# Title: How plastics are transforming the implantable medical devices space
# Snippet: Aug 12, 2020 ... In recent years, this innovative drive has been increasingly apparent in the implantable medical devices industry. Implantable medical devices ...
# Company URL: https://www.medicalplasticsnews.com
# Company Name: Medicalplasticsnews
# Original URL: https://www.medicalplasticsnews.com/news/the-transformative-influence-of-plastics-on-implantable-medi/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  44
# Title: What Are The Different Injection Molding Types: 25 Injection Molding ...
# Snippet: Mar 19, 2024 ... Medical devices and components that are in direct contact with human skin. Automotive parts that must withstand extreme temperatures ...
# Company URL: https://www.3erp.com
# Company Name: 3erp
# Original URL: https://www.3erp.com/blog/injection-molding-types/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  45
# Title: High-Temperature Material, High-Temperature Nylon (PA10T ...
# Snippet: LCP allows for precise injection molding, enabling complex geometries and intricate structures. ... LCP finds applications in medical devices, including high- ...
# Company URL: https://nypla.com
# Company Name: Nypla
# Original URL: https://nypla.com/en/high-temperature.phtml
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  46
# Title: Medical Molding Modernized | Medical Product Outsourcing
# Snippet: Jun 6, 2023 ... As the world continues to rebound from COVID-19, demand for new medical devices is on the rise as more people are following through with ...
# Company URL: https://www.mpo-mag.com
# Company Name: Mpo
# Original URL: https://www.mpo-mag.com/issues/2023-06-01/view_features/medical-molding-modernized/
# The text does not contain '.pdf'. Therefore extracting data from URL
# An error occurred: HTTPSConnectionPool(host='www.mpo-mag.com', port=443): Max retries exceeded with url: /issues/2023-06-01/view_features/medical-molding-modernized/ (Caused by SSLError(SSLError(1, '[SSL: UNSAFE_LEGACY_RENEGOTIATION_DISABLED] unsafe legacy renegotiation disabled (_ssl.c:1007)')))
# --> Failed to fetch full content.
#
# URL counter to scrap data:  47
# Title: Upcycling Nylon for New Uses | DuPont
# Snippet: Medical Devices & Materials · View All Product Lines · Water Solutions · View All ... injection mold applications in a variety of markets. Our Enabling a Circular ...
# Company URL: https://www.dupont.com
# Company Name: Dupont
# Original URL: https://www.dupont.com/about/sustainability/enabling-a-circular-economy-2021/upcycling-nylon-for-new-uses.html
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  48
# Title: Healthcare Printers | Nota3D
# Snippet: The Vital Role of 3D Printing in Rapid Prototyping of Medical Devices In the ... Revolutionizing Medical Device Manufacturing With 3D Printed Injection Molds ...
# Company URL: https://www.nota3d.com
# Company Name: Nota3d
# Original URL: https://www.nota3d.com/healthcare-printers/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  49
# Title: Success Stories - NC State University Industry Expansion Solutions
# Snippet: ... in 2006 in Greensboro, North Carolina. CTM is a world class injection molding facility serving industries that include: aerospace, defense, medical devices ...
# Company URL: https://www.ies.ncsu.edu
# Company Name: Ies
# Original URL: https://www.ies.ncsu.edu/defense-industry-initiatives/success-stories/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.ies.ncsu.edu/defense-industry-initiatives/success-stories/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  50
# Title: Engineered Plastics for Medical Applications | Trelleborg
# Snippet: ... in that it is melt-processable using injection molding and screw extrusion techniques. ... Tubing material typically used in many disposable medical devices ...
# Company URL: https://www.trelleborg.com
# Company Name: Trelleborg
# Original URL: https://www.trelleborg.com/en/medical/products-capabilities/materials/plastics
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# --> Current Working Directory: /home/ec2-user/SageMaker/AscendNB/WebScrapingCode
# Completed web scrapping.
#
# --> Current Working Directory: /home/ec2-user/SageMaker/AscendNB/WebScrapingCode
# ================================================================
