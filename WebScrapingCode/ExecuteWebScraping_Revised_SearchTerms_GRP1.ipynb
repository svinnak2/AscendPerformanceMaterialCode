# %%
""" This file search the google web based on search term provided and scraps 99 websites from the web.

Very Important:
    1) Make sure to execute the required libraries by either commenting/uncommenting pip
    2) Make sure to use the right API Key for the GOOGLE_CS_API_KEY variable.

"""

# %%
# pip install -r "/home/ec2-user/SageMaker/AscendNotebook/ascendrequirements.txt"

# %%
# Import os module for interacting with the operating system
import os

# Import pandas as pd for data manipulation and analysis
import pandas as pd

from TimeMethods import get_Date, get_DateTime, Time

from WebScraping import (search_term_directory, crawl_search_term, scrap_websites)

# %%
# Define the following NUM_RESULTS variable to determine the number of web search results to crawl for scrapping
NUM_RESULTS = 50

# Exclude Wikipedia, Reddit, and LinkedIn from search results
# exclude_sites = 'site:en.wikipedia.org OR site:reddit.com OR site:linkedin.com'

MY_API_KEY = 'XXXXXXXX' # This Sai Vinnakota personal Google API keys
# TIOT_API_KEY = 'XXXXXXXX' #'XXXXXXXX' # This is TensorIOT Google API Keys
MY_CSE_ID = 'XXXXXXXX' #'XXXXXXXX' # Replace this with the client Search Engine ID
GOOGLE_CS_API_KEY = MY_API_KEY

# Get the working directory
wrk_dir = os.getcwd()
print(f"Current working directory \"{wrk_dir}\".")

# Initialize Root Directory
ROOT_DIR = "/home/ec2-user/SageMaker/AscendNB/"
print(f"Root directory \"{ROOT_DIR}\".")

# Initialize directory to save operation execution results
Rslts_Save_Dir = "/home/ec2-user/SageMaker/AscendNB/CodeExecutionMetrics/"
print(f"Directory to save scraping execution results \"{Rslts_Save_Dir}\".")

# Initialize directory to save web scraped data
WebSC_DIR = "/home/ec2-user/SageMaker/AscendNB/WebScrapedUpdatedApproach/"
print(f"Directory to save scraped data files \"{WebSC_DIR}\".")
# Out:
# Current working directory "/home/ec2-user/SageMaker/AscendNB/WebScrapingCode".
# Root directory "/home/ec2-user/SageMaker/AscendNB/".
# Directory to save scraping execution results "/home/ec2-user/SageMaker/AscendNB/CodeExecutionMetrics/".
# Directory to save scraped data files "/home/ec2-user/SageMaker/AscendNB/WebScrapedUpdatedApproach/".

# %% [markdown]
# # Use the right Google Custom Search API Key

# %%
GOOGLE_CS_API_KEY = MY_API_KEY

# %% [markdown]
# # Chose the appropriate search term

# %%
# MY_SEARCH = "Nylon & Polyamide injection molders"
# MY_SEARCH = "Plastic Profile Extruders"
# MY_SEARCH = "Plastic Sheet extruders"
# MY_SEARCH = "Recycled carpet fibers applications"
# MY_SEARCH = "Nylon Compounders & Polyamide Compounders"
MY_SEARCH = "Revised Search Terms"

# MY_SEARCHES = ["Nylon & Polyamide injection molders", "Plastic Profile Extruders", "Plastic Sheet extruders", "Recycled carpet fibers applications", "Nylon Compounders & Polyamide Compounders"]

# %%
# Crawl_scrap_processing_status = pd.DataFrame(columns = ['Search Term','Number of Results Crawled', 'Crawl Start Time', 
#                                            'Crawl End Time', 'Crawl Exec Time in Minutes'])

# print(f"Performing Google search for \"{MY_SEARCH}\".")
# print("================================================================")
# print(" ")

# # Define search term directory to save web scrapping results
# SEARCH_TERM_DIR = search_term_directory(MY_SEARCH)

# print(f"--> Search Term directory that will be used to save results is: \"{SEARCH_TERM_DIR}\".")

# # Crawl the web to get results
# Crawl_process_stats, results = crawl_search_term(MY_SEARCH, GOOGLE_CS_API_KEY, MY_CSE_ID, NUM_RESULTS)

# print("Completed web crawling and started web scrapping.")
# print(" ")

# Metadata_DF_Final = scrap_websites(results, MY_SEARCH, WebSC_DIR, SEARCH_TERM_DIR, wrk_dir, get_Date())

# print("Completed web scrapping.")
# print(" ")

# # Saving search results summary to a csv file
# print("--> Current Working Directory:", os.getcwd())
# Metadata_DF_Final.to_csv(Rslts_Save_Dir + "/" + SEARCH_TERM_DIR +"_"+ get_DateTime() + '.csv', index=False)

# print("================================================================")
# print(" ")

# # Append the row
# Crawl_scrap_processing_status.loc[len(Crawl_scrap_processing_status)] = Crawl_process_stats

# Crawl_scrap_processing_status.to_csv(Rslts_Save_Dir + "/" + MY_SEARCH +"WebScrap_ProcessTime_"+ get_DateTime() + '.csv', index=False)

# %%
SRCH_TERMS = ["\"consumer electronic parts\" manufactured from nylon 6,6",
"\"consumer electronic\" products manufactured from nylon 6,6",
"\"consumer electronic\" companies that use \"Nylon\" in their products",
"\"consumer electronic\" Nylon injection molders",
"\"consumer electronic\" innovations using Nylon injection molders"]

# %%
Crawl_scrap_processing_status = pd.DataFrame(columns = ['Search Term','Number of Results Crawled', 'Crawl Start Time', 
                                           'Crawl End Time', 'Crawl Exec Time in Minutes'])
SRCH_TERM_COUNT = 1
for SEARCHTERM in SRCH_TERMS:
    
    SRCH_GRP = "GRP1"
    SRCH_GRP_TERM = SRCH_GRP + "_" + str(SRCH_TERM_COUNT)
    print(f"Search Group and Term Type: {SRCH_GRP_TERM}")
    
    print(f"Performing Google search for \"{SEARCHTERM}\".")
    print("================================================================")
    print(" ")
    
    # Define search term directory to save web scrapping results
    SEARCH_TERM_DIR = search_term_directory(MY_SEARCH)
    
    print(f"--> Search Term directory that will be used to save results is: \"{SEARCH_TERM_DIR}\".")
    # Crawl the web to get results
    Crawl_process_stats, results = crawl_search_term(SEARCHTERM, GOOGLE_CS_API_KEY, MY_CSE_ID, NUM_RESULTS)
    
    print("Completed web crawling and started web scrapping.")
    print(" ")

    Metadata_DF_Final = scrap_websites(results, MY_SEARCH, WebSC_DIR, SEARCH_TERM_DIR, wrk_dir, get_Date(), SRCH_GRP_TERM)

    print("Completed web scrapping.")
    print(" ")

    # Saving search results summary to a csv file
    print("--> Current Working Directory:", os.getcwd())
    Metadata_DF_Final.to_csv(Rslts_Save_Dir + "/" + SRCH_GRP + SEARCH_TERM_DIR +"_"+ get_DateTime() + '.csv', index=False)

    print("================================================================")
    print(" ")

    # Append the row
    Crawl_scrap_processing_status.loc[len(Crawl_scrap_processing_status)] = Crawl_process_stats
    
    SRCH_TERM_COUNT+=1

Crawl_scrap_processing_status.to_csv(Rslts_Save_Dir + "/" + SRCH_GRP + MY_SEARCH +"WebScrap_ProcessTime_"+ get_DateTime() + '.csv', index=False)
# Out:
# Search Group and Term Type: GRP1_1
# Performing Google search for ""consumer electronic parts" manufactured from nylon 6,6".
# ================================================================
#
# --> Search Term directory that will be used to save results is: "Revised_Search_Terms".
# --> Starting Crawling for "consumer electronic parts" manufactured from nylon 6,6 term at: 2024-06-22 23:32:25
# Perform Custom Google Search for "consumer electronic parts" manufactured from nylon 6,6
# Perform Custom Google Search for "consumer electronic parts" manufactured from nylon 6,6
# Perform Custom Google Search for "consumer electronic parts" manufactured from nylon 6,6
# --> Finished Crawling for "consumer electronic parts" manufactured from nylon 6,6 term at: 2024-06-22 23:32:25
#
# Completed web crawling and started web scrapping.
#
# --> Current Working Directory: /home/ec2-user/SageMaker/AscendNB/WebScrapingCode
# Directory 'Revised_Search_Terms' already exists.
# URL counter to scrap data:  1
# Title: Engineering Plastic Components - Lakshmi Electrical Control ...
# Snippet: Manufacturing High-performance gears and high aesthetic premium consumer electronic parts ... Polyamide (Nylon) 6/66, Urea Formaldehyde. Colouring Options.
# Company URL: https://www.lecsindia.com
# Company Name: Lecsindia
# Original URL: https://www.lecsindia.com/engineering-plastic-components/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  2
# Title: GWG 1000 replacement band | WatchUSeek Watch Forums
# Snippet: Dec 11, 2021 ... Consumer Electronic Parts and Accessories at PacParts, Inc. ... Free shipping for many products! www.ebay.com. [Richie Strap] 22mm 5 Ring Nylon ...
# Company URL: https://www.watchuseek.com
# Company Name: Watchuseek
# Original URL: https://www.watchuseek.com/threads/gwg-1000-replacement-band.5363147/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  3
# Title: Buy Business abs plastic custom Wholesale Items Hassle-Free ...
# Snippet: ABS custom made OEM plastic product injection parts of auto consumer electronic parts. $0.20 - $2.00. MOQ: 500 pieces. Contact supplier ...
# Company URL: https://www.alibaba.com
# Company Name: Alibaba
# Original URL: https://www.alibaba.com/showroom/abs-plastic-custom.html
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  4
# Title: Precision plastic injection mould for consumer electronic parts
# Snippet: Precision plastic injection mould for consumer electronic parts. Precision ... China Toolmaker, plastic mould manufacturing, die cast mold making, custom ...
# Company URL: https://www.suntimemould.com
# Company Name: Suntimemould
# Original URL: https://www.suntimemould.com/precision-mould-for-mobile-connector-service/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  5
# Title: Plastic injection moulding project from Rapid prototyping to Tooling ...
# Snippet: Our main business is for plastic injection mold making, die cast mold making ... Precision plastic injection mould for consumer electronic parts · Precision ...
# Company URL: https://m.suntimemould.com
# Company Name: M
# Original URL: https://m.suntimemould.com/injection-molding-for-uilding-construction-service/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  6
# Title: Plastic mould for Nylon with glass fiber material | Suntime
# Snippet: Precision plastic injection mould for consumer electronic parts · Precision ... China Toolmaker, plastic mould manufacturing, die cast mold making, custom ...
# Company URL: https://www.suntimemould.com
# Company Name: Suntimemould
# Original URL: https://www.suntimemould.com/mining-parts-tooling-with-nylon-gf-resin-service/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  7
# Title: Prototyping – Henrong CNC Machining
# Snippet: May 20, 2019 ... ... consumer electronic parts, customer demand is more and more various ... * Machinable Plastic: ABS, Nylon 6/6, etc. AVAILABLE FINISHES.
# Company URL: https://www.henrongcncmachining.com
# Company Name: Henrongcncmachining
# Original URL: https://www.henrongcncmachining.com/prototyping/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred:
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 503 Server Error: Service Unavailable for url: https://www.amazon.in/Cable-Video-Camera-Adapter-Connector/dp/B01MUS02H3
# --> Failed to fetch full content.
#
# --> Current Working Directory: /home/ec2-user/SageMaker/AscendNB/WebScrapingCode
# Completed web scrapping.
#
# --> Current Working Directory: /home/ec2-user/SageMaker/AscendNB/WebScrapingCode
# ================================================================
#
# Search Group and Term Type: GRP1_2
# Performing Google search for ""consumer electronic" products manufactured from nylon 6,6".
# ================================================================
#
# --> Search Term directory that will be used to save results is: "Revised_Search_Terms".
# --> Starting Crawling for "consumer electronic" products manufactured from nylon 6,6 term at: 2024-06-22 23:33:44
# Perform Custom Google Search for "consumer electronic" products manufactured from nylon 6,6
# Perform Custom Google Search for "consumer electronic" products manufactured from nylon 6,6
# Perform Custom Google Search for "consumer electronic" products manufactured from nylon 6,6
# Perform Custom Google Search for "consumer electronic" products manufactured from nylon 6,6
# Perform Custom Google Search for "consumer electronic" products manufactured from nylon 6,6
# --> Finished Crawling for "consumer electronic" products manufactured from nylon 6,6 term at: 2024-06-22 23:33:45
#
# Completed web crawling and started web scrapping.
#
# --> Current Working Directory: /home/ec2-user/SageMaker/AscendNB/WebScrapingCode
# Directory 'Revised_Search_Terms' already exists.
# URL counter to scrap data:  1
# Title: Thermoplastic Injection Molding – An Engineer's Guide - Polymer ...
# Snippet: Dec 19, 2019 ... ... manufacturing quality plastic products for diverse industries. ... There are several consumer electronic goods like laundry irons, hair ...
# Company URL: https://prlresins.com
# Company Name: Prlresins
# Original URL: https://prlresins.com/thermoplastic-injection-molding-an-engineers-guide/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://prlresins.com/thermoplastic-injection-molding-an-engineers-guide/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  2
# Title: IDEM: Recycle Indiana: What Is Recyclable
# Snippet: ... consumer electronic equipment. Electronics (Televisions):. Recoverable ... Used leather goods or scrap leather can be made into new leather products. Lead ...
# Company URL: https://www.in.gov
# Company Name: In
# Original URL: https://www.in.gov/idem/recycle/what-is-recyclable/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  3
# Title: Huntsman Polyurethanes :: Huntsman Corporation (HUN)
# Snippet: Apr 17, 2024 ... ... made using recycled plastic waste. It's a true sustainability ... consumer electronic devices, including plasma screens, mobile phones ...
# Company URL: https://www.huntsman.com
# Company Name: Huntsman
# Original URL: https://www.huntsman.com/about/polyurethanes
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  4
# Title: Home Furnishings and Thermal Insulation Act
# Snippet: Jan 1, 2022 ... (b) (1) A manufacturer of covered products ... (4) Consumer electronic products that do not fall under the bureau's jurisdiction for flammability.
# Company URL: https://www.bhgs.dca.ca.gov
# Company Name: Bhgs
# Original URL: https://www.bhgs.dca.ca.gov/laws/hfti_regs.pdf
# The text contains '.pdf'.
# The pdf file name is hfti_regs.pdf
# URL counter to scrap data:  5
# Title: Port Sealing: An Effective Heat Sealing Solution - Heat Staking ...
# Snippet: Heat sealing of products with thermal adhesives is used to hold clear display screens onto consumer electronic ... Nylon 6/6 (Polyamide 6/6); PPO (polyphenylene ...
# Company URL: https://www.thermalpress.com
# Company Name: Thermalpress
# Original URL: https://www.thermalpress.com/port-sealing-effective-heat-sealing-solution/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  12
# Title: I need to identify peculiar MAC address in my network - Networking ...
# Snippet: May 29, 2014 ... jbrix (Jared7469) May 29, 2014, 12:26pm 6 ... is a leading manufacturer professional designer and OEM/ODM supplier of digital consumer electronic ...
# Company URL: https://community.spiceworks.com
# Company Name: Community
# Original URL: https://community.spiceworks.com/t/i-need-to-identify-peculiar-mac-address-in-my-network/307898
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  13
# Title: Cord Product Terminals | Ground Pins | Blade Terminals | ETCO
# Snippet: Polarized Blades come as a set and can be used in virtually any consumer electronic or appliance power application. ... 6/6 Nylon, Flame Retardant Insulators ...
# Company URL: https://www.etco.com
# Company Name: Etco
# Original URL: https://www.etco.com/cord-products/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  14
# Title: Electronics industry - Wikipedia
# Snippet: ... plastic, steel tubing, and other materials. Consumer electronics ... Global annual consumer electronic sales are expected to reach $2.9 trillion by 2020.
# Company URL: https://en.wikipedia.org
# Company Name: En
# Original URL: https://en.wikipedia.org/wiki/Electronics_industry
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  15
# Title: Best Tips for 3D Printing Consumer Electronic Housings
# Snippet: and considerations of 3D printing consumer electronic housings. Starting with the benefits of Additive. Manufacturing and the main factors of why you should ...
# Company URL: https://info.sculpteo.com
# Company Name: Info
# Original URL: https://info.sculpteo.com/hubfs/downloads/3D%20Printing%20and%20Consumer%20Electronics%20Housings.pdf
# The text contains '.pdf'.
# The pdf file name is 3D%20Printing%20and%20Consumer%20Electronics%20Housings.pdf
# URL counter to scrap data:  16
# Title: PA Plastic | Material Series for Product Design
# Snippet: Jun 4, 2024 ... Consumer Electronic · Casing , housing and components of cellphones ... Polyamide 6 (PA 6) and Polyamide 66 (PA 66). Processing Conditions.
# Company URL: https://firstmold.com
# Company Name: Firstmold
# Original URL: https://firstmold.com/guides/pa-plastic/
# The text does not contain '.pdf'. Therefore extracting data from URL
# An error occurred: HTTPSConnectionPool(host='firstmold.com', port=443): Max retries exceeded with url: /guides/pa-plastic/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7eff40823010>, 'Connection to firstmold.com timed out. (connect timeout=30)'))
# --> Failed to fetch full content.
#
# URL counter to scrap data:  17
# Title: BASF Factbook
# Snippet: Jun 1, 2022 ... while also serving global consumer electronic and energy storage ... polyamide 6 and 6.6, nitric acid, sulfur and chlorine products, inorganic ...
# Company URL: https://www.basf.com
# Company Name: Basf
# Original URL: https://www.basf.com/global/documents/en/investor-relations/calendar-and-publications/Factbook/BASF_Factbook_2022.pdf
# The text contains '.pdf'.
# The pdf file name is BASF_Factbook_2022.pdf
# URL counter to scrap data:  18
# Title: BENFEI DisplayPort to DisplayPort 3 Feet Cable, DP ... - Amazon.com
# Snippet: Since our foundation in 2014, we've been dedicated to building consumer electronic devices and accessories with leading technological innovations. We focus ...
# Company URL: https://www.amazon.com
# Company Name: Amazon
# Original URL: https://www.amazon.com/BENFEI-DisplayPort-Gold-Plated-Supports-Compatible/dp/B0C6Y1SRMT
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 500 Server Error: Internal Server Error for url: https://www.amazon.com/BENFEI-DisplayPort-Gold-Plated-Supports-Compatible/dp/B0C6Y1SRMT
# --> Failed to fetch full content.
#
# URL counter to scrap data:  19
# Title: UL 94 Flame Classifications - UL94 FLAME RATINGS for Plastics
# Snippet: ... manufacturing enclosures, structural parts and insulators found in consumer electronic products ... Nylon - EXTRUDED, Nylon 6/6 UNFILLED · Vespel® SP-1 Rod & ...
# Company URL: https://www.professionalplastics.com
# Company Name: Professionalplastics
# Original URL: https://www.professionalplastics.com/UL94FlameClassificationsForPlastics
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.professionalplastics.com/UL94FlameClassificationsForPlastics
# --> Failed to fetch full content.
#
# URL counter to scrap data:  20
# Title: K 2013 Preview: Materials & Additives | Plastics Technology
# Snippet: Aug 28, 2013 ... ... consumer electronic components, novelty products, and handles. ... Grade OP 1400 is designed for reinforced nylon 6 and 66. In addition to its ...
# Company URL: https://www.ptonline.com
# Company Name: Ptonline
# Original URL: https://www.ptonline.com/articles/k-2013-preview-materials-additives
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.ptonline.com/articles/k-2013-preview-materials-additives
# --> Failed to fetch full content.
#
# URL counter to scrap data:  21
# Title: Nylon Electronic Hardware | PCB Nylon Fasteners
# Snippet: Nylon spacers and standoffs are well-suited for consumer electronic devices and applications. We stock various standoffs and unthreaded spacers in nylon and ...
# Company URL: https://www.rcfastener.com
# Company Name: Rcfastener
# Original URL: https://www.rcfastener.com/products/nylon-electronic-hardware.html
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  22
# Title: Designing consumer electronic products for the circular economy ...
# Snippet: the caseworks of small consumer electronic products as a step towards more circular design and ... Custom sample holders were produced in sintered Nylon allowing ...
# Company URL: https://irep.ntu.ac.uk
# Company Name: Irep
# Original URL: https://irep.ntu.ac.uk/id/eprint/37132/1/14303_Ford.pdf
# The text contains '.pdf'.
# The pdf file name is 14303_Ford.pdf
# URL counter to scrap data:  23
# Title: Specialty Films - Specialty Chemicals Update Program (SCUP ...
# Snippet: ... consumer electronic products such as smartphones, tablets, notebooks ... Nylon film 66. Properties 66. Technology and manufacture 67. Production cost 68. United ...
# Company URL: https://www.spglobal.com
# Company Name: Spglobal
# Original URL: https://www.spglobal.com/commodityinsights/en/ci/products/chemical-specialty-films-scup.html
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.spglobal.com/commodityinsights/en/ci/products/chemical-specialty-films-scup.html
# --> Failed to fetch full content.
#
# URL counter to scrap data:  24
# Title: 21st Century Entertainment Inc.: Distributor of Consumer Electronic ...
# Snippet: WE MANUFACTURE HUNDREDS OF PRODUCTS! MY CART 0. Your cart is currently empty ... CDD Nylon Cable Tie 10", 100 Pack. No reviews. QUICK VIEW · CDD Silicone Sealant ...
# Company URL: https://www.21stcenturyent.com
# Company Name: 21stcenturyent
# Original URL: https://www.21stcenturyent.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  25
# Title: Regulatory Determinations Report to the Legislature: Safer Products ...
# Snippet: Jun 5, 2022 ... Yes. Restriction on HFRs in external plastic device casings for electric and electronic products intended for indoor use. ... Consumer electronic.
# Company URL: https://apps.ecology.wa.gov
# Company Name: Apps
# Original URL: https://apps.ecology.wa.gov/publications/documents/2204018.pdf
# The text contains '.pdf'.
# The pdf file name is 2204018.pdf
# URL counter to scrap data:  26
# Title: Digitakt modified with internal battery - Digitakt - Elektronauts
# Snippet: TALENTCELL provide the latest in premium quality consumer electronic products and accessories. Innovation and quality mean everything. Every single ...
# Company URL: https://www.elektronauts.com
# Company Name: Elektronauts
# Original URL: https://www.elektronauts.com/t/digitakt-modified-with-internal-battery/91600?page=15
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  27
# Title: trinamiX GmbH on LinkedIn: Exciting days ahead: Today MWC ...
# Snippet: Feb 23, 2021 ... AR VR Consumer Electronic | Project Management | New Product ... product, the first polyamide 6 entirely made from textile waste. With ...
# Company URL: https://www.linkedin.com
# Company Name: Linkedin
# Original URL: https://www.linkedin.com/posts/trinamixsensing_exciting-days-ahead-today-mwc-shanghai-activity-6769993359193976833-QPoP?trk=public_profile_like_view
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  28
# Title: Low Torque Termination Tool | Jonard Tools
# Snippet: Designed to tighten F Connectors, this indoor torque tool is perfect for connecting COAX connectors to consumer electronic devices with the proper amount of ...
# Company URL: https://jonard.com
# Company Name: Jonard
# Original URL: https://jonard.com/tt-812-low-torque-termination-tool
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  29
# Title: Global Nylon 6 Production Capacity reach to 8.86 million Tons in 2024
# Snippet: Nov 28, 2019 ... Consumer Electronic · Automotive · Vehicle · Automotive Part · NEVs · Unmanned ... Nylon 6 is the downstream product of petrochemical industry ...
# Company URL: https://www.hdinresearch.com
# Company Name: Hdinresearch
# Original URL: https://www.hdinresearch.com/news/56
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  30
# Title: 64th Annual Report of the Foreign-Trade Zones Board
# Snippet: (motor vehicle audio/vehicle products), approved 6/28/01 (66. FR 36743, 7/13/01) ... 72L (consumer electronic products), approved 3/27/96 (61. FR 15461, 4/8/96) ...
# Company URL: https://www.trade.gov
# Company Name: Trade
# Original URL: https://www.trade.gov/sites/default/files/2020-10/AR-2002.pdf
# The text contains '.pdf'.
# The pdf file name is AR-2002.pdf
# URL counter to scrap data:  31
# Title: Pub 4355 ITA Expansion Part 1 332-532
# Snippet: Oct 24, 2012 ... microchip manufacturing, and consumer electronic equipment. None identified. None identified. 900661. Discharge lamp ("electronic") flashlight.
# Company URL: https://www.usitc.gov
# Company Name: Usitc
# Original URL: https://www.usitc.gov/publications/332/pub4355.pdf
# The text contains '.pdf'.
# The pdf file name is pub4355.pdf
# URL counter to scrap data:  32
# Title: Towards the Circular Economy: Accelerating the scale-up across ...
# Snippet: Nylon 6 over and over again. This in turn can be transformed into 100 ... devices and other consumer electronic equipment is also vibrant. The US ...
# Company URL: https://www3.weforum.org
# Company Name: Www3
# Original URL: https://www3.weforum.org/docs/WEF_ENV_TowardsCircularEconomy_Report_2014.pdf
# The text contains '.pdf'.
# An error occurred: Exceeded 30 redirects.
# URL counter to scrap data:  33
# Title: Wandrd Rogue Sling 6 l photo bag – yellow | Fdirect.eu - B2B only
# Snippet: ... 6 l is made of high-quality water-resistant materials. ... A European distributor of photo, video, audio, consumer electronic and healthcare products carrying ...
# Company URL: https://fdirect.eu
# Company Name: Fdirect
# Original URL: https://fdirect.eu/b2b/wandrd-rogue-sling-6-l-photo-bag-yellow/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  34
# Title: K-One Technology Bhd | LinkedIn
# Snippet: ... manufacturing services (EMS) focusing on medical/healthcare devices, IoT gadgets, consumer electronic products and industrial equipment, (2) development and ...
# Company URL: https://zw.linkedin.com
# Company Name: Zw
# Original URL: https://zw.linkedin.com/company/k-one-technology
# The text does not contain '.pdf'. Therefore extracting data from URL
# --> Failed to fetch full content.
#
# URL counter to scrap data:  35
# Title: Computer Display Industry and Technology Profile
# Snippet: growing numbers of consumer electronic products in the marketplace, creating an ... The transistors are made up of the regions illustrated in Figure 3-6 and.
# Company URL: https://19january2017snapshot.epa.gov
# Company Name: 19january2017snapshot
# Original URL: https://19january2017snapshot.epa.gov/sites/production/files/2014-01/documents/computer_display_profile.pdf
# The text contains '.pdf'.
# The pdf file name is computer_display_profile.pdf
# URL counter to scrap data:  36
# Title: Fly Ash-Incorporated Polystyrene Nanofiber Membrane as a Fire ...
# Snippet: Oct 28, 2022 ... ... consumer electronic products, building and construction, and oil ... nylon-6 nanocomposite prepared by one-step electrospinning process.
# Company URL: https://www.ncbi.nlm.nih.gov
# Company Name: Ncbi
# Original URL: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9656177/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9656177/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  37
# Title: Deca-BDE and Alternatives in Electrical and Electronic Equipment
# Snippet: Dec 13, 2005 ... Polyamide 66; Nylon6-6 ... materials commonly used in manufacturing enclosures, structural parts and insulators found in consumer electronic prod-.
# Company URL: https://www2.mst.dk
# Company Name: Www2
# Original URL: https://www2.mst.dk/udgiv/publications/2007/978-87-7052-349-3/pdf/978-87-7052-350-9.pdf
# The text contains '.pdf'.
# The pdf file name is 978-87-7052-350-9.pdf
# URL counter to scrap data:  38
# Title: 1 UNITED STATES TRADE REPRESENTATIVE + + + + + 301 ...
# Snippet: Aug 21, 2018 ... ... products falling in. 19. Subheading 8417.80.10 are consumer electronic. 20 products. More specifically, they are. 21 controllers for DJ systems ...
# Company URL: https://ustr.gov
# Company Name: Ustr
# Original URL: https://ustr.gov/sites/default/files/enforcement/301Investigations/0821USTR.pdf
# The text contains '.pdf'.
# The pdf file name is 0821USTR.pdf
# URL counter to scrap data:  39
# Title: PGM market report - May 2022
# Snippet: While the hard disk industry faces some headwinds, notably from the adoption of solid-state drives in most consumer electronic devices, this has been more than.
# Company URL: https://matthey.com
# Company Name: Matthey
# Original URL: https://matthey.com/documents/161599/509428/PGM-market-report-May-2022.pdf/542bcada-f4ac-a673-5f95-ad1bbfca5106?t=1655877358676
# The text contains '.pdf'.
# The pdf file name is 542bcada-f4ac-a673-5f95-ad1bbfca5106?t=1655877358676
# URL counter to scrap data:  40
# Title: VH Connector Datasheet by JST Sales America Inc. | Digi-Key ...
# Snippet: consumer electronic products. Features ––––––––––––––––––––––––. • Proven box ... Nylon 6, UL94V-0, natural (white). Housing ...
# Company URL: https://www.digikey.in
# Company Name: Digikey
# Original URL: https://www.digikey.in/htmldatasheets/production/75674/0/0/1/vh-connector.html
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  50
# Title: 3M™ Adhesive Transfer Tape 9471LE | 3M United States
# Snippet: Consumer electronic device assemblies such as phones, tablets and wearable devices ... product that is produced via a solventless manufacturing process.
# Company URL: https://www.3m.com
# Company Name: 3m
# Original URL: https://www.3m.com/3M/en_US/p/d/b40065864/
# The text does not contain '.pdf'. Therefore extracting data from URL
# An error occurred: HTTPSConnectionPool(host='www.3m.com', port=443): Read timed out. (read timeout=30)
# --> Failed to fetch full content.
#
# --> Current Working Directory: /home/ec2-user/SageMaker/AscendNB/WebScrapingCode
# Completed web scrapping.
#
# --> Current Working Directory: /home/ec2-user/SageMaker/AscendNB/WebScrapingCode
# ================================================================
#
# Search Group and Term Type: GRP1_3
# Performing Google search for ""consumer electronic" companies that use "Nylon" in their products".
# ================================================================
#
# --> Search Term directory that will be used to save results is: "Revised_Search_Terms".
# --> Starting Crawling for "consumer electronic" companies that use "Nylon" in their products term at: 2024-06-22 23:35:24
# Perform Custom Google Search for "consumer electronic" companies that use "Nylon" in their products
# Perform Custom Google Search for "consumer electronic" companies that use "Nylon" in their products
# Perform Custom Google Search for "consumer electronic" companies that use "Nylon" in their products
# Perform Custom Google Search for "consumer electronic" companies that use "Nylon" in their products
# Perform Custom Google Search for "consumer electronic" companies that use "Nylon" in their products
# --> Finished Crawling for "consumer electronic" companies that use "Nylon" in their products term at: 2024-06-22 23:35:26
#
# Completed web crawling and started web scrapping.
#
# --> Current Working Directory: /home/ec2-user/SageMaker/AscendNB/WebScrapingCode
# Directory 'Revised_Search_Terms' already exists.
# URL counter to scrap data:  1
# Title: What's in Store for Polymer Additive Manufacturing Materials in 2024 ...
# Snippet: Feb 12, 2024 ... For manufacturers using Nylon 12, a material made with petroleum ... the consumer electronic space. As our history has shown with laptops ...
# Company URL: https://www.advancedlasermaterials.com
# Company Name: Advancedlasermaterials
# Original URL: https://www.advancedlasermaterials.com/alm-industry-predictions-2024/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  2
# Title: ESD Anti-Static IC Tray Strap Electronic Products Nylon Bundle ...
# Snippet: ... Products Nylon Bundle Reverse Buckle Strap - DONGGUAN ANTISK ELECTRONIC CO., LTD. ... Consumer Electronic Product · Security Strap · Strap Adjust · Strap Harness ...
# Company URL: https://antisk.en.made-in-china.com
# Company Name: Antisk
# Original URL: https://antisk.en.made-in-china.com/product/uThRocPlaQkX/China-ESD-Anti-Static-IC-Tray-Strap-Electronic-Products-Nylon-Bundle-Reverse-Buckle-Strap.html
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 493 Client Error:  for url: https://antisk.en.made-in-china.com/product/uThRocPlaQkX/China-ESD-Anti-Static-IC-Tray-Strap-Electronic-Products-Nylon-Bundle-Reverse-Buckle-Strap.html
# --> Failed to fetch full content.
#
# URL counter to scrap data:  3
# Title: Tips to Choose the Right SLS Printing Service for Your Project
# Snippet: SLS 3D printing uses various materials to build functional and robust parts, but top manufacturers offer powdered PA 12 (nylon). ... Consumer Electronic Product ...
# Company URL: https://www.hlhprototypes.com
# Company Name: Hlhprototypes
# Original URL: https://www.hlhprototypes.com/tips-to-choose-the-right-sls-printing-service-for-your-project/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  4
# Title: Connectors for Consumer Electronic Applications | ElectroShield
# Snippet: Your Connection For Consumer Electronic Applications. Consumer buying power ... Nylon, nickel plated brass, stainless steel, silicone, rubber, gold plated are ...
# Company URL: https://www.electroshield.com
# Company Name: Electroshield
# Original URL: https://www.electroshield.com/consumer
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  5
# Title: IDEM: Recycle Indiana: What Is Recyclable
# Snippet: Nylon fibers from used carpet and/or pre-consumer nylon derived from the carpet manufacturing process are recycled to produce new carpet. ... consumer electronic ...
# Company URL: https://www.in.gov
# Company Name: In
# Original URL: https://www.in.gov/idem/recycle/what-is-recyclable/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  6
# Title: Why are Chinese products of such low quality (other than iPhone ...
# Snippet: Aug 7, 2013 ... ... a CHEAP NYLON shoulder strap and PLASTIC interior zipper. Berluti ... Industry cluster: China has many industry cluster-consumer electronic ...
# Company URL: https://www.quora.com
# Company Name: Quora
# Original URL: https://www.quora.com/Why-are-Chinese-products-of-such-low-quality-other-than-iPhone-being-manufactured-in-China
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  7
# Title: Plastic Screws | Plastic Bolts | Nylon Screws/Bolts | Fastenright Ltd
# Snippet: Widely used across a range of industries and typically found in general consumer electronic devices or home appliances. ... See our full range of Plastic & Nylon ...
# Company URL: https://www.fastenright.com
# Company Name: Fastenright
# Original URL: https://www.fastenright.com/products/general-fixings/plastic-nylon-fasteners/plastic-nylon-screws
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.fastenright.com/products/general-fixings/plastic-nylon-fasteners/plastic-nylon-screws
# --> Failed to fetch full content.
#
# URL counter to scrap data:  8
# Title: Midi Thru PCB Enclosure — 3D People UK
# Snippet: Mar 5, 2021 ... Tindie's products are usually PCB boards for DIY projects and therefore do not come as a final consumer electronic product with casing.
# Company URL: https://www.3dpeople.uk
# Company Name: 3dpeople
# Original URL: https://www.3dpeople.uk/3dpeopleuk-blog/midi-thru-pcb-enclosure
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  9
# Title: Selective Laser Sintering Equipment Market by Material & Industry ...
# Snippet: SLS equipment is extensively used in the prototyping and functional prototyping of consumer electronic devices¡ ... using either nylon or metal as the base ...
# Company URL: https://www.marketsandmarkets.com
# Company Name: Marketsandmarkets
# Original URL: https://www.marketsandmarkets.com/Market-Reports/selective-laser-sintering-equipment-market-27853684.html
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  10
# Title: Designing consumer electronic products for the circular economy ...
# Snippet: Nov 1, 2019 ... ... consumer electronic products as a step towards more circular design and manufacturing. ... Nylon, PC, PLA and TPU 95A) for use as bipolar plates ( ...
# Company URL: https://www.sciencedirect.com
# Company Name: Sciencedirect
# Original URL: https://www.sciencedirect.com/science/article/abs/pii/S095965261932298X
# The text does not contain '.pdf'. Therefore extracting data from URL
# ...
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  23
# Title: Styrolution PS 5600/5601 - HIPS
# Snippet: Consumer electronic housings; Housewares; Office accessories; Appliance parts ... Only in exceptional cases (e.g. mouldings with a marble effect) injection ...
# Company URL: https://www.ineos-styrolution.com
# Company Name: Ineos
# Original URL: https://www.ineos-styrolution.com/Product/HIPS_Styrolution-PS-5600-5601_SKU200400070630.html
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  24
# Title: The Ultimate Guide to Plastic Injection Molding - UKPACK
# Snippet: Jul 5, 2023 ... The design and fabrication of molds used in plastic injection molding ... The production of consumer electronic devices heavily relies on plastic ...
# Company URL: https://www.ukpackchina.com
# Company Name: Ukpackchina
# Original URL: https://www.ukpackchina.com/plastic-injection-molding/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  25
# Title: The 3-D Printing Revolution
# Snippet: But recent advances in the technology are changing that dramatically in industrial settings. ... consumer electronic devices. Additional applications include ...
# Company URL: https://hbr.org
# Company Name: Hbr
# Original URL: https://hbr.org/2015/05/the-3-d-printing-revolution
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  26
# Title: From rapid prototyping to home fabrication: How 3D printing is ...
# Snippet: In the UK, High Street consumer electronic retailer Maplin also started to ... Precision prototyping: the role of 3D printed molds in the injection molding ...
# Company URL: https://www.sciencedirect.com
# Company Name: Sciencedirect
# Original URL: https://www.sciencedirect.com/science/article/pii/S0040162515002425
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.sciencedirect.com/science/article/pii/S0040162515002425
# --> Failed to fetch full content.
#
# URL counter to scrap data:  27
# Title: BENFEI DisplayPort to DisplayPort 3 Feet Cable, DP ... - Amazon.com
# Snippet: Integrated injection molding, Integrated injection molding. Brief content ... consumer electronic devices and accessories with leading technological innovations.
# Company URL: https://www.amazon.com
# Company Name: Amazon
# Original URL: https://www.amazon.com/BENFEI-DisplayPort-Gold-Plated-Supports-Compatible/dp/B0C6Y1SRMT
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 500 Server Error: Internal Server Error for url: https://www.amazon.com/BENFEI-DisplayPort-Gold-Plated-Supports-Compatible/dp/B0C6Y1SRMT
# --> Failed to fetch full content.
#
# URL counter to scrap data:  28
# Title: K 2013 Preview: Materials & Additives | Plastics Technology
# Snippet: Aug 28, 2013 ... ... consumer electronic components, novelty products, and handles. Wacker Chemical (U.S. office in Adrian, Mich.) will unveil an LSR for molded ...
# Company URL: https://www.ptonline.com
# Company Name: Ptonline
# Original URL: https://www.ptonline.com/articles/k-2013-preview-materials-additives
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.ptonline.com/articles/k-2013-preview-materials-additives
# --> Failed to fetch full content.
#
# URL counter to scrap data:  29
# Title: SYNTHENE » PU[RE]INNOVATION
# Snippet: A large catalogue of efficient vacuum casting resins for prototyping and small series like automotive and consumer electronic projects ... Excellence in dipping, ...
# Company URL: https://www.synthene.com
# Company Name: Synthene
# Original URL: https://www.synthene.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  30
# Title: SPE® ANNOUNCES “CALL FOR NOMINATIONS” FOR 50TH ...
# Snippet: Feb 18, 2021 ... Technology at the 2021 Consumer Electronic Show. OESA Supplier ... nylon composites have been studied through injection molding and mechanical ...
# Company URL: https://speautomotive.com
# Company Name: Speautomotive
# Original URL: https://speautomotive.com/wp-content/uploads/2021/03/SPEADNews_Spring21_FinalLR.pdf
# The text contains '.pdf'.
# The pdf file name is SPEADNews_Spring21_FinalLR.pdf
# URL counter to scrap data:  31
# Title: Consumer Electronic Accessories | Avient
# Snippet: Consumer Electronic Accessories ... In the fast-paced world of consumer electronics, you need to be producing the next best thing before it's big. We can help ...
# Company URL: https://www.avient.com
# Company Name: Avient
# Original URL: https://www.avient.com/industries/consumer/consumer-discretionary/home-household/consumer-electronic-accessories
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  32
# Title: Rapid Prototyping for Consumer Products - Boen
# Snippet: ... technologies,the integration of every kind Consumer Electronic device into our daily lives. ... The SLS process is to print the electronic products parts in nylon ...
# Company URL: https://www.boenrapid.com
# Company Name: Boenrapid
# Original URL: https://www.boenrapid.com/consumer-electronics.html
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  33
# Title: Best Company Of Plastic Injection Molding in China - TDL
# Snippet: ... in plastic tester mold manufacturing by integrating innovation ... Plastic injection molding is widely used to produce various components of consumer electronic ...
# Company URL: https://tdlmould.com
# Company Name: Tdlmould
# Original URL: https://tdlmould.com/capabilities/plastic-injection-molding/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://tdlmould.com/capabilities/plastic-injection-molding/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  34
# Title: Nylon Electronic Hardware | PCB Nylon Fasteners
# Snippet: Nylon spacers and standoffs are well-suited for consumer electronic devices and applications. ... Innovative nylon solutions coupled with over 66 years of ...
# Company URL: https://www.rcfastener.com
# Company Name: Rcfastener
# Original URL: https://www.rcfastener.com/products/nylon-electronic-hardware.html
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  35
# Title: Packing bimodal magnetic particles to fabricate highly dense ...
# Snippet: Jun 7, 2023 ... ... molding technology. The bimodal feedstock was a 96 wt ... in electric/hybrid vehicles, wind generators and other consumer electronic devices.
# Company URL: https://pubs.rsc.org
# Company Name: Pubs
# Original URL: https://pubs.rsc.org/en/content/articlehtml/2023/ra/d3ra02349d
# The text does not contain '.pdf'. Therefore extracting data from URL
# An error occurred: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# --> Failed to fetch full content.
#
# URL counter to scrap data:  36
# Title: How Mature Is Your Industry In Its Adoption Of 3D Printing ...
# Snippet: Jul 9, 2019 ... ... Technology to 3D print antennas and sensors for consumer electronic devices since 2016. This example alone demonstrates a huge, but largely ...
# Company URL: https://amfg.ai
# Company Name: Amfg
# Original URL: https://amfg.ai/2019/07/09/how-mature-is-your-industry-in-its-adoption-of-3d-printing/
# The text does not contain '.pdf'. Therefore extracting data from URL
# An error occurred: HTTPSConnectionPool(host='amfg.ai', port=443): Max retries exceeded with url: /2019/07/09/how-mature-is-your-industry-in-its-adoption-of-3d-printing/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7eff4077d3f0>, 'Connection to amfg.ai timed out. (connect timeout=30)'))
# --> Failed to fetch full content.
#
# URL counter to scrap data:  37
# Title: Plastics Processes
# Snippet: However its major application is as a protective packaging for consumer electronic products and white goods. ... RIM can be done using injection or transfer ...
# Company URL: https://www.bpf.co.uk
# Company Name: Bpf
# Original URL: https://www.bpf.co.uk/plastipedia/processes/Default.aspx
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  38
# Title: PA6 - ZIG SHENG INDUSTRIAL.
# Snippet: Polyamide (PA) 6 is ideal for precision injection molding. Increased surface ... Consumer electronic grade applications have passed VL V0 tests... Zig Sheng ...
# Company URL: http://www.zigsheng.com
# Company Name: Zigsheng
# Original URL: http://www.zigsheng.com/en/zig-sheng-products/polyamide-compounds/pa6/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  39
# Title: Consumer Electronics - Rapid-Protos
# Snippet: Nov 15, 2023 ... ... in various consumer electronic devices, enhancing their performance, functionality, and innovation. ... Injection Molding · Surface Finishing ...
# Company URL: https://www.rapid-protos.com
# Company Name: Rapid
# Original URL: https://www.rapid-protos.com/industries/consumer-electronics/
# The text does not contain '.pdf'. Therefore extracting data from URL
# An error occurred: HTTPSConnectionPool(host='www.rapid-protos.com', port=443): Max retries exceeded with url: /industries/consumer-electronics/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7eff40f46b00>, 'Connection to www.rapid-protos.com timed out. (connect timeout=30)'))
# --> Failed to fetch full content.
#
# URL counter to scrap data:  40
# Title: Additional Specifications - ZIG SHENG INDUSTRIAL.
# Snippet: ... injection molding & extrusion molding, Can replace some thermosetting resin & metal materials ... Consumer electronic grade applications have passed VL V0 tests..
# Company URL: http://www.zigsheng.com
# Company Name: Zigsheng
# Original URL: http://www.zigsheng.com/en/zig-sheng-products/polyamide-compounds/additional-specifications/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  41
# Title: Point-of-Care Diagnostics: Recent Developments in a Connected ...
# Snippet: Dec 13, 2016 ... Miniaturized components used in consumer electronic devices can be adapted for use in POC diagnostic devices. ... using a disposable, injection ...
# Company URL: https://www.ncbi.nlm.nih.gov
# Company Name: Ncbi
# Original URL: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5793870/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5793870/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  42
# Title: Structure and Bonding Materials - Henkel Adhesives
# Snippet: Injection Molding Compounds · Potting Compounds · Board-Level Encapsulants · Low ... consumer electronic devices. However, bonding the various components of the ...
# Company URL: https://www.henkel-adhesives.com
# Company Name: Henkel
# Original URL: https://www.henkel-adhesives.com/be/en/industries/electronics/consumer-electronics/smartphone-tablet/structure-bonding-materials.html
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  43
# Title: Premium Plastic Prototyping Services for Innovative Product ...
# Snippet: Our prototypes are widely used in the automotive prototype project, consumer electronic and household industries. ... Think of rapid injection molding as end use ...
# Company URL: https://www.qc-mold.com
# Company Name: Qc
# Original URL: https://www.qc-mold.com/Plastic-Prototype.html
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  44
# Title: Home - Online Manufacturing For Metal Parts And Plastic Parts, XTJ ...
# Snippet: Jul 17, 2018 ... Consumer Electronic. CNC machining overcome challenges related to ... Enabling Innovation Through Prototyping And Low-Volume Manufacturing ...
# Company URL: https://cncpartsxtj.com
# Company Name: Cncpartsxtj
# Original URL: https://cncpartsxtj.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  45
# Title: BASF Factbook
# Snippet: Jun 1, 2022 ... while also serving global consumer electronic and energy storage ... development and invest in the creation of innovations with the aim of.
# Company URL: https://www.basf.com
# Company Name: Basf
# Original URL: https://www.basf.com/global/documents/en/investor-relations/calendar-and-publications/Factbook/BASF_Factbook_2022.pdf
# The text contains '.pdf'.
# The pdf file name is BASF_Factbook_2022.pdf
# URL counter to scrap data:  46
# Title: Polyurethane Plastic — Better Than Traditional Material | by ...
# Snippet: Oct 4, 2016 ... Soft polyurethane widely used in manufacturing consumer electronic devices such as mobile phone, laptop, computer and television cases.
# Company URL: https://medium.com
# Company Name: Medium
# Original URL: https://medium.com/@alanagomez/polyurethane-plastic-better-than-traditional-material-f42864bed75e
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://medium.com/@alanagomez/polyurethane-plastic-better-than-traditional-material-f42864bed75e
# --> Failed to fetch full content.
#
# URL counter to scrap data:  47
# Title: White Paper – ESDM Industry
# Snippet: The recent trend in the consumer electronic products manufacturing is ... 147 Metal Injection Molding in the 5G era opportunities for growth, Staging, PIM ...
# Company URL: https://www.dcmsme.gov.in
# Company Name: Dcmsme
# Original URL: https://www.dcmsme.gov.in/white_paper/2.%20Whitepaper-ESDM%20Sector-Year%201.pdf
# The text contains '.pdf'.
# The pdf file name is 2.%20Whitepaper-ESDM%20Sector-Year%201.pdf
# URL counter to scrap data:  48
# Title: Effect of 3D Printing Technology on 3C Product Manufacturing
# Snippet: Nov 9, 2020 ... 3C product is the abbreviation of computer, communication and consumer electronic ... with those of injection molding and mechanical processing.
# Company URL: https://www.scirp.org
# Company Name: Scirp
# Original URL: https://www.scirp.org/html/12-1560872_103986.htm
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  49
# Title: Injection Moulding Services - Amuse
# Snippet: Explore our range of technology/options for your custom plastic injection moulding ... Rubber grips in hair dryers or any consumer electronic products are among ...
# Company URL: https://amuse3d.in
# Company Name: Amuse3d
# Original URL: https://amuse3d.in/amuse-injection-moulding-services/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  50
# Title: Accelerate Your Business with 3D Printing Materials for Prototyping ...
# Snippet: Look and feel of durable molded plastic. GOOD FOR: • Rapid prototyping. • Functional assemblies. • Snap-fit components. • Consumer electronic components. • ...
# Company URL: https://engtechgroup.com
# Company Name: Engtechgroup
# Original URL: https://engtechgroup.com/wp-content/uploads/2021/11/3d-systems-materials-buyers-guide-usen-2021-08-26-web_0.pdf
# The text contains '.pdf'.
# The pdf file name is 3d-systems-materials-buyers-guide-usen-2021-08-26-web_0.pdf
# --> Current Working Directory: /home/ec2-user/SageMaker/AscendNB/WebScrapingCode
# Completed web scrapping.
#
# --> Current Working Directory: /home/ec2-user/SageMaker/AscendNB/WebScrapingCode
# ================================================================

# %%
Crawl_process_stats

# %%
print(f"Performing Google search for \"{MY_SEARCH}\".")
print("================================================================")
print(" ")

# Define search term directory to save web scrapping results
SEARCH_TERM_DIR = search_term_directory(MY_SEARCH)

print(f"--> Search Term directory that will be used to save results is: \"{SEARCH_TERM_DIR}\".")

# Crawl the web to get results
Crawl_process_stats, results = crawl_search_term(MY_SEARCH, GOOGLE_CS_API_KEY, MY_CSE_ID, NUM_RESULTS)

print("Completed web crawling and started web scrapping.")
print(" ")

Metadata_DF_Final = scrap_websites(results, MY_SEARCH, WebSC_DIR, SEARCH_TERM_DIR, wrk_dir, get_Date())

print("Completed web scrapping.")
print(" ")

# Saving search results summary to a csv file
print("--> Current Working Directory:", os.getcwd())
Metadata_DF_Final.to_csv(Rslts_Save_Dir + "/" + SEARCH_TERM_DIR +"_"+ get_DateTime() + '.csv', index=False)

print("================================================================")
print(" ")

# Append the row
Crawl_scrap_processing_status.loc[len(Crawl_scrap_processing_status)] = Crawl_process_stats

Crawl_scrap_processing_status.to_csv(Rslts_Save_Dir + "/" + MY_SEARCH +"WebScrap_ProcessTime_"+ get_DateTime() + '.csv', index=False)
