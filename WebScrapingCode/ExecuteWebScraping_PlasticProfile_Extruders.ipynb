# %%
""" This file search the google web based on search term provided and scraps 99 websites from the web.

Very Important:
    1) Make sure to execute the required libraries by either commenting/uncommenting pip
    2) Make sure to use the right API Key for the GOOGLE_CS_API_KEY variable.

"""
# Out:
# ' This file search the google web based on search term provided and scraps 99 websites from the web.\n\nVery Important:\n    1) Make sure to execute the required libraries by either commenting/uncommenting pip\n    2) Make sure to use the right API Key for the GOOGLE_CS_API_KEY variable.\n\n'

# %%
# pip install -r "/home/ec2-user/SageMaker/AscendNotebook/ascendrequirements.txt"

# %%
# Import os module for interacting with the operating system
import os

# Import pandas as pd for data manipulation and analysis
import pandas as pd

from TimeMethods import get_Date, get_DateTime, Time

from WebScraping import (search_term_directory, crawl_search_term, scrap_websites)

# %%
# Define the following NUM_RESULTS variable to determine the number of web search results to crawl for scrapping
NUM_RESULTS = 99

# Exclude Wikipedia, Reddit, and LinkedIn from search results
# exclude_sites = 'site:en.wikipedia.org OR site:reddit.com OR site:linkedin.com'

MY_API_KEY = 'XXXXXXXX' # This Sai Vinnakota personal Google API keys
# TIOT_API_KEY = 'XXXXXXXX' #'XXXXXXXX' # This is TensorIOT Google API Keys
MY_CSE_ID = 'XXXXXXXX' #'XXXXXXXX' # Replace this with the client Search Engine ID
GOOGLE_CS_API_KEY = MY_API_KEY

# Get the working directory
wrk_dir = os.getcwd()
print(f"Current working directory \"{wrk_dir}\".")

# Initialize Root Directory
ROOT_DIR = "/home/ec2-user/SageMaker/AscendNotebook/"
print(f"Root directory \"{ROOT_DIR}\".")

# Initialize directory to save results
Rslts_Save_Dir = "/home/ec2-user/SageMaker/AscendNotebook/CodeExecutionMetrics/"
print(f"Directory to save scrapping results \"{Rslts_Save_Dir}\".")
# Out:
# Current working directory "/home/ec2-user/SageMaker/AscendNotebook/WebScrappingCode".
# Root directory "/home/ec2-user/SageMaker/AscendNotebook/".
# Directory to save scrapping results "/home/ec2-user/SageMaker/AscendNotebook/Results_Saved/".

# %% [markdown]
# # Use the right Google Custom Search API Key

# %%
GOOGLE_CS_API_KEY = MY_API_KEY

# %% [markdown]
# # Chose the appropriate search term

# %%
# MY_SEARCH = "Nylon & Polyamide injection molders"
MY_SEARCH = "Plastic Profile Extruders"
# MY_SEARCH = "Plastic Sheet extruders"
# MY_SEARCH = "Recycled carpet fibers applications"
# MY_SEARCH = "Nylon Compounders & Polyamide Compounders"

# MY_SEARCHES = ["Nylon & Polyamide injection molders", "Plastic Profile Extruders", "Plastic Sheet extruders", "Recycled carpet fibers applications", "Nylon Compounders & Polyamide Compounders"]

# %%
Crawl_scrap_processing_status = pd.DataFrame(columns = ['Search Term','Number of Results Crawled', 'Crawl Start Time', 
                                           'Crawl End Time', 'Crawl Exec Time in Minutes'])

print(f"Performing Google search for \"{MY_SEARCH}\".")
print("================================================================")
print(" ")

# Define search term directory to save web scrapping results
SEARCH_TERM_DIR = search_term_directory(MY_SEARCH)

print(f"--> Search Term directory that will be used to save results is: \"{SEARCH_TERM_DIR}\".")

# Crawl the web to get results
Crawl_process_stats, results = crawl_search_term(MY_SEARCH, GOOGLE_CS_API_KEY, MY_CSE_ID, NUM_RESULTS)

print("Completed web crawling and started web scrapping.")
print(" ")

Metadata_DF_Final = scrap_websites(results, MY_SEARCH, ROOT_DIR, SEARCH_TERM_DIR, wrk_dir, get_Date())

print("Completed web scrapping.")
print(" ")

# Saving search results summary to a csv file
print("--> Current Working Directory:", os.getcwd())
Metadata_DF_Final.to_csv(Rslts_Save_Dir + "/" + SEARCH_TERM_DIR +"_"+ get_DateTime() + '.csv', index=False)

print("================================================================")
print(" ")

# Append the row
Crawl_scrap_processing_status.loc[len(Crawl_scrap_processing_status)] = Crawl_process_stats

Crawl_scrap_processing_status.to_csv(Rslts_Save_Dir + "/" + MY_SEARCH +"WebScrap_ProcessTime_"+ get_DateTime() + '.csv', index=False)
# Out:
# Performing Google search for "Plastic Profile Extruders".
# ================================================================
#
# --> Search Term directory that will be used to save results is: "Plastic_Profile_Extruders".
# --> Starting Crawling for Plastic Profile Extruders term at: 2024-06-18 17:01:20
# 99
# {'kind': 'customsearch#search', 'url': {'type': 'application/json', 'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'}, 'queries': {'request': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 1, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'nextPage': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 11, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}]}, 'context': {'title': 'ASCEND-SE'}, 'searchInformation': {'searchTime': 0.35993, 'formattedSearchTime': '0.36', 'totalResults': '5600000', 'formattedTotalResults': '5,600,000'}, 'items': [{'kind': 'customsearch#result', 'title': 'Profile Plastics, Inc.: Custom Plastic Extrusions', 'htmlTitle': '<b>Profile Plastics</b>, Inc.: Custom <b>Plastic Extrusions</b>', 'link': 'https://www.profileplastics.com/', 'displayLink': 'www.profileplastics.com', 'snippet': 'Founded in 1993, Profile Plastics has offered custom plastic extrusions in Northeast Ohio for nearly 30 years.', 'htmlSnippet': 'Founded in 1993, <b>Profile Plastics</b> has offered custom <b>plastic extrusions</b> in Northeast Ohio for nearly 30 years.', 'formattedUrl': 'https://www.profileplastics.com/', 'htmlFormattedUrl': 'https://www.<b>profileplastic</b>s.com/', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRAh0YTsbqfIeCerrHsw2V8RQiYjI4UDjihPxuypbJtQ0m8A-T0i-ky2VA&s', 'width': '275', 'height': '183'}], 'metatags': [{'og:type': 'website', 'og:site_name': 'Profile Plastics, Inc.', 'article:modified_time': '2022-08-08T15:05:36+00:00', 'viewport': 'width=device-width, initial-scale=1.0', 'og:title': 'Custom Plastic Extrusions - Profile Plastics, Inc.', 'og:locale': 'en_US', 'og:url': 'https://www.profileplastics.com/', 'msapplication-tileimage': 'https://www.profileplastics.com/wp-content/uploads/cropped-logo-270x270.png', 'og:description': 'Founded in 1993, Profile Plastics has offered custom plastic extrusions in Northeast Ohio for nearly 30 years.'}], 'cse_image': [{'src': 'https://www.profileplastics.com/wp-content/uploads/coex2lg.jpg'}]}}, {'kind': 'customsearch#result', 'title': 'Plastic Extrusions - SeaGate Plastics Company', 'htmlTitle': '<b>Plastic Extrusions</b> - SeaGate <b>Plastics</b> Company', 'link': 'https://www.seagateplastics.com/plastic-extrusions/', 'displayLink': 'www.seagateplastics.com', 'snippet': 'Simply put, plastic extrusion is a high-volume manufacturing process in which raw plastic material is melted and formed into a continuous profile. The\xa0...', 'htmlSnippet': 'Simply put, <b>plastic extrusion</b> is a high-volume manufacturing process in which raw <b>plastic</b> material is melted and formed into a continuous <b>profile</b>. The&nbsp;...', 'formattedUrl': 'https://www.seagateplastics.com/plastic-extrusions/', 'htmlFormattedUrl': 'https://www.seagate<b>plastic</b>s.com/<b>plastic</b>-extrusions/', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQkRdDCYB-E6NDtwOdVmu_b0M1lUwHNyJHRcnEqHlBMiXroz4JZx2rhv9B7&s', 'width': '372', 'height': '135'}], 'imageobject': [{'image': 'https://www.s ...
# {'kind': 'customsearch#search', 'url': {'type': 'application/json', 'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'}, 'queries': {'previousPage': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 1, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'request': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 11, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'nextPage': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 21, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}]}, 'context': {'title': 'ASCEND-SE'}, 'searchInformation': {'searchTime': 0.211908, 'formattedSearchTime': '0.21', 'totalResults': '5600000', 'formattedTotalResults': '5,600,000'}, 'items': [{'kind': 'customsearch#result', 'title': 'Plastic Profile Extrusion｜Custom Profile', 'htmlTitle': '<b>Plastic Profile Extrusion</b>｜Custom Profile', 'link': 'https://www.custom-profile.com/', 'displayLink': 'www.custom-profile.com', 'snippet': 'Custom Profile is an employee-owned company that develops and manufactures thermoplastic profile extrusions and sub-assemblies. We have the capacity to handle\xa0...', 'htmlSnippet': 'Custom <b>Profile</b> is an employee-owned company that develops and manufactures thermoplastic <b>profile extrusions</b> and sub-assemblies. We have the capacity to handle&nbsp;...', 'formattedUrl': 'https://www.custom-profile.com/', 'htmlFormattedUrl': 'https://www.custom-<b>profile</b>.com/', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRtCcWmj1SMUyvqX5A9SSDaZss_GmzSDaCBIJqsH43aysisjnkyKKB4&s', 'width': '52', 'height': '66'}], 'metatags': [{'og:image': 'https://www.custom-profile.com/wp-content/uploads/2023/06/Capa_1.png', 'og:type': 'website', 'twitter:card': 'summary_large_image', 'og:site_name': 'Plastic Profile Extrusion｜Custom Profile', 'article:modified_time': '2024-03-01T13:40:27+00:00', 'viewport': 'width=device-width, initial-scale=1', 'og:title': 'Plastic Profile Extrusion｜Custom Profile', 'og:locale': 'en_US', 'og:url': 'https://www.custom-profile.com/', 'msapplication-tileimage': 'https://www.custom-profile.com/wp-content/uploads/2021/03/cropped-cropped-Horizontal-Logo-scaled-1-270x270.jpg', 'og:description': 'Custom Profile focuses on plastic profile extrusion during development, manufacturing, and sub-assembling. View our capabilities here.', 'article:publisher': 'https://www.facebook.com/CustomProfile'}], 'cse_image': [{'src': 'https://www.custom-profile.com/wp-content/uploads/2023/06/Capa_1.png'}]}}, {'kind': 'customsearch#result', 'title': 'Custom Plastic Profile Extrusion Design | Plastic Extruders', 'htmlTitle': 'Custom <b>Plastic Profile Extrusion</b> Design | Plastic Extruders', 'link': 'https://www.sfrindustries.com/design_assistance.phtml', 'displayLink': 'www.sfrindustries.com', 'snippet': 'As a leading manufacturer of custom plastic profile extrusions for a variety of industries, we specialize in catering  ...
# {'kind': 'customsearch#search', 'url': {'type': 'application/json', 'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'}, 'queries': {'previousPage': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 11, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'request': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 21, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'nextPage': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 31, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}]}, 'context': {'title': 'ASCEND-SE'}, 'searchInformation': {'searchTime': 0.179549, 'formattedSearchTime': '0.18', 'totalResults': '5600000', 'formattedTotalResults': '5,600,000'}, 'items': [{'kind': 'customsearch#result', 'title': 'Packaging 101: What Is Profile Extrusion? - Petro Packaging', 'htmlTitle': 'Packaging 101: What Is <b>Profile Extrusion</b>? - Petro Packaging', 'link': 'https://www.petropackaging.com/what-is-profile-extrusion/', 'displayLink': 'www.petropackaging.com', 'snippet': "Mar 15, 2021 ... Now that you know what is plastic extrusion, let's take a look at the process. The Process of Profile Extrusion. In the extrusion of plastics,\xa0...", 'htmlSnippet': 'Mar 15, 2021 <b>...</b> Now that you know what is <b>plastic extrusion</b>, let&#39;s take a look at the process. The Process of <b>Profile Extrusion</b>. In the <b>extrusion</b> of <b>plastics</b>,&nbsp;...', 'formattedUrl': 'https://www.petropackaging.com/what-is-profile-extrusion/', 'htmlFormattedUrl': 'https://www.petropackaging.com/what-is-<b>profile</b>-extrusion/', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSo3OYg-JwaXU1jLSYy2w9Cg4PTkP8Ik-O6mHv7QXBIqh5inkFhmLsALJQ&s', 'width': '318', 'height': '159'}], 'metatags': [{'application-name': 'Petro Packaging', 'msapplication-tilecolor': '#FFFFFF', 'og:image': 'https://www.petropackaging.com/wp-content/uploads/2021/03/what-is-profile-extrusion.png', 'og:type': 'article', 'article:published_time': '2021-03-15T17:34:06+00:00', 'og:image:width': '640', 'og:site_name': 'Petro Packaging', 'author': 'DTD Edit', 'og:title': 'Packaging 101: What Is Profile Extrusion? - Petro Packaging', 'og:image:height': '320', 'twitter:label1': 'Written by', 'twitter:label2': 'Est. reading time', 'og:image:type': 'image/png', 'msapplication-tileimage': 'https://www.petropackaging.com/mstile-144x144.png', 'og:description': "Are you interested in knowing what is profile extrusion? Well, if that's the case, you're in the right place.", 'twitter:data1': 'DTD Edit', 'twitter:data2': '11 minutes', 'article:modified_time': '2024-06-12T18:41:11+00:00', 'viewport': 'user-scalable=no, width=device-width, maximum-scale=1, minimum-scale=1', 'og:locale': 'en_US', 'og:url': 'https://www.petropackaging.com/what-is-profile-extrusion/'}], 'cse_image': [{'src': 'https://www.petropackaging.com/wp-content/uploads/2021/03/what-is-profile-extrusion.png'}]}}, {' ...
# {'kind': 'customsearch#search', 'url': {'type': 'application/json', 'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'}, 'queries': {'previousPage': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 21, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'request': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 31, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'nextPage': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 41, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}]}, 'context': {'title': 'ASCEND-SE'}, 'searchInformation': {'searchTime': 0.322438, 'formattedSearchTime': '0.32', 'totalResults': '5600000', 'formattedTotalResults': '5,600,000'}, 'items': [{'kind': 'customsearch#result', 'title': 'Extruded Profiles and Shapes', 'htmlTitle': '<b>Extruded Profiles</b> and Shapes', 'link': 'https://www.outwater.com/categories-list/extruded-profiles-and-shapes', 'displayLink': 'www.outwater.com', 'snippet': "Outwater's extruded plastic shapes are available in a large variety of different ... Our colored plastic extrusions and aluminum extrusions can be matched to\xa0...", 'htmlSnippet': 'Outwater&#39;s <b>extruded plastic</b> shapes are available in a large variety of different ... Our colored <b>plastic extrusions</b> and aluminum <b>extrusions</b> can be matched to&nbsp;...', 'formattedUrl': 'https://www.outwater.com/categories-list/extruded-profiles-and-shapes', 'htmlFormattedUrl': 'https://www.outwater.com/categories-list/extruded-<b>profile</b>s-and-shapes', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR1RiUbS8QFguxS4QqTBjc3ukGV_oYpIRJXB47AsXStJ53fc5Fz9cqgLug&s', 'width': '225', 'height': '225'}], 'metatags': [{'twitter:image3:src': 'https://www.outwater.com/scs/extensions/MHI/Outwater_Theme/1.0.0/img/no_image_available.jpeg', 'twitter:card': 'gallery', 'twitter:image2:src': 'https://www.outwater.com/scs/extensions/MHI/Outwater_Theme/1.0.0/img/no_image_available.jpeg', 'viewport': 'width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no', 'twitter:image0:src': 'https://www.outwater.com/scs/extensions/MHI/Outwater_Theme/1.0.0/img/no_image_available.jpeg', 'twitter:image1:src': 'https://www.outwater.com/scs/extensions/MHI/Outwater_Theme/1.0.0/img/no_image_available.jpeg'}], 'cse_image': [{'src': 'https://www.outwater.com/core/media/media.nl?id=173448&c=3409204&h=Tf2R1Ph2OKw_PcT1bYfujxeCVCgk_Z9ft8vOodxYI8qvjQml&resizeid=2&resizeh=270&resizew=270'}]}}, {'kind': 'customsearch#result', 'title': 'Plastic PVC profiles including Angles - BUY ONLINE', 'htmlTitle': '<b>Plastic PVC profiles</b> including Angles - BUY ONLINE', 'link': 'https://www.mkmplastics.com/shop', 'displayLink': 'www.mkmplastics.com', 'snippet': 'In terms of plastic extrusion this is the process of heating raw materials and pushing the molten plastic compound through a tool raw plastic to the desired\xa0...', 'htmlSnippet': ' ...
# {'kind': 'customsearch#search', 'url': {'type': 'application/json', 'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'}, 'queries': {'previousPage': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 31, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'request': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 41, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'nextPage': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 51, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}]}, 'context': {'title': 'ASCEND-SE'}, 'searchInformation': {'searchTime': 0.195604, 'formattedSearchTime': '0.20', 'totalResults': '5600000', 'formattedTotalResults': '5,600,000'}, 'items': [{'kind': 'customsearch#result', 'title': 'Rigid Plastic Extrusions', 'htmlTitle': 'Rigid <b>Plastic Extrusions</b>', 'link': 'https://www.reddiplex.com/rigid-plastic-extrusions/', 'displayLink': 'www.reddiplex.com', 'snippet': 'Rigid plastic extrusions are more commonly being used as a replacement for metal in automotive and construction applications. In addition rigid profiles are\xa0...', 'htmlSnippet': 'Rigid <b>plastic extrusions</b> are more commonly being used as a replacement for metal in automotive and construction applications. In addition rigid <b>profiles</b> are&nbsp;...', 'formattedUrl': 'https://www.reddiplex.com/rigid-plastic-extrusions/', 'htmlFormattedUrl': 'https://www.reddiplex.com/rigid-<b>plastic</b>-extrusions/', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT-V-CAY99ujqmG6b3uYmA3bMhjX8dCyKdMSd4CMtqUYgYN5Hd5LReHM365&s', 'width': '311', 'height': '162'}], 'imageobject': [{'thumbnailurl': 'https://www.reddiplex.com/wp-content/uploads/Rigid-Flexible.png'}, {'thumbnailurl': 'https://www.reddiplex.com/wp-content/uploads/Product-Image-Wood-Composite.png'}, {'thumbnailurl': 'https://www.reddiplex.com/wp-content/uploads/Rigid-Isolators.png'}, {'thumbnailurl': 'https://www.reddiplex.com/wp-content/uploads/wpc_250.jpg'}, {'thumbnailurl': 'https://www.reddiplex.com/wp-content/uploads/Tear-Off-Wedge-Gasket250.jpg'}, {'thumbnailurl': 'https://www.reddiplex.com/wp-content/uploads/solid-rubber-extrusion.png'}, {'thumbnailurl': 'https://www.reddiplex.com/wp-content/uploads/Materials-Extruded-Sponge-Ruber.png'}], 'metatags': [{'og:image': 'https://www.reddiplex.com/wp-content/uploads/Reddiplex_1200x627_003.jpg', 'og:type': 'article', 'og:image:width': '1200', 'twitter:card': 'summary_large_image', 'twitter:title': 'Reddiplex Rigid Plastic Extrusions', 'og:site_name': 'Reddiplex Ltd', 'og:title': 'Rigid Plastic Extrusions', 'og:image:height': '627', 'twitter:label1': 'Estimated reading time', 'og:image:type': 'image/jpeg', 'og:description': 'Rigid plastic extrusions can be either single material types or extruded using a combination of rigid and flexible materials.', 'twitter:image': 'https://www.reddiplex.com/wp-content/uploads/Rigid-Plastics.png',  ...
# {'kind': 'customsearch#search', 'url': {'type': 'application/json', 'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'}, 'queries': {'previousPage': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 41, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'request': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 51, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'nextPage': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 61, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}]}, 'context': {'title': 'ASCEND-SE'}, 'searchInformation': {'searchTime': 0.199056, 'formattedSearchTime': '0.20', 'totalResults': '5600000', 'formattedTotalResults': '5,600,000'}, 'items': [{'kind': 'customsearch#result', 'title': 'PVC/PE/PP/WPC wood plastic profile extrusion line - Benk ...', 'htmlTitle': 'PVC/PE/PP/WPC wood <b>plastic profile extrusion</b> line - Benk ...', 'link': 'https://www.benkextruder.com/pvc-pe-pp-wpc-wood-plastic-profile-extrusion-line-2/', 'displayLink': 'www.benkextruder.com', 'snippet': 'What is included in PVC/PE/PP/WPC Wood Plastic Profile Extruding Line? · Controlling system · Mixing unit · Screw feeder · Conical twin-screw extruder\xa0...', 'htmlSnippet': 'What is included in PVC/PE/PP/WPC Wood <b>Plastic Profile Extruding</b> Line? &middot; Controlling system &middot; Mixing unit &middot; Screw feeder &middot; Conical twin-screw extruder&nbsp;...', 'formattedUrl': 'https://www.benkextruder.com/pvc-pe-pp-wpc-wood-plastic-profile-extrusi...', 'htmlFormattedUrl': 'https://www.benkextruder.com/pvc-pe-pp-wpc-wood-<b>plastic</b>-<b>profile</b>-extrusi...', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSmbLJcJa0gep7EFRNElGqq0p-sIdeOlZyyKhpea4to0ToCglwQGQIjXlra&s', 'width': '300', 'height': '168'}], 'metatags': [{'og:image': 'https://www.benkextruder.com/wp-content/uploads/2021/06/PVCPEPPWPC-Wood-Plastic-Profile-Extrusion-Line.png', 'og:type': 'article', 'article:published_time': '2021-06-30T02:46:02+00:00', 'og:image:width': '1024', 'twitter:card': 'summary_large_image', 'og:site_name': 'Benk Machinery Co LTD', 'og:title': 'PVC/PE/PP/WPC wood plastic profile extrusion line - Benk Machinery Co LTD', 'og:image:height': '576', 'twitter:label1': 'Written by', 'twitter:label2': 'Est. reading time', 'og:image:type': 'image/png', 'msapplication-tileimage': 'https://www.benkextruder.com/wp-content/uploads/2021/06/cropped-512x512-1-270x270.png', 'og:description': 'PVC/PE/PP/WPC\xa0wood plastic profile production machine', 'twitter:data1': 'Benkextruder', 'twitter:data2': '2 minutes', 'article:modified_time': '2021-11-26T07:32:00+00:00', 'viewport': 'width=device-width, initial-scale=1.0', 'og:locale': 'en_US', 'og:url': 'https://www.benkextruder.com/pvc-pe-pp-wpc-wood-plastic-profile-extrusion-line-2/'}], 'cse_image': [{'src': 'https://www.benkextruder.com/wp-content/uploads/2021/06/PVCPEPPWPC-Wood-Plastic-Profile-Extrusi ...
# {'kind': 'customsearch#search', 'url': {'type': 'application/json', 'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'}, 'queries': {'previousPage': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 51, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'request': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 61, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'nextPage': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 71, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}]}, 'context': {'title': 'ASCEND-SE'}, 'searchInformation': {'searchTime': 0.205694, 'formattedSearchTime': '0.21', 'totalResults': '5600000', 'formattedTotalResults': '5,600,000'}, 'items': [{'kind': 'customsearch#result', 'title': 'Pipe and Profile Extrusion', 'htmlTitle': 'Pipe and <b>Profile Extrusion</b>', 'link': 'https://magazines.amiplastics.com/pipe-and-profile-extrusion', 'displayLink': 'magazines.amiplastics.com', 'snippet': 'Aimed at producers of plastics pipes and profiles, Pipe and Profile Extrusion magazine covers developments in polymers, additives, extruders and ancillary\xa0...', 'htmlSnippet': 'Aimed at producers of <b>plastics</b> pipes and <b>profiles</b>, Pipe and <b>Profile Extrusion</b> magazine covers developments in polymers, additives, <b>extruders</b> and ancillary&nbsp;...', 'formattedUrl': 'https://magazines.amiplastics.com/pipe-and-profile-extrusion', 'htmlFormattedUrl': 'https://magazines.ami<b>plastic</b>s.com/pipe-and-<b>profile</b>-extrusion', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ0cLaYa5an410cW7BF4tISrIM2OnfALAppV1M4564UJpDkhZQCOt3cVWY&s', 'width': '427', 'height': '118'}], 'metatags': [{'og:image': 'https://amiwebsite.blob.core.windows.net/ami-strapi-assets/uploads/Pipe_and_Profile_Magazine_Logo_2223f1c1ff.svg', 'og:type': 'article', 'twitter:card': 'summary_large_image', 'twitter:title': 'Pipe and Profile Extrusion', 'viewport': 'initial-scale=1.0, maximum-scale=1.0, width=device-width', 'twitter:description': 'Aimed at producers of plastics pipes and profiles, Pipe and Profile Extrusion magazine covers developments in polymers, additives, extruders and ancillary equipment, as well as the latest standards, testing procedures, and market trends.', 'og:title': 'Pipe and Profile Extrusion', 'og:url': 'https://magazines.amiplastics.com/pipe-and-profile-extrusion', 'og:description': 'Aimed at producers of plastics pipes and profiles, Pipe and Profile Extrusion magazine covers developments in polymers, additives, extruders and ancillary equipment, as well as the latest standards, testing procedures, and market trends.', 'twitter:image': 'https://amiwebsite.blob.core.windows.net/ami-strapi-assets/uploads/Pipe_and_Profile_Magazine_Logo_2223f1c1ff.svg'}], 'cse_image': [{'src': 'https://amiwebsite.blob.core.windows.net/ami-strapi-assets/uploads/Pipe_and_Profile_Magazine_Logo_2223f1c1ff.svg'}]}}, {'kind': ' ...
# {'kind': 'customsearch#search', 'url': {'type': 'application/json', 'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'}, 'queries': {'previousPage': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 61, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'request': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 71, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'nextPage': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 81, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}]}, 'context': {'title': 'ASCEND-SE'}, 'searchInformation': {'searchTime': 0.246533, 'formattedSearchTime': '0.25', 'totalResults': '5600000', 'formattedTotalResults': '5,600,000'}, 'items': [{'kind': 'customsearch#result', 'title': 'Plastic Extrusion 101: Definition, Advantages, How it Works, Types ...', 'htmlTitle': '<b>Plastic Extrusion</b> 101: Definition, Advantages, How it Works, Types ...', 'link': 'https://www.worthyhardware.com/news/extrusion/plastic-extrusion/', 'displayLink': 'www.worthyhardware.com', 'snippet': 'Jun 13, 2023 ... High Efficiency: The extrusion process of plastics is a continuous operation, capable of producing long lengths of a product in a relatively\xa0...', 'htmlSnippet': 'Jun 13, 2023 <b>...</b> High Efficiency: The <b>extrusion</b> process of <b>plastics</b> is a continuous operation, capable of producing long lengths of a product in a relatively&nbsp;...', 'formattedUrl': 'https://www.worthyhardware.com/news/extrusion/plastic-extrusion/', 'htmlFormattedUrl': 'https://www.worthyhardware.com/news/extrusion/<b>plastic</b>-extrusion/', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRn9mSw3P8vjSMd-zRxU8MisqQqnw04VXupmfQQ9gTJcx2nN5ISDFglMjmb&s', 'width': '292', 'height': '173'}], 'metatags': [{'og:image': 'https://www.worthyhardware.com/wp-content/uploads/2023/06/Plastic-Extrusion-2.jpg', 'og:type': 'article', 'article:published_time': '2023-06-13T05:11:25+00:00', 'og:image:width': '427', 'twitter:card': 'summary_large_image', 'og:site_name': 'Worthy Hardware', 'author': 'Worthy Hardware', 'og:title': 'Plastic Extrusion 101: Definition, Advantages, How it Works, Types, Applications | CNC Precision Machining Service', 'og:image:height': '253', 'twitter:label1': 'Written by', 'twitter:label2': 'Est. reading time', 'og:image:type': 'image/jpeg', 'og:description': 'Worthy Hardware is a Precision CNC Machining Parts and Sheet Metal Fabrication vendor for 100+ material with free samples in global shipping. Get it now!', 'twitter:data1': 'Worthy Hardware', 'twitter:data2': '11 minutes', 'article:modified_time': '2023-06-30T02:21:58+00:00', 'viewport': 'width=device-width, initial-scale=1, maximum-scale=1', 'og:locale': 'en_US', 'og:url': 'https://www.worthyhardware.com/news/extrusion/plastic-extrusion/'}], 'cse_image': [{'src': 'https://www.worthyhardware.com/wp-content/uploads/2023/06/Plastic-Extrusion-2.jpg'}]}}, {'kind' ...
# {'kind': 'customsearch#search', 'url': {'type': 'application/json', 'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'}, 'queries': {'previousPage': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 71, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'request': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 81, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'nextPage': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 10, 'startIndex': 91, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}]}, 'context': {'title': 'ASCEND-SE'}, 'searchInformation': {'searchTime': 0.202068, 'formattedSearchTime': '0.20', 'totalResults': '5600000', 'formattedTotalResults': '5,600,000'}, 'items': [{'kind': 'customsearch#result', 'title': 'Plastic Extrusion Explained | Fictiv', 'htmlTitle': '<b>Plastic Extrusion</b> Explained | Fictiv', 'link': 'https://www.fictiv.com/articles/plastic-extrusion-explained', 'displayLink': 'www.fictiv.com', 'snippet': 'May 31, 2023 ... The Plastic Extrusion Process. During the plastic extrusion process, the thermoplastic raw material is fed into the extruder through a top-\xa0...', 'htmlSnippet': 'May 31, 2023 <b>...</b> The <b>Plastic Extrusion</b> Process. During the <b>plastic extrusion</b> process, the thermoplastic raw material is fed into the <b>extruder</b> through a top-&nbsp;...', 'formattedUrl': 'https://www.fictiv.com/articles/plastic-extrusion-explained', 'htmlFormattedUrl': 'https://www.fictiv.com/articles/<b>plastic</b>-extrusion-explained', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS1cCiSTkhqHVO7xyoy_IAzWk_nt9vyISEJ9XSSXDNNR0aHanosYgBUhG4&s', 'width': '275', 'height': '183'}], 'metatags': [{'og:image': 'https://www.fictiv.com/wp-content/uploads/2023/05/Plastic-extrusions.jpg', 'twitter:card': 'summary_large_image', 'twitter:title': 'Plastic Extrusion Explained | Fictiv', 'og:type': 'article', 'og:site_name': 'Fictiv', 'og:image:url': 'https://www.fictiv.com/wp-content/uploads/2023/05/Plastic-extrusions.jpg', 'twitter:url': 'https://www.fictiv.com/articles/plastic-extrusion-explained', 'author': 'Steve Melito', 'og:title': 'Plastic Extrusion Explained | Fictiv', 'twitter:label1': 'Est. reading time', 'og:description': 'Plastic extrusion is the process of melting plastic into a mold through an extruder to create a plastic part. Learn more about it here.', 'twitter:image': 'https://www.fictiv.com/wp-content/uploads/2023/05/Plastic-extrusions.jpg', 'twitter:data1': '10 minutes', 'og:image:secure_url': 'https://www.fictiv.com/wp-content/uploads/2023/05/Plastic-extrusions.jpg', 'article:publisher': 'https://www.facebook.com/fictivmade/', 'referrer': 'no-referrer-when-downgrade', 'twitter:site': '@fictiv', 'viewport': 'width=device-width, initial-scale=1.0', 'twitter:description': 'Plastic extrusion is the process of melting plastic into a mold through an extruder to create a plastic part. Learn more abou ...
# {'kind': 'customsearch#search', 'url': {'type': 'application/json', 'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'}, 'queries': {'previousPage': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 9, 'startIndex': 82, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'request': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 9, 'startIndex': 91, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'nextPage': [{'title': 'Google Custom Search - Plastic Profile Extruders', 'totalResults': '5600000', 'searchTerms': 'Plastic Profile Extruders', 'count': 9, 'startIndex': 100, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}]}, 'context': {'title': 'ASCEND-SE'}, 'searchInformation': {'searchTime': 0.288217, 'formattedSearchTime': '0.29', 'totalResults': '5600000', 'formattedTotalResults': '5,600,000'}, 'items': [{'kind': 'customsearch#result', 'title': 'Extruded Plastic Profiles at Best Price in India', 'htmlTitle': '<b>Extruded Plastic Profiles</b> at Best Price in India', 'link': 'https://dir.indiamart.com/impcat/extruded-plastic-profiles.html', 'displayLink': 'dir.indiamart.com', 'snippet': 'PVC Co-Extruded Profile ... A wide range of PVC Co-extruded Profile is provided to our clients in various specifications.Co-Extruded from premium quality raw\xa0...', 'htmlSnippet': '<b>PVC</b> Co-<b>Extruded Profile</b> ... A wide range of <b>PVC</b> Co-<b>extruded Profile</b> is provided to our clients in various specifications.Co-<b>Extruded</b> from premium quality raw&nbsp;...', 'formattedUrl': 'https://dir.indiamart.com/impcat/extruded-plastic-profiles.html', 'htmlFormattedUrl': 'https://dir.indiamart.com/impcat/extruded-<b>plastic</b>-<b>profile</b>s.html', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR_zcbX4zxRknMBIXREDFoCiYnKa7Mmveyr1Udpw-dTmLDeOLMrrjXY3TE&s', 'width': '225', 'height': '225'}], 'metatags': [{'og:image': 'https://3.imimg.com/data3/TH/KM/GLADMIN-28150/extruded-plastic-profiles-250x250.jpg', 'og:image:width': '250', 'og:type': 'website', 'twitter:card': 'summary', 'twitter:title': 'Extruded Plastic Profiles at Best Price in India', 'theme-color': '#00a699', 'og:site_name': 'IndiaMART', 'og:image:url': 'https://3.imimg.com/data3/TH/KM/GLADMIN-28150/extruded-plastic-profiles-250x250.jpg', 'twitter:url': 'https://m.indiamart.com/impcat/extruded-plastic-profiles.html', 'og:title': 'Extruded Plastic Profiles at Best Price in India', 'og:image:height': '250', 'twitter:image:height': '250', 'og:description': 'Find here online price details of companies selling Extruded Plastic Profiles. Get info of suppliers, manufacturers, exporters, traders of Extruded Plastic Profiles for buying in India.', 'twitter:image:src': 'https://3.imimg.com/data3/TH/KM/GLADMIN-28150/extruded-plastic-profiles-250x250.jpg', 'referrer': 'always', 'twitter:site': '@IndiaMART', 'twitter:image:width': '250', 'viewport': 'width=device-width, initial-scale=1', 'twitter:description': 'Find here online price details of companies selling Extruded Plastic Profiles. Get info of suppliers, man ...
# --> Finished Crawling for Plastic Profile Extruders term at: 2024-06-18 17:01:22
#
# Completed web crawling and started web scrapping.
#
# --> Current Working Directory: /home/ec2-user/SageMaker/AscendNotebook/WebScrappingCode
# Directory 'Plastic_Profile_Extruders' created.
# URL counter to scrap data:  1
# Title: Profile Plastics, Inc.: Custom Plastic Extrusions
# Snippet: Founded in 1993, Profile Plastics has offered custom plastic extrusions in Northeast Ohio for nearly 30 years.
# Company URL: https://www.profileplastics.com
# Company Name: Profileplastics
# Original URL: https://www.profileplastics.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.profileplastics.com/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  2
# Title: Plastic Extrusions - SeaGate Plastics Company
# Snippet: Simply put, plastic extrusion is a high-volume manufacturing process in which raw plastic material is melted and formed into a continuous profile. The ...
# Company URL: https://www.seagateplastics.com
# Company Name: Seagateplastics
# Original URL: https://www.seagateplastics.com/plastic-extrusions/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.seagateplastics.com/plastic-extrusions/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  3
# Title: Custom Plastic Profile Extrusion - Plastic Extruder
# Snippet: Lakeland Plastics has been in the custom extrusion business since 1962 delivering unsurpassed quality and value. We provide necessary plastic extrusion ...
# Company URL: https://lakelandplastics.com
# Company Name: Lakelandplastics
# Original URL: https://lakelandplastics.com/custom-plastic-extrusion/plastic-profile-extrusion/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://lakelandplastics.com/custom-plastic-extrusion/plastic-profile-extrusion/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  4
# Title: Extruded profiles and machined profiles | Röchling EN
# Snippet: Our state-of-the-art extrusion systems can be used to create complex geometries for you that cannot be made by machining. Depending on cross-profile, the ...
# Company URL: https://www.roechling.com
# Company Name: Roechling
# Original URL: https://www.roechling.com/industrial/products/thermoplastics-machined-components/profiles
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  5
# Title: Custom Plastic Extrusion - Profiles and Shapes
# Snippet: Lakeland Plastics is one of America's premier Plastic Extrusion Companies specializing in top quality, precisely engineered custom plastic extrusion for ...
# Company URL: https://lakelandplastics.com
# Company Name: Lakelandplastics
# Original URL: https://lakelandplastics.com/custom-plastic-extrusion/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://lakelandplastics.com/custom-plastic-extrusion/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  6
# Title: Extruded Plastic | Plastic Extrusions | Plastic Profiles
# Snippet: Profile Extrusion. Plastic profiles are produced through a process by which various plastic materials are used to develop quality plastic products. These ...
# Company URL: https://www.lomont.com
# Company Name: Lomont
# Original URL: https://www.lomont.com/extrusion
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  7
# Title: What Is Profile Extrusion, and How Is It Different from Other Extrusion ...
# Snippet: Jun 2, 2022 ... Profile extrusion is the process of creating continuous shapes of plastic through extrusion. This process does not include forming sheet or film ...
# Company URL: https://plastrac.com
# Company Name: Plastrac
# Original URL: https://plastrac.com/what-is-profile-extrusion-and-how-is-it-different-from-other-extrusion-methods/
# The text does not contain '.pdf'. Therefore extracting data from URL
# An error occurred: HTTPSConnectionPool(host='plastrac.com', port=443): Max retries exceeded with url: /what-is-profile-extrusion-and-how-is-it-different-from-other-extrusion-methods/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb0a5c7baf0>, 'Connection to plastrac.com timed out. (connect timeout=30)'))
# --> Failed to fetch full content.
#
# URL counter to scrap data:  8
# Title: Plastic Extrusion Manufacturers | Plastic Extrusion Supplier
# Snippet: Petro Extrusion Technologies, Inc. is a premier provider of plastic extrusions. Our team is committed to providing high-quality products, exceptional services, ...
# Company URL: https://www.extrudedplastics.com
# Company Name: Extrudedplastics
# Original URL: https://www.extrudedplastics.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  9
# Title: Profile Extrusion | Gemini Group
# Snippet: Gemini Group has developed over 5000 extrusion profiles and millions of plastic extrusions. Yep, we're just about everywhere.
# Company URL: https://geminigroup.net
# Company Name: Geminigroup
# Original URL: https://geminigroup.net/plastics/profile-extrusion-gpi-sp/
# The text does not contain '.pdf'. Therefore extracting data from URL
# An error occurred: HTTPSConnectionPool(host='geminigroup.net', port=443): Max retries exceeded with url: /plastics/profile-extrusion-gpi-sp/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb0a5c60b20>, 'Connection to geminigroup.net timed out. (connect timeout=30)'))
# --> Failed to fetch full content.
#
# URL counter to scrap data:  10
# Title: Plastic Extrusion Manufacturer Company in Sheboygan, WI
# Snippet: Established in 1953, Northland Plastics has been serving the diverse plastic extrusion needs of our customers for more than 65 years. We understand the deep ...
# Company URL: https://www.northlandplastics.com
# Company Name: Northlandplastics
# Original URL: https://www.northlandplastics.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  11
# Title: Plastic Profile Extrusion｜Custom Profile
# Snippet: Custom Profile is an employee-owned company that develops and manufactures thermoplastic profile extrusions and sub-assemblies. We have the capacity to handle ...
# Company URL: https://www.custom-profile.com
# Company Name: Custom
# Original URL: https://www.custom-profile.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# An error occurred: HTTPSConnectionPool(host='www.custom-profile.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb0a59eabc0>, 'Connection to www.custom-profile.com timed out. (connect timeout=30)'))
# --> Failed to fetch full content.
#
# URL counter to scrap data:  12
# Title: Custom Plastic Profile Extrusion Design | Plastic Extruders
# Snippet: As a leading manufacturer of custom plastic profile extrusions for a variety of industries, we specialize in catering to your specific needs while finding an ...
# Company URL: https://www.sfrindustries.com
# Company Name: Sfrindustries
# Original URL: https://www.sfrindustries.com/design_assistance.phtml
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  13
# Title: Plastic Extrusion Profiles | Extruded Plastic | Thermoplastic Extrusion ...
# ...
# Company URL: https://www.worthyhardware.com
# Company Name: Worthyhardware
# Original URL: https://www.worthyhardware.com/news/extrusion/plastic-extrusion/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  72
# Title: Custom Plastic Profile Extrusion - BD Custom
# Snippet: Plastic Profile Extrusion. The extrusion process is used to form plastic materials into specific profiles. These extruded profiles may be the product, or the ...
# Company URL: https://bdcustommfg.com
# Company Name: Bdcustommfg
# Original URL: https://bdcustommfg.com/plastic-profile-extrusion/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://bdcustommfg.com/plastic-profile-extrusion/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  73
# Title: Omega Plastics: Custom Plastic Extrusions & Profiles
# Snippet: Omega Plastics specializes in providing custom plastic extrusions & profile for any application including thermoplastic & plastic extrusion profiles!
# Company URL: https://www.omegaplastics.com
# Company Name: Omegaplastics
# Original URL: https://www.omegaplastics.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  74
# Title: Uses Of Plastics Extrusions • Paul Murphy Plastics
# Snippet: Sep 18, 2019 ... Plastics extrusion is a high volume manufacturing process that melts and forms raw plastic material into a continuous profile.
# Company URL: https://paulmurphyplastics.com
# Company Name: Paulmurphyplastics
# Original URL: https://paulmurphyplastics.com/2019/09/18/uses-of-plastics-extrusions-2/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://paulmurphyplastics.com/2019/09/18/uses-of-plastics-extrusions-2/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  75
# Title: extrunet.at: Home
# Snippet: Our customers produce plastic profiles (windows, window sills, panels, technical profiles,…) ... plastics profile extrusion that has not been seen for years. Dr.- ...
# Company URL: https://www.extrunet.com
# Company Name: Extrunet
# Original URL: https://www.extrunet.com/en/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  76
# Title: Profile Plastic Extrusions: PPExtrusions
# Snippet: With a strong commitment to innovation, reliability, and customer satisfaction, we have established ourselves as a leading provider of customized extruded ...
# Company URL: https://ppextrusions.com.au
# Company Name: Ppextrusions
# Original URL: https://ppextrusions.com.au/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  77
# Title: Plastic profile extrusion production line – Zhangjiagang Beierman ...
# Snippet: PVC profile production line includes conical twin screw extruder, vacuum forming table, haul off machine, cutting machine and profile stacker. PVC profile ...
# Company URL: https://www.beiermanplas.com
# Company Name: Beiermanplas
# Original URL: https://www.beiermanplas.com/products/plastic-profile-extrusion-production-line/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  78
# Title: Extrusion: Pipe & Profile recent news | Plastics Today
# Snippet: Explore the latest news and expert commentary on Extrusion: Pipe & Profile, brought to you by the editors of Plastics Today.
# Company URL: https://www.plasticstoday.com
# Company Name: Plasticstoday
# Original URL: https://www.plasticstoday.com/plastics-processing/extrusion-pipe-profile
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  79
# Title: Custom Plastic Extrusions | Profiles & Seals | Ultrafab, Inc.
# Snippet: At the leading edge in its vision and technology, Ultrafab, Inc., is a premier manufacturer of pile and extruded weatherstripping products for the window and ...
# Company URL: https://www.ultrafab.com
# Company Name: Ultrafab
# Original URL: https://www.ultrafab.com/product/custom-extrusions/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  80
# Title: Used Plastic Extrusion Machines For Sale | Used Extruder
# Snippet: Browse Used Plastic Extrusion Machines For Sale. PlastiWin specializes in selling and buying used extruder or plastic extruders machine inventory.
# Company URL: https://plastiwin.com
# Company Name: Plastiwin
# Original URL: https://plastiwin.com/buy-used-plastic-processing-equipment/used-plastic/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  81
# Title: Plastic Extrusion Explained | Fictiv
# Snippet: May 31, 2023 ... The Plastic Extrusion Process. During the plastic extrusion process, the thermoplastic raw material is fed into the extruder through a top- ...
# Company URL: https://www.fictiv.com
# Company Name: Fictiv
# Original URL: https://www.fictiv.com/articles/plastic-extrusion-explained
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.fictiv.com/articles/plastic-extrusion-explained
# --> Failed to fetch full content.
#
# URL counter to scrap data:  82
# Title: Downstream Plastic Extrusion Machines - RDN Manufacturing Co., Inc.
# Snippet: Downstream Plastic Extrusion Machines · At RDN Manufacturing, we specialize in post-extrusion equipment manufacturing. · These machines process and finish ...
# Company URL: https://www.rdnmfg.com
# Company Name: Rdnmfg
# Original URL: https://www.rdnmfg.com/products-downstream-extrusion-equipment/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.rdnmfg.com/products-downstream-extrusion-equipment/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  83
# Title: Plastic Extrusion: A Complete Guide to Know Its Process - WayKen
# Snippet: Aug 20, 2022 ... Plastic extrusion is a high-volume manufacturing process that involves the homogenous melting of a thermoplastic material. This melted material ...
# Company URL: https://waykenrm.com
# Company Name: Waykenrm
# Original URL: https://waykenrm.com/blogs/plastic-extrusion-process/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  84
# Title: 2024 Plastic Extruder - Zhangjiagang Yatong Machinery Co., Ltd ...
# Snippet: China Plastic Extruder, Yatong Conical Double Screw Extruder for PVC Pipe,Yatong Sjsz80 Conical Double Screw Extruder by China manufacturer – Zhangjiagang ...
# Company URL: https://yatongmachine.en.made-in-china.com
# Company Name: Yatongmachine
# Original URL: https://yatongmachine.en.made-in-china.com/product-group/vMemcnxVarRj/Plastic-Extruder-catalog-1.html
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 493 Client Error:  for url: https://yatongmachine.en.made-in-china.com/product-group/vMemcnxVarRj/Plastic-Extruder-catalog-1.html
# --> Failed to fetch full content.
#
# URL counter to scrap data:  85
# Title: Custom Plastic Extrusions | Cooper Standard
# Snippet: Review concepts that can be applied to effectively design extruded plastic profiles. Download. Sealing Design Guide. Improve your next seal or gasket design by ...
# Company URL: https://www.cooperstandard.com
# Company Name: Cooperstandard
# Original URL: https://www.cooperstandard.com/custom-plastic-extrusions
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  86
# Title: GSH Industries: Custom Plastic, Aluminum & Rubber Products ...
# Snippet: ... plastic extrusions, tubing, and plastic profiles. GSH Industries | Plastic Extrusion, Aluminum Extrusions, Rubber Extrusions | Injection Molding. Rubber ...
# Company URL: https://www.gshindustries.com
# Company Name: Gshindustries
# Original URL: https://www.gshindustries.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  87
# Title: Plastics Extrusion Machinery: PVC and Plastic Pipe Machinery
# Snippet: Plastics Extrusion Machinery LLC (PEM) is an industry-leading provider of quality downstream equipment in the PVC pipe and custom profile industries.
# Company URL: https://www.pemusa.com
# Company Name: Pemusa
# Original URL: https://www.pemusa.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  88
# Title: UHMW Extrusion Profiles Garland Manufacturing
# Snippet: UHMW Plastics / Profile Extrusions. GAR-DUR® UHMW Profile Extrusions. Made from UHMW Polymer, a material so advanced… It will outperform metal at a fraction ...
# Company URL: https://garlandmfg.com
# Company Name: Garlandmfg
# Original URL: https://garlandmfg.com/uhmw-plastics/profile-extrusions/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  89
# Title: Absolute Custom Extrusions, Inc. | Custom Plastic Extrusions
# Snippet: Absolute Custom Extrusions offers plastic extrusions such as standard plastic tubes, custom plastic tubes, plastic profiles & plastic coated wire & cable.
# Company URL: https://www.ace-extrusions.com
# Company Name: Ace
# Original URL: https://www.ace-extrusions.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  90
# Title: Plastics ERP Software for Profile Extrusion – CyFrame
# Snippet: CyFrame software is not just limited to building the “bill of materials” for profile extrusion products. Our solution covers the entire order process, tracking ...
# Company URL: https://www.cyframe.com
# Company Name: Cyframe
# Original URL: https://www.cyframe.com/profile-extrusion/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  91
# Title: Extruded Plastic Profiles at Best Price in India
# Snippet: PVC Co-Extruded Profile ... A wide range of PVC Co-extruded Profile is provided to our clients in various specifications.Co-Extruded from premium quality raw ...
# Company URL: https://dir.indiamart.com
# Company Name: Dir
# Original URL: https://dir.indiamart.com/impcat/extruded-plastic-profiles.html
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  92
# Title: Seiler Plastics | Custom Plastic Extrusion and Custom ...
# Snippet: Seiler Plastics Corporation manufactures custom plastic extrusions and plastic sheet products including plastic profiles, plastic tubes, and thermoformed .
# Company URL: https://www.seilerpc.com
# Company Name: Seilerpc
# Original URL: https://www.seilerpc.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.seilerpc.com/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  93
# Title: Sj45 Sj50 Sj25 Single Screw Co-Extrusion Supermarket PVC Plastic ...
# Snippet: Product Details · 1. we usually use SJ45, SJ50, SJ25 as main extruder. · 2. ABB/DELTA frequency inverter · 3. Siemens Beide Motor · 4. Omron temperature control
# Company URL: https://zjgfld.en.made-in-china.com
# Company Name: Zjgfld
# Original URL: https://zjgfld.en.made-in-china.com/product/omqUujilfNcB/China-Sj45-Sj50-Sj25-Single-Screw-Co-Extrusion-Supermarket-PVC-Plastic-Profile-Price-Data-Strip-Tag-Holder-Extruder-Machine-Production-Line.html
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 493 Client Error:  for url: https://zjgfld.en.made-in-china.com/product/omqUujilfNcB/China-Sj45-Sj50-Sj25-Single-Screw-Co-Extrusion-Supermarket-PVC-Plastic-Profile-Price-Data-Strip-Tag-Holder-Extruder-Machine-Production-Line.html
# --> Failed to fetch full content.
#
# URL counter to scrap data:  94
# Title: Plastic Extrusion // MagnaPlas
# Snippet: Plastic Extrusion ... The Magna Plas Victoria Manufacturing site contains onsite extruders that allow us to produce high quality plastic extruded rod and plastic ...
# Company URL: https://www.magnaplastics.com.au
# Company Name: Magnaplastics
# Original URL: https://www.magnaplastics.com.au/Custom-Services/Plastic-Extrusion/394
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  95
# Title: Reeves Extruded Products: Custom Plastic Profiles USA
# Snippet: At Reeves, we specialize in creating custom plastic profiles and shapes that meet the unique needs of our customers. Utilizing advanced extrusion techniques, we ...
# Company URL: https://www.reevesextruded.com
# Company Name: Reevesextruded
# Original URL: https://www.reevesextruded.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# An error occurred: HTTPSConnectionPool(host='www.reevesextruded.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fb0a56c7bb0>, 'Connection to www.reevesextruded.com timed out. (connect timeout=30)'))
# --> Failed to fetch full content.
#
# URL counter to scrap data:  96
# Title: Plastics | Custom Profile Extrusion | Eaton
# Snippet: Eaton Plastic Extrusion serves the automotive, recreational vehicle and watercraft industries by offering innovative solutions such as: Weather & UV resistance, ...
# Company URL: https://www.eaton.com
# Company Name: Eaton
# Original URL: https://www.eaton.com/us/en-us/catalog/plastics/custom-profile-extrusion.html
# The text does not contain '.pdf'. Therefore extracting data from URL
# An error occurred: HTTPSConnectionPool(host='www.eaton.com', port=443): Read timed out. (read timeout=30)
# --> Failed to fetch full content.
#
# URL counter to scrap data:  97
# Title: Pixargus: Inline quality control for extrusion lines
# Snippet: The new downsized solution for optical defect detection in the extrusion of rubber and plastic profiles. Read more. Inline quality control for extruded products
# Company URL: https://www.pixargus.com
# Company Name: Pixargus
# Original URL: https://www.pixargus.com/home/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  98
# Title: Extrusion Machines: Customizable, High-Performance Solutions ...
# Snippet: Side profile of Milacron's MPH PVC die head for plastic extrusion machines. Downloads · Single Screw. Milacron Single Screw Extruders ... Extruders are quality ...
# Company URL: https://www.milacron.com
# Company Name: Milacron
# Original URL: https://www.milacron.com/product-types/extrusion-machines/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.milacron.com/product-types/extrusion-machines/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  99
# Title: Plastic Profiles
# Snippet: Ram extruded ultra low friction dry lubricated UHMW-PE (NS). Nolu-S extrusions are a proprietary blend of UHMW-PE and solid lubricants.
# Company URL: https://www.regalrexnord.com
# Company Name: Regalrexnord
# Original URL: https://www.regalrexnord.com/products/conveyor-technologies/guide-products/plastic-profiles
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.regalrexnord.com/products/conveyor-technologies/guide-products/plastic-profiles
# --> Failed to fetch full content.
#
# --> Current Working Directory: /home/ec2-user/SageMaker/AscendNotebook/WebScrappingCode
# Completed web scrapping.
#
# --> Current Working Directory: /home/ec2-user/SageMaker/AscendNotebook/WebScrappingCode
# ================================================================
