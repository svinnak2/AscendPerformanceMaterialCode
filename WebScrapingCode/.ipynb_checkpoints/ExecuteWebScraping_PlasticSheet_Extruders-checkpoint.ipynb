# %%
""" This file search the google web based on search term provided and scraps 99 websites from the web.

Very Important:
    1) Make sure to execute the required libraries by either commenting/uncommenting pip
    2) Make sure to use the right API Key for the GOOGLE_CS_API_KEY variable.

"""
# Out:
# ' This file search the google web based on search term provided and scraps 99 websites from the web.\n\nVery Important:\n    1) Make sure to execute the required libraries by either commenting/uncommenting pip\n    2) Make sure to use the right API Key for the GOOGLE_CS_API_KEY variable.\n\n'

# %%
# pip install -r "/home/ec2-user/SageMaker/AscendNotebook/ascendrequirements.txt"

# %%
# Import os module for interacting with the operating system
import os

# Import pandas as pd for data manipulation and analysis
import pandas as pd

from TimeMethods import get_Date, get_DateTime, Time

from WebScraping import (search_term_directory, crawl_search_term, scrap_websites)

# %%
# Define the following NUM_RESULTS variable to determine the number of web search results to crawl for scrapping
NUM_RESULTS = 99

# Exclude Wikipedia, Reddit, and LinkedIn from search results
# exclude_sites = 'site:en.wikipedia.org OR site:reddit.com OR site:linkedin.com'

MY_API_KEY = 'XXXXXXXX' # This Sai Vinnakota personal Google API keys
# TIOT_API_KEY = 'XXXXXXXX' #'XXXXXXXX' # This is TensorIOT Google API Keys
MY_CSE_ID = 'XXXXXXXX' #'XXXXXXXX' # Replace this with the client Search Engine ID
GOOGLE_CS_API_KEY = MY_API_KEY

# Get the working directory
wrk_dir = os.getcwd()
print(f"Current working directory \"{wrk_dir}\".")

# Initialize Root Directory
ROOT_DIR = "/home/ec2-user/SageMaker/AscendNotebook/"
print(f"Root directory \"{ROOT_DIR}\".")

# Initialize directory to save results
Rslts_Save_Dir = "/home/ec2-user/SageMaker/AscendNotebook/CodeExecutionMetrics/"
print(f"Directory to save scrapping results \"{Rslts_Save_Dir}\".")
# Out:
# Current working directory "/home/ec2-user/SageMaker/AscendNotebook/WebScrappingCode".
# Root directory "/home/ec2-user/SageMaker/AscendNotebook/".
# Directory to save scrapping results "/home/ec2-user/SageMaker/AscendNotebook/Results_Saved/".

# %% [markdown]
# # Use the right Google Custom Search API Key

# %%
GOOGLE_CS_API_KEY = MY_API_KEY

# %% [markdown]
# # Chose the appropriate search term

# %%
# MY_SEARCH = "Nylon & Polyamide injection molders"
# MY_SEARCH = "Plastic Profile Extruders"
MY_SEARCH = "Plastic Sheet extruders"
# MY_SEARCH = "Recycled carpet fibers applications"
# MY_SEARCH = "Nylon Compounders & Polyamide Compounders"

# MY_SEARCHES = ["Nylon & Polyamide injection molders", "Plastic Profile Extruders", "Plastic Sheet extruders", "Recycled carpet fibers applications", "Nylon Compounders & Polyamide Compounders"]

# %%
Crawl_scrap_processing_status = pd.DataFrame(columns = ['Search Term','Number of Results Crawled', 'Crawl Start Time', 
                                           'Crawl End Time', 'Crawl Exec Time in Minutes'])

print(f"Performing Google search for \"{MY_SEARCH}\".")
print("================================================================")
print(" ")

# Define search term directory to save web scrapping results
SEARCH_TERM_DIR = search_term_directory(MY_SEARCH)

print(f"--> Search Term directory that will be used to save results is: \"{SEARCH_TERM_DIR}\".")

# Crawl the web to get results
Crawl_process_stats, results = crawl_search_term(MY_SEARCH, GOOGLE_CS_API_KEY, MY_CSE_ID, NUM_RESULTS)

print("Completed web crawling and started web scrapping.")
print(" ")

Metadata_DF_Final = scrap_websites(results, MY_SEARCH, ROOT_DIR, SEARCH_TERM_DIR, wrk_dir, get_Date())

print("Completed web scrapping.")
print(" ")

# Saving search results summary to a csv file
print("--> Current Working Directory:", os.getcwd())
Metadata_DF_Final.to_csv(Rslts_Save_Dir + "/" + SEARCH_TERM_DIR +"_"+ get_DateTime() + '.csv', index=False)

print("================================================================")
print(" ")

# Append the row
Crawl_scrap_processing_status.loc[len(Crawl_scrap_processing_status)] = Crawl_process_stats

Crawl_scrap_processing_status.to_csv(Rslts_Save_Dir + "/" + MY_SEARCH +"WebScrap_ProcessTime_"+ get_DateTime() + '.csv', index=False)
# Out:
# Performing Google search for "Plastic Sheet extruders".
# ================================================================
#
# --> Search Term directory that will be used to save results is: "Plastic_Sheet_Extruders".
# --> Starting Crawling for Plastic Sheet extruders term at: 2024-06-18 17:26:05
# 99
# {'kind': 'customsearch#search', 'url': {'type': 'application/json', 'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'}, 'queries': {'request': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 1, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'nextPage': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 11, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}]}, 'context': {'title': 'ASCEND-SE'}, 'searchInformation': {'searchTime': 0.261484, 'formattedSearchTime': '0.26', 'totalResults': '5770000', 'formattedTotalResults': '5,770,000'}, 'items': [{'kind': 'customsearch#result', 'title': 'Extruded Plastic Sheet and Plastic Roll | Primex', 'htmlTitle': '<b>Extruded Plastic Sheet</b> and <b>Plastic</b> Roll | Primex', 'link': 'https://www.primexplastics.com/extruded-plastic-sheet-roll-stock/', 'displayLink': 'www.primexplastics.com', 'snippet': "As one of the world's leading plastic sheet extruders, Primex delivers custom sheet and roll solutions made to the highest standards.", 'htmlSnippet': 'As one of the world&#39;s leading <b>plastic sheet extruders</b>, Primex delivers custom sheet and roll solutions made to the highest standards.', 'formattedUrl': 'https://www.primexplastics.com/extruded-plastic-sheet-roll-stock/', 'htmlFormattedUrl': 'https://www.primex<b>plastic</b>s.com/extruded-<b>plastic</b>-<b>sheet</b>-roll-stock/', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRSbydHwU3rbTQyLSBghf2qufbJSPqMMNpOxTB-1HfItoVtn7R42veK8Kwu&s', 'width': '300', 'height': '168'}], 'metatags': [{'og:image': 'https://www.primexplastics.com/wp-content/uploads/pellet-piles.jpg', 'theme-color': '#030922', 'og:type': 'article', 'og:image:width': '870', 'twitter:card': 'summary_large_image', 'og:site_name': 'Primex Plastics', 'og:title': 'Extruded Plastic Sheet and Plastic Roll | Primex', 'og:image:height': '489', 'og:image:type': 'image/jpeg', 'og:description': 'As one of the world’s leading plastic sheet extruders, Primex delivers custom sheet and roll solutions made to the highest standards.', 'article:modified_time': '2023-05-19T12:48:07+00:00', 'viewport': 'width=device-width, initial-scale=1', 'og:locale': 'en_US', 'og:url': 'https://www.primexplastics.com/extruded-plastic-sheet-roll-stock/'}], 'cse_image': [{'src': 'https://www.primexplastics.com/wp-content/uploads/pellet-piles.jpg'}]}}, {'kind': 'customsearch#result', 'title': 'Plastic Sheet Extrusion - Allied Plastics', 'htmlTitle': '<b>Plastic Sheet Extrusion</b> - Allied Plastics', 'link': 'https://alliedplastics.com/services/plastic-extrusion/', 'displayLink': 'alliedplastics.com', 'snippet': 'Allied Plastics is a full-service Custom Sheet Extruder with sheet size capability up to 120” wide x 200” long and .060” to .550” thick. Our team has experience\xa0...', 'htmlSnippet': 'Allied <b>Plastics</b> is a full-service Custom <b>Sheet Extruder</b> with <b>sheet</b> size capability up to 120” wide x 200” long and .060” to .550” thick. Our team has experience&nbsp;...', 'formattedUrl': 'https://alliedplastics.com/services/plastic-extrusio ...
# {'kind': 'customsearch#search', 'url': {'type': 'application/json', 'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'}, 'queries': {'previousPage': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 1, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'request': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 11, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'nextPage': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 21, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}]}, 'context': {'title': 'ASCEND-SE'}, 'searchInformation': {'searchTime': 0.148459, 'formattedSearchTime': '0.15', 'totalResults': '5770000', 'formattedTotalResults': '5,770,000'}, 'items': [{'kind': 'customsearch#result', 'title': 'Industry leaders in rigid Biobased Rollstock Film sheets and extrusion.', 'htmlTitle': 'Industry leaders in rigid Biobased Rollstock <b>Film sheets</b> and <b>extrusion</b>.', 'link': 'https://goodnaturedproducts.com/pages/bioplastic-roll-stock-extruded-sheets', 'displayLink': 'goodnaturedproducts.com', 'snippet': 'Made from multiple materials, including PCR, bioplastic Clear thermorming plastic sheets, with precise film slitting & sheeting.', 'htmlSnippet': 'Made from multiple materials, including PCR, bioplastic Clear thermorming <b>plastic sheets</b>, with precise <b>film</b> slitting &amp; <b>sheeting</b>.', 'formattedUrl': 'https://goodnaturedproducts.com/pages/bioplastic-roll-stock-extruded-sheets', 'htmlFormattedUrl': 'https://goodnaturedproducts.com/pages/bio<b>plastic</b>-roll-stock-extruded-<b>sheet</b>s', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRm1Qo_yWof8G9bEjbNrlh-FvLv6deePaVAzUFhwlh_6IvjOfDO6sUcLY6D&s', 'width': '279', 'height': '181'}], 'metatags': [{'og:image': 'http://goodnaturedproducts.com/cdn/shop/files/GN_logo_positive_b5feb362-9f41-4c49-bf87-568d87b966c6_1200x1200.png?v=1614353382', 'theme-color': '#00869f', 'og:type': 'website', 'og:image:width': '550', 'twitter:card': 'summary_large_image', 'twitter:title': 'Industry leaders in rigid Biobased Rollstock Film sheets and extrusion', 'og:site_name': 'good natured Products Inc.', 'og:title': 'Industry leaders in rigid Biobased Rollstock Film sheets and extrusion', 'og:image:height': '356', 'shopify-checkout-api-token': 'dc952accf65cbd04894f8aa919ed471e', 'og:description': 'Made from multiple materials, including PCR, bioplastic Clear thermorming plastic sheets, with precise film slitting & sheeting. Custom rigid film extruders', 'og:image:secure_url': 'https://goodnaturedproducts.com/cdn/shop/files/GN_logo_positive_b5feb362-9f41-4c49-bf87-568d87b966c6_1200x1200.png?v=1614353382', 'facebook-domain-verification': '9154mynvf2syqawlq94cqb3zcmbgb8', 'twitter:site': '@goodnatured_inc', 'viewport': 'width=device-width,initial-scale=1', 'twitter:description': 'Made from multiple materials, including PCR, bioplastic Clear thermorming plastic sheets, with preci ...
# {'kind': 'customsearch#search', 'url': {'type': 'application/json', 'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'}, 'queries': {'previousPage': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 11, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'request': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 21, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'nextPage': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 31, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}]}, 'context': {'title': 'ASCEND-SE'}, 'searchInformation': {'searchTime': 0.19494, 'formattedSearchTime': '0.19', 'totalResults': '5770000', 'formattedTotalResults': '5,770,000'}, 'items': [{'kind': 'customsearch#result', 'title': 'Plastic sheet extrusion | Primex Plastics UK | HDPE and PP Extruder', 'htmlTitle': '<b>Plastic sheet extrusion</b> | Primex Plastics UK | HDPE and PP Extruder', 'link': 'https://www.primexplastics.co.uk/extrusion', 'displayLink': 'www.primexplastics.co.uk', 'snippet': 'We have 6 lines producing HDPE, LDPE, PP and Tuff-x plastic sheet. Primex Plastic Limited has the capacity for 16,000 tonnes annually, and have the ability to\xa0...', 'htmlSnippet': 'We have 6 lines producing HDPE, LDPE, PP and Tuff-x <b>plastic sheet</b>. Primex <b>Plastic</b> Limited has the capacity for 16,000 tonnes annually, and have the ability to&nbsp;...', 'formattedUrl': 'https://www.primexplastics.co.uk/extrusion', 'htmlFormattedUrl': 'https://www.primex<b>plastic</b>s.co.uk/extrusion', 'pagemap': {'metatags': [{'og:type': 'website', 'twitter:card': 'summary_large_image', 'twitter:title': 'Plastic sheet extrusion | Primex Plastics UK | HDPE and PP Extruder', 'og:site_name': 'Primex Plastics UK', 'skype_toolbar': 'skype_toolbar_parser_compatible', 'viewport': 'width=320, user-scalable=yes', 'twitter:description': 'Primex Plastics Limited is a world leader in HDPE and Polypropylene plastic sheet extrusion.', 'og:title': 'Plastic sheet extrusion | Primex Plastics UK | HDPE and PP Extruder', 'og:url': 'https://www.primexplastics.co.uk/extrusion', 'og:description': 'Primex Plastics Limited is a world leader in HDPE and Polypropylene plastic sheet extrusion.', 'format-detection': 'telephone=no'}]}}, {'kind': 'customsearch#result', 'title': 'PTi - Sheet Extrusion System, Plastic Sheet Extrusion, Control ...', 'htmlTitle': 'PTi - Sheet Extrusion System, <b>Plastic Sheet Extrusion</b>, Control ...', 'link': 'https://www.ptiextruders.com/', 'displayLink': 'www.ptiextruders.com', 'snippet': 'PTi is a Global Leader in high performance sheet extrusion machinery. Engineered to exact standards PTi systems offer a unique array of design features\xa0...', 'htmlSnippet': 'PTi is a Global Leader in high performance <b>sheet extrusion</b> machinery. Engineered to exact standards PTi systems offer a unique array of design features&nbsp;...', 'formattedUrl': 'https://www.ptiextruders.com/', 'htmlFormattedUrl': 'https: ...
# {'kind': 'customsearch#search', 'url': {'type': 'application/json', 'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'}, 'queries': {'previousPage': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '7310000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 21, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'request': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '7310000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 31, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'nextPage': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '7310000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 41, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}]}, 'context': {'title': 'ASCEND-SE'}, 'searchInformation': {'searchTime': 0.2919, 'formattedSearchTime': '0.29', 'totalResults': '7310000', 'formattedTotalResults': '7,310,000'}, 'items': [{'kind': 'customsearch#result', 'title': 'DDS-8C EASTMAN SPECTAR Copolyester - Tips on Extrusion of ...', 'htmlTitle': 'DDS-8C EASTMAN SPECTAR Copolyester - Tips on <b>Extrusion</b> of ...', 'link': 'https://www.eastman.com/Literature_Center/D/DDS8.pdf', 'displayLink': 'www.eastman.com', 'snippet': 'Tips on extrusion of plastic sheet. Page 3. • Do not use high-shear mixers. These can cause excessive melt temperatures. • Do not use a restrictor-bar die, if\xa0...', 'htmlSnippet': 'Tips on <b>extrusion</b> of <b>plastic sheet</b>. Page 3. • Do not use high-shear mixers. These can cause excessive melt temperatures. • Do not use a restrictor-bar die, if&nbsp;...', 'formattedUrl': 'https://www.eastman.com/Literature_Center/D/DDS8.pdf', 'htmlFormattedUrl': 'https://www.eastman.com/Literature_Center/D/DDS8.pdf', 'pagemap': {'metatags': [{'moddate': "D:20120807104937-04'00'", 'creationdate': "D:20120801113634-04'00'", 'creator': 'Adobe InDesign CS5.5 (7.5)', 'gts_pdfxconformance': 'PDF/X-1a:2001', 'producer': 'Adobe PDF Library 9.9', 'title': 'DDS-8C  EASTMAN SPECTAR Copolyester - Tips on Extrusion of Plastic Sheet', 'gts_pdfxversion': 'PDF/X-1:2001'}]}, 'mime': 'application/pdf', 'fileFormat': 'PDF/Adobe Acrobat'}, {'kind': 'customsearch#result', 'title': 'PET/PLA twin-screw sheet extruder | Plastics and Rubber Product', 'htmlTitle': 'PET/PLA twin-screw <b>sheet extruder</b> | <b>Plastics</b> and Rubber Product', 'link': 'https://www.chinaplasonline.com/emp/1000739/12665', 'displayLink': 'www.chinaplasonline.com', 'snippet': 'PET/PLA twin-screw sheet extruder is using high torque gearbox, torque output and gearbox stable des…', 'htmlSnippet': 'PET/PLA twin-screw <b>sheet extruder</b> is using high torque gearbox, torque output and gearbox stable des…', 'formattedUrl': 'https://www.chinaplasonline.com/emp/1000739/12665', 'htmlFormattedUrl': 'https://www.chinaplasonline.com/emp/1000739/12665', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT6kJGMuyW5V5TpsaW7DEbWfUf7zS7dhr3UGjXqecNs-N8G0c21hA70NlA&s', 'width': '310', 'height': '163'}], 'metatags': [{'og:image': 'https://cdn.adsalecdn.com/onlineExhibitorDatabase/ShareLogo/shareLogo_en.png?ver=20220413&x-oss-process=image/resize,h ...
# {'kind': 'customsearch#search', 'url': {'type': 'application/json', 'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'}, 'queries': {'previousPage': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 31, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'request': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 41, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'nextPage': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 51, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}]}, 'context': {'title': 'ASCEND-SE'}, 'searchInformation': {'searchTime': 0.203642, 'formattedSearchTime': '0.20', 'totalResults': '5770000', 'formattedTotalResults': '5,770,000'}, 'items': [{'kind': 'customsearch#result', 'title': 'Extruded Acrylic Sheet - Simply Plastics', 'htmlTitle': '<b>Extruded Acrylic Sheet</b> - Simply <b>Plastics</b>', 'link': 'https://www.simplyplastics.com/catalog/sheet/extruded-acrylic-sheet/c-24/c-84', 'displayLink': 'www.simplyplastics.com', 'snippet': 'Extruded Acrylic Sheet. Extruded acrylic sheet is an economical yet versatile plastic sheet suitable for many applications from glazing to signage. Extruded\xa0...', 'htmlSnippet': '<b>Extruded Acrylic Sheet</b>. <b>Extruded acrylic sheet</b> is an economical yet versatile <b>plastic sheet</b> suitable for many applications from glazing to signage. <b>Extruded</b>&nbsp;...', 'formattedUrl': 'https://www.simplyplastics.com/catalog/sheet/extruded-acrylic-sheet/c.../c-8...', 'htmlFormattedUrl': 'https://www.simply<b>plastic</b>s.com/catalog/<b>sheet</b>/extruded-acrylic-<b>sheet</b>/c.../c-8...', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ0WMM3cQQ_n302LfOsvTDJQkzby9qLHaA_WjAMHhnba54feCz01_HWBfaS&s', 'width': '217', 'height': '233'}], 'metatags': [{'application-name': 'Static', 'copyright': '© 2024 Simply Plastics Ltd.', 'twitter:card': 'summary_large_image', 'twitter:title': 'Extruded Acrylic Sheet - Simply Plastics', 'og:type': 'website', 'author': '@SimplyPlastics', 'og:title': 'Extruded Acrylic Sheet - Simply Plastics', 'title': 'Extruded Acrylic Sheet - Simply Plastics', 'twitter:creator': '@SimplyPlastics', 'og:description': 'Order Cut to Size Extruded Acrylic at Simply Plastics the UK’s #1 supplier. Shop Perspex® & Plexiglas®.  Anti-Glare in Stock NOW!⚡ Express Delivery Available.', 'twitter:site': 'Simply Plastics', 'viewport': 'width=device-width, initial-scale=1', 'apple-mobile-web-app-capable': 'yes', 'twitter:description': 'Order Cut to Size Extruded Acrylic at Simply Plastics the UK’s #1 supplier. Shop Perspex® & Plexiglas®.  Anti-Glare in Stock NOW!⚡ Express Delivery Available.', 'og:locale': 'en-GB', 'og:url': 'https://www.simplyplastics.com/catalog/sheet/extruded-acrylic-sheet/c-24/c-84'}], 'cse_image': [{'src': 'https://www.simplyplastics.com/media/dzqbly4w/fabrication-services-cta.png?anchor=center&mode=crop&width=271&height=291&rnd=133324300320830000'}]}} ...
# {'kind': 'customsearch#search', 'url': {'type': 'application/json', 'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'}, 'queries': {'previousPage': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 41, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'request': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 51, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'nextPage': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 61, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}]}, 'context': {'title': 'ASCEND-SE'}, 'searchInformation': {'searchTime': 0.198021, 'formattedSearchTime': '0.20', 'totalResults': '5770000', 'formattedTotalResults': '5,770,000'}, 'items': [{'kind': 'customsearch#result', 'title': 'Plastic-Craft | Nylon Extruded Type 6/6 Sheet', 'htmlTitle': '<b>Plastic</b>-Craft | Nylon <b>Extruded</b> Type 6/6 <b>Sheet</b>', 'link': 'https://plastic-craft.com/nylon-extruded-type-6-6-sheet/', 'displayLink': 'plastic-craft.com', 'snippet': 'Extruded Nylon 6/6 Sheets have outstanding wear resistance and low frictional properties. Nylon has very good temperature, chemical, and impact properties.', 'htmlSnippet': '<b>Extruded</b> Nylon 6/6 <b>Sheets</b> have outstanding wear resistance and low frictional properties. Nylon has very good temperature, chemical, and impact properties.', 'formattedUrl': 'https://plastic-craft.com/nylon-extruded-type-6-6-sheet/', 'htmlFormattedUrl': 'https://<b>plastic</b>-craft.com/nylon-extruded-type-6-6-<b>sheet</b>/', 'pagemap': {'offer': [{'pricevaliduntil': '2025-06-15', 'pricecurrency': 'USD', 'price': '0.00', 'availability': 'http://schema.org/InStock', 'itemcondition': 'http://schema.org/Condition', 'url': 'https://plastic-craft.com/nylon-extruded-type-6-6-sheet/'}], 'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTAJ98Zx1ngW1NHEYROOrlHQBwXoMX1XlFIR9sjIXDjL54mzvzDd92MlEoV&s', 'width': '300', 'height': '168'}], 'product': [{'image': 'https://cdn11.bigcommerce.com/s-hep33asv71/images/stencil/1280x1280/products/259/807/Natural_Nylon_Sheet__51330.1632776060.png?c=1', 'name': 'Nylon Extruded Type 6/6 Sheet', 'description': 'Nylon 6/6 Sheet Description Nylon is a strong, stiff engineering plastic with outstanding bearing and wear properties. Nylon is frequently used to replace metal bearings and bushings often...', 'sku': 'NY132'}], 'metatags': [{'og:image': 'https://cdn11.bigcommerce.com/s-hep33asv71/products/259/images/807/Natural_Nylon_Sheet__51330.1632776060.386.513.png?c=1', 'og:type': 'product', 'og:site_name': 'Plastic-Craft Products', 'og:availability': 'instock', 'pinterest:richpins': 'enabled', 'viewport': 'width=device-width, initial-scale=1, maximum-scale=1', 'product:price:currency': 'USD', 'og:title': 'Nylon Extruded Type 6/6 Sheet', 'product:price:amount': '0', 'og:url': 'https://plastic-craft.com/nylon-extruded-type-6-6-sheet/', 'og:description': "Extruded Nylon 6/6 Sheets have outstanding ...
# {'kind': 'customsearch#search', 'url': {'type': 'application/json', 'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'}, 'queries': {'previousPage': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 51, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'request': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 61, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'nextPage': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 71, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}]}, 'context': {'title': 'ASCEND-SE'}, 'searchInformation': {'searchTime': 0.228848, 'formattedSearchTime': '0.23', 'totalResults': '5770000', 'formattedTotalResults': '5,770,000'}, 'items': [{'kind': 'customsearch#result', 'title': 'PLASTICS EXTRUDER DEGASSING | Edwards Vacuum', 'htmlTitle': '<b>PLASTICS EXTRUDER</b> DEGASSING | Edwards Vacuum', 'link': 'https://www.edwardsvacuum.com/content/dam/brands/edwards-vacuum/edwards-website-assets/our-markets/chemical-food-processing/documents/plastic-processing/edwards-plastics-extruder-degassing-application-note.pdf', 'displayLink': 'www.edwardsvacuum.com', 'snippet': 'Plastic items such as pipes and tubing, thermoplastic yarn, window frames, plastic films, sheet, wire and cable coating as well as polymer pellets used to\xa0...', 'htmlSnippet': '<b>Plastic</b> items such as pipes and tubing, thermoplastic yarn, window frames, <b>plastic</b> films, <b>sheet</b>, wire and cable coating as well as <b>polymer</b> pellets used to&nbsp;...', 'formattedUrl': 'https://www.edwardsvacuum.com/.../plastic.../edwards-plastics-extruder-deg...', 'htmlFormattedUrl': 'https://www.edwardsvacuum.com/.../<b>plastic</b>.../edwards-<b>plastic</b>s-extruder-deg...', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRK65sv3Psja8aeQUD9EWhiWcxG6I8nWhhcYN8nSZFilGaipbRbduils6us&s', 'width': '254', 'height': '198'}], 'metatags': [{'moddate': 'D:20230322151401Z', 'creationdate': 'D:20191022060853Z', 'creator': 'Adobe InDesign 14.0 (Windows)', 'subject': 'Application note for plastics extruder degassing for plastics industry', 'producer': 'Adobe PDF Library 15.0', 'title': 'Plastics Extruder Degassing'}], 'cse_image': [{'src': 'x-raw-image:///94cf8e1e6b1f88df251c1990729b5d9c62ce35a569609dd067d3f630953f3af2'}]}, 'mime': 'application/pdf', 'fileFormat': 'PDF/Adobe Acrobat'}, {'kind': 'customsearch#result', 'title': 'Plastic Sheet Extrusion Temperature Control | Optris', 'htmlTitle': '<b>Plastic Sheet Extrusion</b> Temperature Control | Optris', 'link': 'https://www.optris.com/en-us/industries/plastics/flat-film-and-sheet-extrusion/', 'displayLink': 'www.optris.com', 'snippet': 'Ideal tools for plastic sheet extrusion temperature control. Use Optris IR cameras to reliably detect ✓cracks and ✓surface defects.', 'htmlSnippet': 'Ideal tools for <b>plastic sheet extrusion</b> temperature control. Use Optris IR cameras to reliably detect ✓cracks and ✓ ...
# {'kind': 'customsearch#search', 'url': {'type': 'application/json', 'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'}, 'queries': {'previousPage': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 61, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'request': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 71, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'nextPage': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 81, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}]}, 'context': {'title': 'ASCEND-SE'}, 'searchInformation': {'searchTime': 0.225781, 'formattedSearchTime': '0.23', 'totalResults': '5770000', 'formattedTotalResults': '5,770,000'}, 'items': [{'kind': 'customsearch#result', 'title': 'Plastic Film Custom Extrusion and Conversion | Arlin Mfg. Co.', 'htmlTitle': '<b>Plastic Film</b> Custom <b>Extrusion</b> and Conversion | Arlin Mfg. Co.', 'link': 'https://arlinmfg.com/', 'displayLink': 'arlinmfg.com', 'snippet': 'Arlin Mfg. Co. in Lowell, MA specializes in custom extrusion and converting of plastic films.', 'htmlSnippet': 'Arlin Mfg. Co. in Lowell, MA specializes in custom <b>extrusion</b> and converting of <b>plastic</b> films.', 'formattedUrl': 'https://arlinmfg.com/', 'htmlFormattedUrl': 'https://arlinmfg.com/', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQCXsJniY8UriuGzgVe5Lc3A7oE7FmYcP4X3dMyN9RRXu66m9u54ceQHzCi&s', 'width': '242', 'height': '208'}], 'metatags': [{'og:type': 'website', 'og:site_name': 'Arlin Mfg. Co., Inc.', 'article:modified_time': '2024-06-10T15:27:07+00:00', 'viewport': 'width=device-width, initial-scale=1', 'og:title': 'Plastic Film Custom Extrusion and Conversion | Arlin Mfg. Co.', 'og:locale': 'en_US', 'og:url': 'https://arlinmfg.com/', 'og:description': 'Arlin Mfg. Co. in Lowell, MA specializes in custom extrusion and converting of plastic films.'}], 'webpage': [{'maincontentofpage': 'Custom Extrusion and Converting of Plastic Films', 'headline': 'Cookie and Privacy Settings'}], 'creativework': [{'text': 'Custom Extrusion and Converting of Plastic Films'}, {'text': 'Transforming traditional films to target unique tensile properties, optical properties, and heat stability.MOPP FilmsUnique MDO film orienting capabilitiesCustom Spooling and SlittingWidths...'}, {'text': 'The leader in custom extrusion and converting of plastic film'}, {'text': 'Discover quality products, customized solutions, and impeccable service at competitive pricing. ARLIN Mfg has helped turn client concepts into products for more than 70 years.'}, {'text': 'Contact us for a quote today!'}, {'text': 'What We Offer'}, {'text': 'Choose from a variety of cast and oriented polypropylene film and sheet products or let us customize to your needs.READ MORE', 'headline': 'Plastic Film and Sheet Extrusion'}, {'text': 'All our single layer and our multilayer oriented films (MOPP and BOPP) are manufactured using strict ...
# {'kind': 'customsearch#search', 'url': {'type': 'application/json', 'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'}, 'queries': {'previousPage': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 71, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'request': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 81, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'nextPage': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 10, 'startIndex': 91, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}]}, 'context': {'title': 'ASCEND-SE'}, 'searchInformation': {'searchTime': 0.344849, 'formattedSearchTime': '0.34', 'totalResults': '5770000', 'formattedTotalResults': '5,770,000'}, 'items': [{'kind': 'customsearch#result', 'title': 'Ensinger Penn Fibre', 'htmlTitle': 'Ensinger Penn Fibre', 'link': 'https://www.pennfibre.com/', 'displayLink': 'www.pennfibre.com', 'snippet': '... plastics – available for a wide range of applications. Sheets. Plastic Sheets. Today our largest business is extruded plastic sheet. The plastic sheeting\xa0...', 'htmlSnippet': '... <b>plastics</b> – available for a wide range of applications. <b>Sheets</b>. <b>Plastic Sheets</b>. Today our largest business is <b>extruded plastic sheet</b>. The <b>plastic sheeting</b>&nbsp;...', 'formattedUrl': 'https://www.pennfibre.com/', 'htmlFormattedUrl': 'https://www.pennfibre.com/', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRs2-0uOL5J_OigfN5Me2YcB5eD-QsBb-_hkCM8fbBN9kX0wk_-rKtiMg&s', 'width': '120', 'height': '121'}], 'cse_image': [{'src': 'https://www.pennfibre.com/images/sheets.jpg'}]}}, {'kind': 'customsearch#result', 'title': 'Types of plastic extrusion and its manufacturing process', 'htmlTitle': 'Types of <b>plastic extrusion</b> and its <b>manufacturing</b> process', 'link': 'https://europlas.com.vn/en-US/blog-1/types-of-plastic-extrusion-and-its-manufacturing-process', 'displayLink': 'europlas.com.vn', 'snippet': 'Sheet/film extrusion method is somewhat similar to the blown film method. However, because the end products must be thicker (when compared with products of\xa0...', 'htmlSnippet': '<b>Sheet</b>/<b>film extrusion</b> method is somewhat similar to the blown <b>film</b> method. However, because the end products must be thicker (when compared with products of&nbsp;...', 'formattedUrl': 'https://europlas.com.vn/.../types-of-plastic-extrusion-and-its-manufacturing...', 'htmlFormattedUrl': 'https://europlas.com.vn/.../types-of-<b>plastic</b>-extrusion-and-its-manufacturing...', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSHvRlgM3f7BCh_04RLfnLfdLH2ljAbl9fGGjtwc4yOA5XRCWpCQvyRK5W3&s', 'width': '274', 'height': '184'}], 'metatags': [{'og:image': 'https://europlas.com.vn/Data/Sites/1/News/3127/pipe.png', 'og:type': 'article', 'og:site_name': 'EuroPlas', 'viewport': 'width=device-width, initial-scale=1.0, minimum-scale=1.0, maximu ...
# {'kind': 'customsearch#search', 'url': {'type': 'application/json', 'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'}, 'queries': {'previousPage': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 9, 'startIndex': 82, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'request': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 9, 'startIndex': 91, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}], 'nextPage': [{'title': 'Google Custom Search - Plastic Sheet extruders', 'totalResults': '5770000', 'searchTerms': 'Plastic Sheet extruders', 'count': 9, 'startIndex': 100, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'c5f78325ca55341c9'}]}, 'context': {'title': 'ASCEND-SE'}, 'searchInformation': {'searchTime': 0.260167, 'formattedSearchTime': '0.26', 'totalResults': '5770000', 'formattedTotalResults': '5,770,000'}, 'items': [{'kind': 'customsearch#result', 'title': 'APET Cpet RPET Sheet Extruder Plastic Sheet Extrusion ...', 'htmlTitle': 'APET Cpet RPET Sheet Extruder <b>Plastic Sheet Extrusion</b> ...', 'link': 'https://extruforming.en.made-in-china.com/product/AnRpLrFGqUhO/China-APET-Cpet-RPET-Sheet-Extruder-Plastic-Sheet-Extrusion-Manufacturing-Production-Line.html', 'displayLink': 'extruforming.en.made-in-china.com', 'snippet': 'APET Cpet RPET Sheet Extruder Plastic Sheet Extrusion Manufacturing Production Line, Find Details and Price about Extruder Machine Sheet Extrusion Machine\xa0...', 'htmlSnippet': 'APET Cpet RPET Sheet Extruder <b>Plastic Sheet Extrusion</b> Manufacturing Production Line, Find Details and Price about Extruder Machine Sheet Extrusion Machine&nbsp;...', 'formattedUrl': 'https://extruforming.en.made-in-china.com/.../China-APET-Cpet-RPET-She...', 'htmlFormattedUrl': 'https://extruforming.en.made-in-china.com/.../China-APET-Cpet-RPET-<b>She</b>...', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTnMVocA5UdXcIGJ3gi3h_TtEAHBiiE_WStFXR7szOcxPZVKhMLhrBb0lys&s', 'width': '225', 'height': '225'}], 'metatags': [{'og:image': 'https://image.made-in-china.com/2f0j00PRskLcnFpybJ/APET-Cpet-RPET-Sheet-Extruder-Plastic-Sheet-Extrusion-Manufacturing-Production-Line.jpg', 'renderer': 'webkit', 'og:type': 'product', 'og:site_name': 'Made-in-China.com', 'og:availability': 'instock', 'og:title': '[Hot Item] APET Cpet RPET Sheet Extruder Plastic Sheet Extrusion Manufacturing Production Line', 'product:price:amount': '226000.0', 'og:description': 'After-sales Service: Lifetime Warranty: 1 Year Type: Sheet Extruder Plastic Processed: PP Product Type: Extrusion Molding Machine Feeding Mode: Multiple Feed', 'fb:app_id': '205885989426763', 'viewport': 'initial-scale=1.0,user-scalable=no,maximum-scale=1,width=device-width', 'product:price:currency': 'USD', 'fb:admins': '292039974180201', 'fb:page_id': '10150525576765348', 'og:url': 'https://extruforming.en.made-in-china.com/product/AnRpLrFGqUhO/China-APET-Cpet-RPET-Sheet-Extruder-Plastic-Sheet-Extrusion-Manufacturing-Production-Line.html', 'format-detection': 'telephone=no'}], 'cse_image': [{'src': 'https://image.made-in-china.com/2f0j00PRskL ...
# --> Finished Crawling for Plastic Sheet extruders term at: 2024-06-18 17:26:08
#
# Completed web crawling and started web scrapping.
#
# --> Current Working Directory: /home/ec2-user/SageMaker/AscendNotebook/WebScrappingCode
# Directory 'Plastic_Sheet_Extruders' created.
# URL counter to scrap data:  1
# Title: Extruded Plastic Sheet and Plastic Roll | Primex
# Snippet: As one of the world's leading plastic sheet extruders, Primex delivers custom sheet and roll solutions made to the highest standards.
# Company URL: https://www.primexplastics.com
# Company Name: Primexplastics
# Original URL: https://www.primexplastics.com/extruded-plastic-sheet-roll-stock/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.primexplastics.com/extruded-plastic-sheet-roll-stock/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  2
# Title: Plastic Sheet Extrusion - Allied Plastics
# Snippet: Allied Plastics is a full-service Custom Sheet Extruder with sheet size capability up to 120” wide x 200” long and .060” to .550” thick. Our team has experience ...
# Company URL: https://alliedplastics.com
# Company Name: Alliedplastics
# Original URL: https://alliedplastics.com/services/plastic-extrusion/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://alliedplastics.com/services/plastic-extrusion/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  3
# Title: Plastic Sheet Extrusion Equipment
# Snippet: The right plastic sheet extrusion machine will manufacture with precision, cost-effectiveness, and minimal production error. If you have any questions about ...
# Company URL: https://www.arlingtonmachinery.com
# Company Name: Arlingtonmachinery
# Original URL: https://www.arlingtonmachinery.com/plastic-extruder/pl.c.1047.0/sheet-extrusion-lines/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  4
# Title: Cut-to-Size Clear Extruded Acrylic Sheets | Acme Plastics
# Snippet: Cut-to-Size Clear Acrylic Sheet - Extruded · Thermoformable · Lightweight and rigid · Prone to low water absorption · Easy to glue and machine · Excellent ...
# Company URL: https://www.acmeplastics.com
# Company Name: Acmeplastics
# Original URL: https://www.acmeplastics.com/cut-to-size-clear-acrylic-sheet-extruded
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  5
# Title: Sheet extruded products
# Snippet: Sheet extrusion is the process of extruding a thermoplastic through a sheet die. This creates a thermoplastic sheet that can have a pattern or finish ...
# Company URL: https://sherwoodind.com
# Company Name: Sherwoodind
# Original URL: https://sherwoodind.com/sheet-extrusion/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  6
# Title: Cast vs. Extruded Acrylic | Acme Plastics
# Snippet: Available in a broad range of standard and custom colors for a variety of applications, cast acrylic is more pliable than extruded, less likely to bend, chip, ...
# Company URL: https://www.acmeplastics.com
# Company Name: Acmeplastics
# Original URL: https://www.acmeplastics.com/cast-vs-extruded
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  7
# Title: Cut to Size Plastic Acrylic Sheets - TAP Plastics : TAP Plastics
# Snippet: Extruded Acrylic (1/16" to 1/4" thickness). Clear. Add to Favorites Share.
# Company URL: https://www.tapplastics.com
# Company Name: Tapplastics
# Original URL: https://www.tapplastics.com/product/plastics/cut_to_size_plastic/acrylic_sheets_clear/508
# The text does not contain '.pdf'. Therefore extracting data from URL
# --> Failed to fetch full content.
#
# URL counter to scrap data:  8
# Title: Custom Plastic Sheet Manufacturer | Extrusion Services ...
# Snippet: Let Seiler Plastics be your plastic sheets manufacturer. We are fully equipped to provide you with plastic sheet extrusion services.
# Company URL: https://www.seilerpc.com
# Company Name: Seilerpc
# Original URL: https://www.seilerpc.com/extruded-plastic-sheet
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.seilerpc.com/extruded-plastic-sheet
# --> Failed to fetch full content.
#
# URL counter to scrap data:  9
# Title: GOEX: Plastic Sheet Manufacturer & Supplier
# Snippet: The industry leader in extruding quality custom rigid plastic sheet and roll stock products. · Graphics · Food · Medical · Consumer · Fully-integrated and ...
# Company URL: https://www.goex.com
# Company Name: Goex
# Original URL: https://www.goex.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  10
# Title: High Quality Sheets | Advanced Plastic Extrusion | United States
# Snippet: Advanced Plastic Extrusion is a manufacturer of premium plastic sheets/rolls in ABS, PC/ABS, Acrylic, HIPS, and TPO.
# Company URL: https://www.apex-extrusion.com
# Company Name: Apex
# Original URL: https://www.apex-extrusion.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  11
# Title: Industry leaders in rigid Biobased Rollstock Film sheets and extrusion.
# Snippet: Made from multiple materials, including PCR, bioplastic Clear thermorming plastic sheets, with precise film slitting & sheeting.
# Company URL: https://goodnaturedproducts.com
# Company Name: Goodnaturedproducts
# Original URL: https://goodnaturedproducts.com/pages/bioplastic-roll-stock-extruded-sheets
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  12
# Title: Plastic extrusion - Wikipedia
# Snippet: Plastics extrusion is a high-volume manufacturing process in which raw plastic is melted and formed into a continuous profile. Extrusion produces items such ...
# Company URL: https://en.wikipedia.org
# Company Name: En
# Original URL: https://en.wikipedia.org/wiki/Plastic_extrusion
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  13
# Title: Highland Plastics: Plastic Sheet & Extrusion Solutions
# Snippet: HPI specializes in custom plastic sheet extrusion. Whether you want a specification or to create something new, we can advise you on your application.
# Company URL: https://www.highlandplastics.com
# Company Name: Highlandplastics
# Original URL: https://www.highlandplastics.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  14
# Title: What is sheet Extrusion?
# Snippet: Sheet Extrusion. In the simplest form of sheet extrusion, plastic granules (possibly including additives) are fed from the extruder hopper along a heated ...
# Company URL: https://fkur.com
# Company Name: Fkur
# Original URL: https://fkur.com/en/knowledgebase/sheet-extrusion/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  15
# Title: ACRYLITEÃ‚Â® | Extruded Acrylic | Total Plastics
# Snippet: ACRYLITEÃ‚Â® extruded sheets, availble at Total Plastics are economical, provide tight thickness tolerance, high optical characteristics and low stress ...
# Company URL: https://totalplastics.com
# Company Name: Totalplastics
# Original URL: https://totalplastics.com/product/acrylite-extruded-acrylic/
# ...
# Company Name: Technicmachines
# Original URL: https://www.technicmachines.com/de/sheet-extruder-machine-line/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  74
# Title: What is Plastic Extrusion? (A Definitive Process Guide) - TWI
# Snippet: This process is used for manufacturing of products such as shopping bags. 3. Sheet Film Extrusion. This type is used for the extrusion of plastic sheets or ...
# Company URL: https://www.twi-global.com
# Company Name: Twi
# Original URL: https://www.twi-global.com/technical-knowledge/faqs/plastic-extrusion
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  75
# Title: Home / Plastics Extrusion World Expo
# Snippet: The Plastics Extrusion World Expo brings together professionals from across the industry for two days of networking, knowledge sharing and innovation.
# Company URL: https://na.extrusion-expo.com
# Company Name: Na
# Original URL: https://na.extrusion-expo.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  76
# Title: Free Accessories Plastic PC Sheet Extruder Machine Luggage ...
# Snippet: Free Accessories Plastic PC Sheet Extruder Machine Luggage Plastic Plate Extrusion Line, Find Details about Extruder, Single Screw Extruder from Free ...
# Company URL: https://cnchaoxu.en.made-in-china.com
# Company Name: Cnchaoxu
# Original URL: https://cnchaoxu.en.made-in-china.com/product/eJgUoKyOyjcq/China-Free-Accessories-Plastic-PC-Sheet-Extruder-Machine-Luggage-Plastic-Plate-Extrusion-Line.html
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 493 Client Error:  for url: https://cnchaoxu.en.made-in-china.com/product/eJgUoKyOyjcq/China-Free-Accessories-Plastic-PC-Sheet-Extruder-Machine-Luggage-Plastic-Plate-Extrusion-Line.html
# --> Failed to fetch full content.
#
# URL counter to scrap data:  77
# Title: Dalian Deyu Conical Twin Screw Extruder for Rubber/Plastic Sheet ...
# Snippet: Dalian Deyu Conical Twin Screw Extruder for Rubber/Plastic Sheet Xjy-Sz 250, Find Details about Twin Screw Sheet Extruder, Rubber Processing Machinery from ...
# Company URL: https://deyumachine.en.made-in-china.com
# Company Name: Deyumachine
# Original URL: https://deyumachine.en.made-in-china.com/product/WwiAkGNchVrn/China-Dalian-Deyu-Conical-Twin-Screw-Extruder-for-Rubber-Plastic-Sheet-Xjy-Sz-250.html
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 493 Client Error:  for url: https://deyumachine.en.made-in-china.com/product/WwiAkGNchVrn/China-Dalian-Deyu-Conical-Twin-Screw-Extruder-for-Rubber-Plastic-Sheet-Xjy-Sz-250.html
# --> Failed to fetch full content.
#
# URL counter to scrap data:  78
# Title: Plastic Sheet Textures for Enclosures & Housings | Envision Plastics ...
# Snippet: Plastic Enclosure Material Textures. Plastic sheet manufacturers (material extruders) offer several types of textures on thier products. However, most ...
# Company URL: https://envplastics.com
# Company Name: Envplastics
# Original URL: https://envplastics.com/materials/sheet-textures
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  79
# Title: Southern Film Extruders
# Snippet: Southern Film Extruders is a plastics extrusion manufacturing company in NC. Southern Film Extruders is part of Sigma Plastics Group.
# Company URL: https://www.sigmaplasticsgroup.com
# Company Name: Sigmaplasticsgroup
# Original URL: https://www.sigmaplasticsgroup.com/location/southern-film-extruders/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  80
# Title: Plastic Extrusion Explained | Fictiv
# Snippet: May 31, 2023 ... Blow-Film Extrusion: This is commonly used for creating items like shopping bags. This process uses an air ring to cool and expand the extruded ...
# Company URL: https://www.fictiv.com
# Company Name: Fictiv
# Original URL: https://www.fictiv.com/articles/plastic-extrusion-explained
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.fictiv.com/articles/plastic-extrusion-explained
# --> Failed to fetch full content.
#
# URL counter to scrap data:  81
# Title: Ensinger Penn Fibre
# Snippet: ... plastics – available for a wide range of applications. Sheets. Plastic Sheets. Today our largest business is extruded plastic sheet. The plastic sheeting ...
# Company URL: https://www.pennfibre.com
# Company Name: Pennfibre
# Original URL: https://www.pennfibre.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  82
# Title: Types of plastic extrusion and its manufacturing process
# Snippet: Sheet/film extrusion method is somewhat similar to the blown film method. However, because the end products must be thicker (when compared with products of ...
# Company URL: https://europlas.com.vn
# Company Name: Europlas
# Original URL: https://europlas.com.vn/en-US/blog-1/types-of-plastic-extrusion-and-its-manufacturing-process
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  83
# Title: Euro Extrusions | Plastic Extruder | Thermoplastic Sheet | High ...
# Snippet: Plastic extruder Euro Extrusions Ltd has become a major force in supplying thermoplastic sheet and film due to our wealth of knowledge and experience.
# Company URL: https://www.euroextrusions.com
# Company Name: Euroextrusions
# Original URL: https://www.euroextrusions.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# An error occurred: HTTPSConnectionPool(host='www.euroextrusions.com', port=443): Read timed out.
# --> Failed to fetch full content.
#
# URL counter to scrap data:  84
# Title: Double Screw Co-Extrusion Plastic Sheet Extruder, Ab/ABA Co ...
# Snippet: Double Screw Co-Extrusion Plastic Sheet Extruder, Ab/ABA Co-Extruding Sheet Machine, Two Color Plastic Sheet Making Machine, Flowerpot Plastic Sheet Machine ...
# Company URL: https://yongxujx.en.made-in-china.com
# Company Name: Yongxujx
# Original URL: https://yongxujx.en.made-in-china.com/product/oSMEyTIBgfra/China-Double-Screw-Co-Extrusion-Plastic-Sheet-Extruder-Ab-ABA-Co-Extruding-Sheet-Machine-Two-Color-Plastic-Sheet-Making-Machine-Flowerpot-Plastic-Sheet-Machine.html
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 493 Client Error:  for url: https://yongxujx.en.made-in-china.com/product/oSMEyTIBgfra/China-Double-Screw-Co-Extrusion-Plastic-Sheet-Extruder-Ab-ABA-Co-Extruding-Sheet-Machine-Two-Color-Plastic-Sheet-Making-Machine-Flowerpot-Plastic-Sheet-Machine.html
# --> Failed to fetch full content.
#
# URL counter to scrap data:  85
# Title: PA Extruded Nylon - TECAMID | Ensinger
# Snippet: Extruded Polyamide material, commonly called Nylon plastic, is manufactured by Ensinger in standard stock shapes for machining and is extruded in sheet, ...
# Company URL: https://www.ensingerplastics.com
# Company Name: Ensingerplastics
# Original URL: https://www.ensingerplastics.com/en-us/shapes/engineering-plastics/extruded-nylon-
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  86
# Title: PVC sheet extrusion
# Snippet: For a variety of PVC sheet products · Proven 32D extrusion technology · Excellent production of thermoformable compact sheets and foam sheets · Engineering work ...
# Company URL: https://www.kraussmaffei.com
# Company Name: Kraussmaffei
# Original URL: https://www.kraussmaffei.com/en/our-products/pvc-sheet-extrusion
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  87
# Title: What Is Profile Extrusion, and How Is It Different from Other Extrusion ...
# Snippet: Jun 2, 2022 ... Profile extrusion is the process of creating continuous shapes of plastic through extrusion. This process does not include forming sheet or film ...
# Company URL: https://plastrac.com
# Company Name: Plastrac
# Original URL: https://plastrac.com/what-is-profile-extrusion-and-how-is-it-different-from-other-extrusion-methods/
# The text does not contain '.pdf'. Therefore extracting data from URL
# An error occurred: HTTPSConnectionPool(host='plastrac.com', port=443): Max retries exceeded with url: /what-is-profile-extrusion-and-how-is-it-different-from-other-extrusion-methods/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fba8af65660>, 'Connection to plastrac.com timed out. (connect timeout=30)'))
# --> Failed to fetch full content.
#
# URL counter to scrap data:  88
# Title: Farber Plastics: Extruders of PET and HIPS Polystyrene ~ RPET ...
# Snippet: Farber Plastics Inc., a leading extruder of PET and HIPS roll stock and sheets for thermoformers, offering rapid turnaround and custom color. Call now for fast ...
# Company URL: http://www.farberplastics.com
# Company Name: Farberplastics
# Original URL: http://www.farberplastics.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  89
# Title: Extruded and Cast Acrylic: How to Laser Engrave and Cut Acrylic ...
# Snippet: Jan 20, 2023 ... Examples of the different types of acrylic sheets that can be cut with laser machines include: Plexiglas®, Plaskolite, Perspex®, and Acrylite®.
# Company URL: https://www.xometry.com
# Company Name: Xometry
# Original URL: https://www.xometry.com/resources/sheet/cast-acrylic-cutting/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  90
# Title: Quality Plastic Extrusion Line Shang Ta Chia : Reliable PVC Sheet ...
# Snippet: Our R&D team design series of extrusion line including plastic sheet extrusion machine, pet extrusion machine line, pp extrusion machine line, pvc extrusion ...
# Company URL: https://www.stcmach.com
# Company Name: Stcmach
# Original URL: https://www.stcmach.com/e/product.html
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  91
# Title: APET Cpet RPET Sheet Extruder Plastic Sheet Extrusion ...
# Snippet: APET Cpet RPET Sheet Extruder Plastic Sheet Extrusion Manufacturing Production Line, Find Details and Price about Extruder Machine Sheet Extrusion Machine ...
# Company URL: https://extruforming.en.made-in-china.com
# Company Name: Extruforming
# Original URL: https://extruforming.en.made-in-china.com/product/AnRpLrFGqUhO/China-APET-Cpet-RPET-Sheet-Extruder-Plastic-Sheet-Extrusion-Manufacturing-Production-Line.html
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 493 Client Error:  for url: https://extruforming.en.made-in-china.com/product/AnRpLrFGqUhO/China-APET-Cpet-RPET-Sheet-Extruder-Plastic-Sheet-Extrusion-Manufacturing-Production-Line.html
# --> Failed to fetch full content.
#
# URL counter to scrap data:  92
# Title: Plastic Extruders | Using a Plastic Extrusion Machine to Create New ...
# Snippet: Plastic is already a versatile material, but plastic extruders can stretch ... Plastic Sheet: Acrylic and polycarbonate can be extruded in thin sheets as a ...
# Company URL: https://thebonnotco.com
# Company Name: Thebonnotco
# Original URL: https://thebonnotco.com/using-plastic-extruders-to-create-a-diverse-catalog-of-products/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://thebonnotco.com/using-plastic-extruders-to-create-a-diverse-catalog-of-products/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  93
# Title: China OEM China Plastic Sheet Welding - Hand Welding Extruder ...
# Snippet: We also offer fantastic OEM provider to numerous famous brands. OEM China Plastic Sheet Welding - Hand Welding Extruder LST610C – Lesite Detail: Advantages.
# Company URL: https://www.lesiteweld.com
# Company Name: Lesiteweld
# Original URL: https://www.lesiteweld.com/oem-china-plastic-sheet-welding-hand-welding-extruder-lst610c-lesite-product/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  94
# Title: Used Plastic Extrusion Machines For Sale | Used Extruder
# Snippet: Extruders | Used Twin Screw Extruder. PlastiWin is pleased to offer plastic extruders, used sheet extrusion lines, film extrusion lines, pelletizing lines ...
# Company URL: https://plastiwin.com
# Company Name: Plastiwin
# Original URL: https://plastiwin.com/buy-used-plastic-processing-equipment/used-plastic/
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  95
# Title: Sheet extrusion,Film extrusion,Sheet extrusion machinery ...
# Snippet: Polystyrene is the most general polymer used in sheet extrusion. It is major plastic material for the thermoformed packaging, and it gives competition to ABS & ...
# Company URL: http://www.industrialextrusionmachinery.com
# Company Name: Industrialextrusionmachinery
# Original URL: http://www.industrialextrusionmachinery.com/plastic_extrusion_sheet.html
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  96
# Title: Bandera 3 Layer Plastic Sheet Extrusion Line In Europe
# Snippet: Material PET, PLA, PP. PET is possible both as virgin or as recycled material. Sheet width 1310 mm. Extruder 1 Layer ref: A Screw diam 50 mm. Description ...
# Company URL: https://www.plastemart.com
# Company Name: Plastemart
# Original URL: https://www.plastemart.com/used-bandera-3-layer-plastic-sheet-extrusion-line-europe/19445/um
# The text does not contain '.pdf'. Therefore extracting data from URL
# Can fetch full content.
#
#
# URL counter to scrap data:  97
# Title: Sheet Extrusion Machinery - Davis-Standard
# Snippet: Apr 26, 2018 ... Davis-Standard has years of experience supplying complete turnkey sheet extrusion lines for sheet ... plastic sheet utilized in heavy sheet ...
# Company URL: https://davis-standard.com
# Company Name: Davis
# Original URL: https://davis-standard.com/extrusion_system/sheet/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://davis-standard.com/extrusion_system/sheet/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  98
# Title: Dongguan Taizhang Machinery Co., Ltd.: China Pet Sheet Extruder ...
# Snippet: Featured Products · Plastic Sheet Extrusion Production Line · Plastic Vacuum Forming Machine.
# Company URL: https://plasticsheetextruder.en.made-in-china.com
# Company Name: Plasticsheetextruder
# Original URL: https://plasticsheetextruder.en.made-in-china.com/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 493 Client Error:  for url: https://plasticsheetextruder.en.made-in-china.com/
# --> Failed to fetch full content.
#
# URL counter to scrap data:  99
# Title: Side-By-Side PET Plastic Extrusion | Advanced Extrusion, Inc.
# Snippet: Our custom S-B-S PET extruded sheet can be cut and formed into a range of packaging products, including thermoform blisters, clamshells, and trays.
# Company URL: https://www.advancedextrusion.com
# Company Name: Advancedextrusion
# Original URL: https://www.advancedextrusion.com/s-b-s-pet-plastic-extrusion/
# The text does not contain '.pdf'. Therefore extracting data from URL
# HTTP error occurred: 403 Client Error: Forbidden for url: https://www.advancedextrusion.com/s-b-s-pet-plastic-extrusion/
# --> Failed to fetch full content.
#
# --> Current Working Directory: /home/ec2-user/SageMaker/AscendNotebook/WebScrappingCode
# Completed web scrapping.
#
# --> Current Working Directory: /home/ec2-user/SageMaker/AscendNotebook/WebScrappingCode
# ================================================================
