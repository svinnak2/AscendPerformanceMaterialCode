# %%
# pip install -r "/home/ec2-user/SageMaker/AscendNotebook/ascendrequirements.txt"

# %%
""" To run this script, pass the following two parameters:

Parameter1, Parameter2

Parameter1 accepts one of the following values:
    "Nylon & Polyamide injection molders"
    "Plastic Profile Extruders"
    "Plastic Sheet extruders"
    "Recycled carpet fibers applications"
    "Nylon Compounders & Polyamide Compounders"
    
Parameter2 accept any material that you check whether a company will purchase it or not.

The following is an example command to run it.

# %run SalesLeadClassification.py "Recycled carpet fibers applications" "nylon6,6"

"""

# %%
# %run SalesLeadClassification.py "Recycled carpet fibers applications" "nylon6,6"
# Out:
# Search Term: Recycled carpet fibers applications
# Number of Results to Query: nylon6,6
# Present working directory: /home/ec2-user/SageMaker/AscendNotebook
# Directory to save results: /home/ec2-user/SageMaker/AscendNotebook/CodeExecutionMetrics/
# Directory to save Sales Leads: /home/ec2-user/SageMaker/AscendNotebook/SalesLeadData/
# Starting NER job for Recycled carpet fibers applications at: 2024-06-18 21:54:37
# Files Search Directory to Work: Recycled_carpet_fibers_applications
# Current working directory: /home/ec2-user/SageMaker/AscendNotebook
#
# Current working directory: /home/ec2-user/SageMaker/AscendNotebook/Recycled_carpet_fibers_applications
# ['O16F29644.pdf', 'Recycled carpet fibers applications_76_Ccarpetsinc.txt', 'Recycled carpet fibers applications_74_Baneclene.txt', 'Recycled carpet fibers applications_84_Techpacker.txt', 'Recycled carpet fibers applications_96_Intercol.txt', 'Recycled carpet fibers applications_97_Vcpublicworks.txt', 'Recycled carpet fibers applications_77_Philadelphiacommercial.txt', 'Recycled carpet fibers applications_15_Epa.txt', 'Recycled carpet fibers applications_43_Drexelteam.txt', 'Recycled carpet fibers applications_4_Nylene.txt', 'Recycled carpet fibers applications_59_Summitcarpetandtile.txt', 'Recycled carpet fibers applications_63_Aquafil.txt', 'Recycled carpet fibers applications_38_Search.txt', 'Recycled carpet fibers applications_69_Carpetrecyclinguk.txt', 'Recycled carpet fibers applications_11_Bennettscarpets.txt', 'Recycled carpet fibers applications_5_Floorsusa.txt', 'Recycled carpet fibers applications_92_Performancefooting.txt', 'Recycled carpet fibers applications_28_Zerorez.txt', 'Recycled carpet fibers applications_25_Textileworld.txt', 'Recycled carpet fibers applications_56_Aaapolymer.txt', 'Recycled carpet fibers applications_72_Floorcoveringweekly.txt', 'Recycled carpet fibers applications_90_Thespruce.txt', 'Recycled carpet fibers applications_29_Buildinggreen.txt', 'Recycled carpet fibers applications_45_Vnpolyfiber.txt', 'Recycled carpet fibers applications_7_Mdpi.txt', 'Recycled carpet fibers applications_95_Dec.txt', 'Recycled carpet fibers applications_24_Lsiflooring.txt', 'Recycled carpet fibers applications_61_Linkedin.txt', 'Recycled carpet fibers applications_23_Read.txt', 'Recycled carpet fibers applications_19_Erema.txt', 'Recycled carpet fibers applications_51_Greenwashingindex.txt', 'CarpetPCReport_11_21.pdf', 'Recycled carpet fibers applications_40_Mohawkhome.txt', 'ecra-2030_action_planhq.pdf', 'Recycled carpet fibers applications_34_Carpetcushion.txt', 'Recycled carpet fibers applications_80_Thisoldhouse.txt', 'Recycled carpet fibers applications_30_En.txt', 'Recycled carpet fibers applications_33_Floortrendsmag.txt', 'Recycled carpet fibers applications_49_Durablebuildingsolutions.txt', 'Recycled carpet fibers applications_50_Fibre2fashion.txt', 'Recycled carpet fibers applications_52_Advansix.txt', 'Recycled carpet fibers applications_26_Home.txt', 'TechnicalBulletin_BiodegradableSustainableFibers_Chap6_2005_pdf.pdf', 'Recycled carpet fibers applications_16_Sewport.txt', 'Recycled carpet fibers applications_75_Msscleaning.txt', 'Recycled carpet fibers applications_22_In.txt', 'Recycled carpet fibers applications_37_Ascendmaterials.txt', 'Recycled carpet fibers applications_32_Americanlaboratory.txt', 'Recycled carpet fibers applications_44_Floordaily.txt', 'Recycled carpet fibers applications_62_Technicaltextile.txt', 'Recycled carpet fibers applications_73_Ultra.txt', 'Recycled carpet fibers applications_83_Americanfibercushion.txt', 'Recycled carpet fibers applications_13_Recyclenation.txt', 'pttgenapprev8-30-06.pdf', 'Recycled carpet fibers applications_66_Greenbuildingsupply.txt', 'Recycled carpet fibers applications_70_Kdielements.txt', 'Recycled carpet fibers applications_21_Pfa.txt']
# Reading File: 0
# Reading file name: O16F29644.pdf
#
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided does not contain information about a specific company that manufactures injection molded products. It is a report discussing carpet recycling initiatives in the carpet industry. There is no data on any company that is likely to purchase nylon6,6 material."
# }
# ```
#
# The context discusses current product stewardship initiatives and recycling programs in the carpet industry. It provides an overview of the materials and construction of carpets, carpet disposal issues, and options for carpet recycling.
#
# The context focuses on industry-wide programs and does not provide any information about a specific injection molding company that might purchase nylon6,6 material. Without data on an individual company, I cannot determine if a company is likely to purchase the provided material.
#
# Therefore, my prediction is that there is no data to determine if a company is likely to purchase the nylon6,6 material. I've provided "Not likely to purchase" as the prediction and explained the lack of relevant data in the prediction reason. The other response fields are "N/A" since no company information is available.
# The data is not in JSON format.
# Printing data Text:
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided does not contain information about a specific company that manufactures injection molded products. It is a report discussing carpet recycling initiatives in the carpet industry. There is no data on any company that is likely to purchase nylon6,6 material."
# }
# ```
#
# The context discusses current product stewardship initiatives and recycling programs in the carpet industry. It provides an overview of the materials and construction of carpets, carpet disposal issues, and options for carpet recycling.
#
# The context focuses on industry-wide programs and does not provide any information about a specific injection molding company that might purchase nylon6,6 material. Without data on an individual company, I cannot determine if a company is likely to purchase the provided material.
#
# Therefore, my prediction is that there is no data to determine if a company is likely to purchase the nylon6,6 material. I've provided "Not likely to purchase" as the prediction and explained the lack of relevant data in the prediction reason. The other response fields are "N/A" since no company information is available.
# Printing data after removing backticks:
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided does not contain information about a specific company that manufactures injection molded products. It is a report discussing carpet recycling initiatives in the carpet industry. There is no data on any company that is likely to purchase nylon6,6 material."
# }
# ```
#
# The context discusses current product stewardship initiatives and recycling programs in the carpet industry. It provides an overview of the materials and construction of carpets, carpet disposal issues, and options for carpet recycling.
#
# The context focuses on industry-wide programs and does not provide any information about a specific injection molding company that might purchase nylon6,6 material. Without data on an individual company, I cannot determine if a company is likely to purchase the provided material.
#
# Therefore, my prediction is that there is no data to determine if a company is likely to purchase the nylon6,6 material. I've provided "Not likely to purchase" as the prediction and explained the lack of relevant data in the prediction reason. The other response fields are "N/A" since no company information is available.
# Extracted JSON Part
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided does not contain information about a specific company that manufactures injection molded products. It is a report discussing carpet recycling initiatives in the carpet industry. There is no data on any company that is likely to purchase nylon6,6 material."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 1
# Reading file name: Recycled carpet fibers applications_76_Ccarpetsinc.txt
#
#  Here is the analysis in JSON format:
#
# {
#   "Company_Name": "Commercial Carpet & Flooring Services Inc.",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is a website for a flooring company that installs and provides tips on different types of flooring like carpet, laminate, and hardwood. There is no indication that they manufacture or mold any products. So they are not likely to purchase nylon6,6 material."
# }
#
# The key reasons I predicted they are not likely to purchase nylon6,6:
#
# 1) The company is a flooring installation and services company, not a manufacturing company.
#
# 2) The context focuses on tips, facts, and information about different flooring products like carpet, laminate, hardwood etc. There is no mention of any manufacturing or injection molding operations.
#
# 3) Nylon6,6 is a material often used in injection molding processes to create plastic parts or components. But this company does not seem to be involved in any kind of manufacturing where they would need such material.
#
# So based on the information provided, I don't see any evidence that this company performs injection molding or otherwise manufactures products requiring nylon6,6 material. Therefore, they are unlikely to purchase it.
# The data is not in JSON format.
# Printing data Text:
#  Here is the analysis in JSON format:
#
# {
#   "Company_Name": "Commercial Carpet & Flooring Services Inc.",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is a website for a flooring company that installs and provides tips on different types of flooring like carpet, laminate, and hardwood. There is no indication that they manufacture or mold any products. So they are not likely to purchase nylon6,6 material."
# }
#
# The key reasons I predicted they are not likely to purchase nylon6,6:
#
# 1) The company is a flooring installation and services company, not a manufacturing company.
#
# 2) The context focuses on tips, facts, and information about different flooring products like carpet, laminate, hardwood etc. There is no mention of any manufacturing or injection molding operations.
#
# 3) Nylon6,6 is a material often used in injection molding processes to create plastic parts or components. But this company does not seem to be involved in any kind of manufacturing where they would need such material.
#
# So based on the information provided, I don't see any evidence that this company performs injection molding or otherwise manufactures products requiring nylon6,6 material. Therefore, they are unlikely to purchase it.
# Printing data after removing backticks:
#  Here is the analysis in JSON format:
#
# {
#   "Company_Name": "Commercial Carpet & Flooring Services Inc.",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is a website for a flooring company that installs and provides tips on different types of flooring like carpet, laminate, and hardwood. There is no indication that they manufacture or mold any products. So they are not likely to purchase nylon6,6 material."
# }
#
# The key reasons I predicted they are not likely to purchase nylon6,6:
#
# 1) The company is a flooring installation and services company, not a manufacturing company.
#
# 2) The context focuses on tips, facts, and information about different flooring products like carpet, laminate, hardwood etc. There is no mention of any manufacturing or injection molding operations.
#
# 3) Nylon6,6 is a material often used in injection molding processes to create plastic parts or components. But this company does not seem to be involved in any kind of manufacturing where they would need such material.
#
# So based on the information provided, I don't see any evidence that this company performs injection molding or otherwise manufactures products requiring nylon6,6 material. Therefore, they are unlikely to purchase it.
# Extracted JSON Part
# {
#   "Company_Name": "Commercial Carpet & Flooring Services Inc.",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is a website for a flooring company that installs and provides tips on different types of flooring like carpet, laminate, and hardwood. There is no indication that they manufacture or mold any products. So they are not likely to purchase nylon6,6 material."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 2
# Reading file name: Recycled carpet fibers applications_74_Baneclene.txt
#
#  Based on the context, I could not find enough information to determine if the company is likely to purchase the material nylon6,6. The context talks about a company called "baneclene.com" that sells cleaning products, but there is no indication that they are an injection molding company or would have use for nylon6,6.
#
# Here is the output in JSON format:
#
# ```json
# {
#   "Company_Name": "baneclene.com",
#   "Company Website": "baneclene.com",
#   "Phone Number": "800-428-9512",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The company sells cleaning products, no indication they are an injection molding company or would need nylon6,6"
# }
# ```
#
# I provided the available company details, but predicted they are not likely to purchase the material since they seem to be a cleaning products company rather than an injection molding company. Let me know if you need any other details or have additional context to provide.
# The data is not in JSON format.
# Printing data Text:
#  Based on the context, I could not find enough information to determine if the company is likely to purchase the material nylon6,6. The context talks about a company called "baneclene.com" that sells cleaning products, but there is no indication that they are an injection molding company or would have use for nylon6,6.
#
# Here is the output in JSON format:
#
# ```json
# {
#   "Company_Name": "baneclene.com",
#   "Company Website": "baneclene.com",
#   "Phone Number": "800-428-9512",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The company sells cleaning products, no indication they are an injection molding company or would need nylon6,6"
# }
# ```
#
# I provided the available company details, but predicted they are not likely to purchase the material since they seem to be a cleaning products company rather than an injection molding company. Let me know if you need any other details or have additional context to provide.
# Printing data after removing backticks:
#  Based on the context, I could not find enough information to determine if the company is likely to purchase the material nylon6,6. The context talks about a company called "baneclene.com" that sells cleaning products, but there is no indication that they are an injection molding company or would have use for nylon6,6.
#
# Here is the output in JSON format:
#
# ```json
# {
#   "Company_Name": "baneclene.com",
#   "Company Website": "baneclene.com",
#   "Phone Number": "800-428-9512",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The company sells cleaning products, no indication they are an injection molding company or would need nylon6,6"
# }
# ```
#
# I provided the available company details, but predicted they are not likely to purchase the material since they seem to be a cleaning products company rather than an injection molding company. Let me know if you need any other details or have additional context to provide.
# Extracted JSON Part
# {
#   "Company_Name": "baneclene.com",
#   "Company Website": "baneclene.com",
#   "Phone Number": "800-428-9512",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The company sells cleaning products, no indication they are an injection molding company or would need nylon6,6"
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 3
# Reading file name: Recycled carpet fibers applications_84_Techpacker.txt
#
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is an article about sustainable and eco-friendly fashion materials. It does not contain any information about an injection molding company that might purchase nylon6,6 material. So there is insufficient data to determine if a company is likely to purchase the material."
# }
# ```
#
# I could not identify an injection molding company from the given context. The context talks about sustainable fashion materials and how they are made. It does not provide any information about potential buyers of the nylon6,6 material mentioned in the material tag. So I have responded with "Not likely to purchase" for the prediction and "N/A" for the other fields. Please let me know if you need any other details!
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is an article about sustainable and eco-friendly fashion materials. It does not contain any information about an injection molding company that might purchase nylon6,6 material. So there is insufficient data to determine if a company is likely to purchase the material."
# }
# ```
#
# I could not identify an injection molding company from the given context. The context talks about sustainable fashion materials and how they are made. It does not provide any information about potential buyers of the nylon6,6 material mentioned in the material tag. So I have responded with "Not likely to purchase" for the prediction and "N/A" for the other fields. Please let me know if you need any other details!
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is an article about sustainable and eco-friendly fashion materials. It does not contain any information about an injection molding company that might purchase nylon6,6 material. So there is insufficient data to determine if a company is likely to purchase the material."
# }
# ```
#
# I could not identify an injection molding company from the given context. The context talks about sustainable fashion materials and how they are made. It does not provide any information about potential buyers of the nylon6,6 material mentioned in the material tag. So I have responded with "Not likely to purchase" for the prediction and "N/A" for the other fields. Please let me know if you need any other details!
# Extracted JSON Part
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is an article about sustainable and eco-friendly fashion materials. It does not contain any information about an injection molding company that might purchase nylon6,6 material. So there is insufficient data to determine if a company is likely to purchase the material."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 4
# Reading file name: Recycled carpet fibers applications_96_Intercol.txt
#
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Intercol",
#   "Company Website": "https://www.intercol.nl",
#   "Phone Number": "+31 318 636363",
#   "Location": "Netherlands",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is about carpet recycling processes and VAE polymer compounds. It does not indicate that Intercol is an injection molding company looking to purchase nylon6,6 material. Rather, it seems to be an adhesives manufacturer providing solutions for carpet recycling."
# }
# ```
#
# The context talks about carpet recycling and VAE polymer compounds that can be used to enable carpet recycling. It provides details on mechanical and chemical recycling processes for carpets. Intercol seems to be a company that manufactures adhesives, including VAE compounds, that can be used in carpet production and recycling.
#
# There is no indication that Intercol is an injection molding company looking to purchase nylon6,6 material. So I have predicted "Not likely to purchase" along with an explanation that Intercol does not seem to be the target customer for the nylon6,6 material based on the context provided. The other fields are populated with details extracted from the context.
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Intercol",
#   "Company Website": "https://www.intercol.nl",
#   "Phone Number": "+31 318 636363",
#   "Location": "Netherlands",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is about carpet recycling processes and VAE polymer compounds. It does not indicate that Intercol is an injection molding company looking to purchase nylon6,6 material. Rather, it seems to be an adhesives manufacturer providing solutions for carpet recycling."
# }
# ```
#
# The context talks about carpet recycling and VAE polymer compounds that can be used to enable carpet recycling. It provides details on mechanical and chemical recycling processes for carpets. Intercol seems to be a company that manufactures adhesives, including VAE compounds, that can be used in carpet production and recycling.
#
# There is no indication that Intercol is an injection molding company looking to purchase nylon6,6 material. So I have predicted "Not likely to purchase" along with an explanation that Intercol does not seem to be the target customer for the nylon6,6 material based on the context provided. The other fields are populated with details extracted from the context.
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Intercol",
#   "Company Website": "https://www.intercol.nl",
#   "Phone Number": "+31 318 636363",
#   "Location": "Netherlands",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is about carpet recycling processes and VAE polymer compounds. It does not indicate that Intercol is an injection molding company looking to purchase nylon6,6 material. Rather, it seems to be an adhesives manufacturer providing solutions for carpet recycling."
# }
# ```
#
# The context talks about carpet recycling and VAE polymer compounds that can be used to enable carpet recycling. It provides details on mechanical and chemical recycling processes for carpets. Intercol seems to be a company that manufactures adhesives, including VAE compounds, that can be used in carpet production and recycling.
#
# There is no indication that Intercol is an injection molding company looking to purchase nylon6,6 material. So I have predicted "Not likely to purchase" along with an explanation that Intercol does not seem to be the target customer for the nylon6,6 material based on the context provided. The other fields are populated with details extracted from the context.
# Extracted JSON Part
# {
#   "Company_Name": "Intercol",
#   "Company Website": "https://www.intercol.nl",
#   "Phone Number": "+31 318 636363",
#   "Location": "Netherlands",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is about carpet recycling processes and VAE polymer compounds. It does not indicate that Intercol is an injection molding company looking to purchase nylon6,6 material. Rather, it seems to be an adhesives manufacturer providing solutions for carpet recycling."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 5
# Reading file name: Recycled carpet fibers applications_97_Vcpublicworks.txt
#
#  Here is the analysis in JSON format:
#
# {
#   "Company_Name": "Ventura County Public Works Agency",
#   "Company Website": "https://www.vcpublicworks.org/",
#   "Phone Number": "805-654-2018",
#   "Location": "Ventura, California, USA",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The Ventura County Public Works Agency is a government agency focused on public works services like roads, transportation, waste management etc. There is no indication they manufacture products or use nylon6,6 material."
# }
#
# The key reasons I predicted the company is not likely to purchase nylon6,6 material:
#
# 1) It is a government public works agency not a manufacturing company.
#
# 2) The context focuses on their public services like roads, transportation, waste management etc. There is no mention of any manufacturing or use of plastics/chemicals.
#
# 3) Specifically, the carpet recycling section they discuss is focused on residents/businesses recycling carpets and sending it to recycling centers. The agency itself does not seem to use or purchase any nylon6,6 or other materials.
#
# Let me know if you need any other clarification or have additional information to add!
# The data is not in JSON format.
# Printing data Text:
#  Here is the analysis in JSON format:
#
# {
#   "Company_Name": "Ventura County Public Works Agency",
#   "Company Website": "https://www.vcpublicworks.org/",
#   "Phone Number": "805-654-2018",
#   "Location": "Ventura, California, USA",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The Ventura County Public Works Agency is a government agency focused on public works services like roads, transportation, waste management etc. There is no indication they manufacture products or use nylon6,6 material."
# }
#
# The key reasons I predicted the company is not likely to purchase nylon6,6 material:
#
# 1) It is a government public works agency not a manufacturing company.
#
# 2) The context focuses on their public services like roads, transportation, waste management etc. There is no mention of any manufacturing or use of plastics/chemicals.
#
# 3) Specifically, the carpet recycling section they discuss is focused on residents/businesses recycling carpets and sending it to recycling centers. The agency itself does not seem to use or purchase any nylon6,6 or other materials.
#
# Let me know if you need any other clarification or have additional information to add!
# Printing data after removing backticks:
#  Here is the analysis in JSON format:
#
# {
#   "Company_Name": "Ventura County Public Works Agency",
#   "Company Website": "https://www.vcpublicworks.org/",
#   "Phone Number": "805-654-2018",
#   "Location": "Ventura, California, USA",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The Ventura County Public Works Agency is a government agency focused on public works services like roads, transportation, waste management etc. There is no indication they manufacture products or use nylon6,6 material."
# }
#
# The key reasons I predicted the company is not likely to purchase nylon6,6 material:
#
# 1) It is a government public works agency not a manufacturing company.
#
# 2) The context focuses on their public services like roads, transportation, waste management etc. There is no mention of any manufacturing or use of plastics/chemicals.
#
# 3) Specifically, the carpet recycling section they discuss is focused on residents/businesses recycling carpets and sending it to recycling centers. The agency itself does not seem to use or purchase any nylon6,6 or other materials.
#
# Let me know if you need any other clarification or have additional information to add!
# Extracted JSON Part
# {
#   "Company_Name": "Ventura County Public Works Agency",
#   "Company Website": "https://www.vcpublicworks.org/",
#   "Phone Number": "805-654-2018",
#   "Location": "Ventura, California, USA",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The Ventura County Public Works Agency is a government agency focused on public works services like roads, transportation, waste management etc. There is no indication they manufacture products or use nylon6,6 material."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 6
# Reading file name: Recycled carpet fibers applications_77_Philadelphiacommercial.txt
#
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Philadelphia Commercial",
#   "Company Website": "https://philadelphiacommercial.com/",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Philadelphia Commercial manufactures and sells commercial carpet and flooring products. The material tag specifies nylon6,6 which is a type of nylon fiber used in carpets and flooring. Since Philadelphia Commercial works with nylon fibers like EcoSolution Q and Solution Q for its carpet products, it is likely they would be interested in purchasing more nylon6,6 material for manufacturing new carpet products."
# }
# ```
#
# To summarize:
# - Philadelphia Commercial is a manufacturer of commercial carpets and floorings
# - The material specified is nylon6,6 which is used to make carpets/floorings
# - Philadelphia Commercial uses nylon fibers like EcoSolution Q and Solution Q in its carpet products
# - So it is likely they would purchase more nylon6,6 to manufacture new carpet products
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Philadelphia Commercial",
#   "Company Website": "https://philadelphiacommercial.com/",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Philadelphia Commercial manufactures and sells commercial carpet and flooring products. The material tag specifies nylon6,6 which is a type of nylon fiber used in carpets and flooring. Since Philadelphia Commercial works with nylon fibers like EcoSolution Q and Solution Q for its carpet products, it is likely they would be interested in purchasing more nylon6,6 material for manufacturing new carpet products."
# }
# ```
#
# To summarize:
# - Philadelphia Commercial is a manufacturer of commercial carpets and floorings
# - The material specified is nylon6,6 which is used to make carpets/floorings
# - Philadelphia Commercial uses nylon fibers like EcoSolution Q and Solution Q in its carpet products
# - So it is likely they would purchase more nylon6,6 to manufacture new carpet products
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Philadelphia Commercial",
#   "Company Website": "https://philadelphiacommercial.com/",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Philadelphia Commercial manufactures and sells commercial carpet and flooring products. The material tag specifies nylon6,6 which is a type of nylon fiber used in carpets and flooring. Since Philadelphia Commercial works with nylon fibers like EcoSolution Q and Solution Q for its carpet products, it is likely they would be interested in purchasing more nylon6,6 material for manufacturing new carpet products."
# }
# ```
#
# To summarize:
# - Philadelphia Commercial is a manufacturer of commercial carpets and floorings
# - The material specified is nylon6,6 which is used to make carpets/floorings
# - Philadelphia Commercial uses nylon fibers like EcoSolution Q and Solution Q in its carpet products
# - So it is likely they would purchase more nylon6,6 to manufacture new carpet products
# Extracted JSON Part
# {
#   "Company_Name": "Philadelphia Commercial",
#   "Company Website": "https://philadelphiacommercial.com/",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Philadelphia Commercial manufactures and sells commercial carpet and flooring products. The material tag specifies nylon6,6 which is a type of nylon fiber used in carpets and flooring. Since Philadelphia Commercial works with nylon fibers like EcoSolution Q and Solution Q for its carpet products, it is likely they would be interested in purchasing more nylon6,6 material for manufacturing new carpet products."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 7
# Reading file name: Recycled carpet fibers applications_15_Epa.txt
#
#  Unfortunately, there is not enough relevant information in the provided context to determine if the company is likely to purchase the material nylon6,6. The context talks about the EPA's Comprehensive Procurement Guidelines for various construction products, but does not mention any specific companies that might purchase nylon6,6.
#
# Since there is insufficient data to make a prediction, here is the output in the requested JSON format:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "No company name or any other relevant information provided to determine if the company is likely to purchase nylon6,6."
# }
# ```
# The data is not in JSON format.
# Printing data Text:
#  Unfortunately, there is not enough relevant information in the provided context to determine if the company is likely to purchase the material nylon6,6. The context talks about the EPA's Comprehensive Procurement Guidelines for various construction products, but does not mention any specific companies that might purchase nylon6,6.
#
# Since there is insufficient data to make a prediction, here is the output in the requested JSON format:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "No company name or any other relevant information provided to determine if the company is likely to purchase nylon6,6."
# }
# ```
# Printing data after removing backticks:
#  Unfortunately, there is not enough relevant information in the provided context to determine if the company is likely to purchase the material nylon6,6. The context talks about the EPA's Comprehensive Procurement Guidelines for various construction products, but does not mention any specific companies that might purchase nylon6,6.
#
# Since there is insufficient data to make a prediction, here is the output in the requested JSON format:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "No company name or any other relevant information provided to determine if the company is likely to purchase nylon6,6."
# }
#
# Extracted JSON Part
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "No company name or any other relevant information provided to determine if the company is likely to purchase nylon6,6."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 8
# Reading file name: Recycled carpet fibers applications_43_Drexelteam.txt
#
#  Based on the context provided, I could not conclusively determine if this company is an injection molding company that might purchase the material nylon6,6. The context talks about carpets, flooring, and building materials, but does not mention anything about injection molding or purchasing nylon6,6 specifically.
#
# Therefore, my response is:
#
# ```json
# {
#   "Company_Name": "Drexel Building Supply",
#   "Company Website": "https://www.drexelbuildingsupply.com/",
#   "Phone Number": "N/A",
#   "Location": "Wisconsin, United States",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context does not mention anything about injection molding or purchasing nylon6,6 specifically. It talks about carpets, flooring and building materials."
# }
# ```
#
# I've provided the company name, website, and location based on the context. But I've predicted they are not likely to purchase the material since there is no evidence they do injection molding or would use that specific material.
# The data is not in JSON format.
# Printing data Text:
#  Based on the context provided, I could not conclusively determine if this company is an injection molding company that might purchase the material nylon6,6. The context talks about carpets, flooring, and building materials, but does not mention anything about injection molding or purchasing nylon6,6 specifically.
#
# Therefore, my response is:
#
# ```json
# {
#   "Company_Name": "Drexel Building Supply",
#   "Company Website": "https://www.drexelbuildingsupply.com/",
#   "Phone Number": "N/A",
#   "Location": "Wisconsin, United States",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context does not mention anything about injection molding or purchasing nylon6,6 specifically. It talks about carpets, flooring and building materials."
# }
# ```
#
# I've provided the company name, website, and location based on the context. But I've predicted they are not likely to purchase the material since there is no evidence they do injection molding or would use that specific material.
# Printing data after removing backticks:
#  Based on the context provided, I could not conclusively determine if this company is an injection molding company that might purchase the material nylon6,6. The context talks about carpets, flooring, and building materials, but does not mention anything about injection molding or purchasing nylon6,6 specifically.
#
# Therefore, my response is:
#
# ```json
# {
#   "Company_Name": "Drexel Building Supply",
#   "Company Website": "https://www.drexelbuildingsupply.com/",
#   "Phone Number": "N/A",
#   "Location": "Wisconsin, United States",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context does not mention anything about injection molding or purchasing nylon6,6 specifically. It talks about carpets, flooring and building materials."
# }
# ```
#
# I've provided the company name, website, and location based on the context. But I've predicted they are not likely to purchase the material since there is no evidence they do injection molding or would use that specific material.
# Extracted JSON Part
# {
#   "Company_Name": "Drexel Building Supply",
#   "Company Website": "https://www.drexelbuildingsupply.com/",
#   "Phone Number": "N/A",
#   "Location": "Wisconsin, United States",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context does not mention anything about injection molding or purchasing nylon6,6 specifically. It talks about carpets, flooring and building materials."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 9
# Reading file name: Recycled carpet fibers applications_4_Nylene.txt
#
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```JSON
# {
#   "Company_Name": "Nylene Specialty Nylon",
#   "Company Website": "https://www.nylene.com",
#   "Phone Number": "N/A",
#   "Location": "North America",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Nylene Specialty Nylon manufactures nylon products including nylon 6 fiber grade polymers for carpet applications. The material tag specifies nylon 6,6 which is a type of nylon. Since Nylene already produces nylon polymers for carpets, they are likely to purchase more nylon material to expand their offerings."
# }
# ```
#
# To summarize:
#
# - The company name is Nylene Specialty Nylon based on the website and content
# - The company website is https://www.nylene.com
# - A phone number was not found
# - The location is listed as North America based on the corporate office address
# - I predicted "Likely to purchase" since they manufacture nylon products and the material is a type of nylon
# - My reason is that they already produce nylon so would likely purchase more to expand their carpet fiber offerings
#
# Let me know if you need any clarification or have additional questions!
# The data is not in JSON format.
# Printing data Text:
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```JSON
# {
#   "Company_Name": "Nylene Specialty Nylon",
#   "Company Website": "https://www.nylene.com",
#   "Phone Number": "N/A",
#   "Location": "North America",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Nylene Specialty Nylon manufactures nylon products including nylon 6 fiber grade polymers for carpet applications. The material tag specifies nylon 6,6 which is a type of nylon. Since Nylene already produces nylon polymers for carpets, they are likely to purchase more nylon material to expand their offerings."
# }
# ```
#
# To summarize:
#
# - The company name is Nylene Specialty Nylon based on the website and content
# - The company website is https://www.nylene.com
# - A phone number was not found
# - The location is listed as North America based on the corporate office address
# - I predicted "Likely to purchase" since they manufacture nylon products and the material is a type of nylon
# - My reason is that they already produce nylon so would likely purchase more to expand their carpet fiber offerings
#
# Let me know if you need any clarification or have additional questions!
# Printing data after removing backticks:
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```JSON
# {
#   "Company_Name": "Nylene Specialty Nylon",
#   "Company Website": "https://www.nylene.com",
#   "Phone Number": "N/A",
#   "Location": "North America",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Nylene Specialty Nylon manufactures nylon products including nylon 6 fiber grade polymers for carpet applications. The material tag specifies nylon 6,6 which is a type of nylon. Since Nylene already produces nylon polymers for carpets, they are likely to purchase more nylon material to expand their offerings."
# }
# ```
#
# To summarize:
#
# - The company name is Nylene Specialty Nylon based on the website and content
# - The company website is https://www.nylene.com
# - A phone number was not found
# - The location is listed as North America based on the corporate office address
# - I predicted "Likely to purchase" since they manufacture nylon products and the material is a type of nylon
# - My reason is that they already produce nylon so would likely purchase more to expand their carpet fiber offerings
#
# Let me know if you need any clarification or have additional questions!
# Extracted JSON Part
# {
#   "Company_Name": "Nylene Specialty Nylon",
#   "Company Website": "https://www.nylene.com",
#   "Phone Number": "N/A",
#   "Location": "North America",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Nylene Specialty Nylon manufactures nylon products including nylon 6 fiber grade polymers for carpet applications. The material tag specifies nylon 6,6 which is a type of nylon. Since Nylene already produces nylon polymers for carpets, they are likely to purchase more nylon material to expand their offerings."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 10
# Reading file name: Recycled carpet fibers applications_59_Summitcarpetandtile.txt
#
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Summit Carpet & Tile, Inc",
#   "Company Website": "http://summitcarpetandtile.com",
#   "Phone Number": "(303) 678-0704",
#   "Location": "Longmont, CO, USA",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is about a carpet and tile store. There is no indication that this company does injection molding or would purchase nylon6,6 material. They sell flooring products to consumers."
# }
# ```
#
# I analyzed the long context provided and determined that Summit Carpet & Tile is a flooring store that sells carpets, tiles, wood floors, etc. to consumers. There is no evidence that they do injection molding manufacturing or would purchase nylon6,6 material. So I have predicted they are "Not likely to purchase" the material. My reason is that they are a retailer, not a manufacturer.
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Summit Carpet & Tile, Inc",
#   "Company Website": "http://summitcarpetandtile.com",
#   "Phone Number": "(303) 678-0704",
#   "Location": "Longmont, CO, USA",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is about a carpet and tile store. There is no indication that this company does injection molding or would purchase nylon6,6 material. They sell flooring products to consumers."
# }
# ```
#
# I analyzed the long context provided and determined that Summit Carpet & Tile is a flooring store that sells carpets, tiles, wood floors, etc. to consumers. There is no evidence that they do injection molding manufacturing or would purchase nylon6,6 material. So I have predicted they are "Not likely to purchase" the material. My reason is that they are a retailer, not a manufacturer.
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Summit Carpet & Tile, Inc",
#   "Company Website": "http://summitcarpetandtile.com",
#   "Phone Number": "(303) 678-0704",
#   "Location": "Longmont, CO, USA",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is about a carpet and tile store. There is no indication that this company does injection molding or would purchase nylon6,6 material. They sell flooring products to consumers."
# }
# ```
#
# I analyzed the long context provided and determined that Summit Carpet & Tile is a flooring store that sells carpets, tiles, wood floors, etc. to consumers. There is no evidence that they do injection molding manufacturing or would purchase nylon6,6 material. So I have predicted they are "Not likely to purchase" the material. My reason is that they are a retailer, not a manufacturer.
# Extracted JSON Part
# {
#   "Company_Name": "Summit Carpet & Tile, Inc",
#   "Company Website": "http://summitcarpetandtile.com",
#   "Phone Number": "(303) 678-0704",
#   "Location": "Longmont, CO, USA",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is about a carpet and tile store. There is no indication that this company does injection molding or would purchase nylon6,6 material. They sell flooring products to consumers."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 11
# Reading file name: Recycled carpet fibers applications_63_Aquafil.txt
#
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```JSON
# {
#   "Company_Name": "Aquafil Group",
#   "Company Website": "https://www.aquafil.com/",
#   "Phone Number": "N/A",
#   "Location": "Italy, USA, Thailand",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Aquafil Group manufactures nylon carpet yarn which is the material provided. They have extrusion, spinning and texturing capabilities to produce nylon carpet yarn. As a leading manufacturer of nylon carpet yarn, they are likely to purchase nylon6,6 material for production."
# }
# ```
#
# The key information that indicates Aquafil Group is likely to purchase nylon6,6 material:
#
# ...
# Extracted JSON Part
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "No company name or contact details are provided in the given context. The article talks about recycling nylon carpet in general but does not mention any specific company that manufactures injection molded products or is likely to purchase nylon6,6 material."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 53
# Reading file name: pttgenapprev8-30-06.pdf
#
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "E. I. du Pont de Nemours and Company and Mohawk Industries, Inc. PTT Poly Canada",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company manufactures carpets and apparel using nylon6,6 material. The context mentions that the company has launched carpets made from PTT fiber and sells them under the SmartStrand trademark. This indicates they are likely to purchase more nylon6,6 material for continued manufacturing of these products."
# }
# ```
#
# The key information I extracted:
#
# - The company name is E. I. du Pont de Nemours and Company and Mohawk Industries, Inc. PTT Poly Canada
# - No website, phone number or location details are provided
# - They have launched carpets made from PTT fiber and sell them under the SmartStrand trademark
# - This indicates they are likely to purchase more nylon6,6 material to continue manufacturing these PTT fiber products
#
# My prediction is "Likely to purchase" nylon6,6 material because they already manufacture products using it and will need more supply for continued production. The reasoning is that they have demonstrated usage and demand by launching PTT fiber products for carpets and apparel under existing brands.
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "E. I. du Pont de Nemours and Company and Mohawk Industries, Inc. PTT Poly Canada",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company manufactures carpets and apparel using nylon6,6 material. The context mentions that the company has launched carpets made from PTT fiber and sells them under the SmartStrand trademark. This indicates they are likely to purchase more nylon6,6 material for continued manufacturing of these products."
# }
# ```
#
# The key information I extracted:
#
# - The company name is E. I. du Pont de Nemours and Company and Mohawk Industries, Inc. PTT Poly Canada
# - No website, phone number or location details are provided
# - They have launched carpets made from PTT fiber and sell them under the SmartStrand trademark
# - This indicates they are likely to purchase more nylon6,6 material to continue manufacturing these PTT fiber products
#
# My prediction is "Likely to purchase" nylon6,6 material because they already manufacture products using it and will need more supply for continued production. The reasoning is that they have demonstrated usage and demand by launching PTT fiber products for carpets and apparel under existing brands.
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "E. I. du Pont de Nemours and Company and Mohawk Industries, Inc. PTT Poly Canada",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company manufactures carpets and apparel using nylon6,6 material. The context mentions that the company has launched carpets made from PTT fiber and sells them under the SmartStrand trademark. This indicates they are likely to purchase more nylon6,6 material for continued manufacturing of these products."
# }
# ```
#
# The key information I extracted:
#
# - The company name is E. I. du Pont de Nemours and Company and Mohawk Industries, Inc. PTT Poly Canada
# - No website, phone number or location details are provided
# - They have launched carpets made from PTT fiber and sell them under the SmartStrand trademark
# - This indicates they are likely to purchase more nylon6,6 material to continue manufacturing these PTT fiber products
#
# My prediction is "Likely to purchase" nylon6,6 material because they already manufacture products using it and will need more supply for continued production. The reasoning is that they have demonstrated usage and demand by launching PTT fiber products for carpets and apparel under existing brands.
# Extracted JSON Part
# {
#   "Company_Name": "E. I. du Pont de Nemours and Company and Mohawk Industries, Inc. PTT Poly Canada",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company manufactures carpets and apparel using nylon6,6 material. The context mentions that the company has launched carpets made from PTT fiber and sells them under the SmartStrand trademark. This indicates they are likely to purchase more nylon6,6 material for continued manufacturing of these products."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 54
# Reading file name: Recycled carpet fibers applications_66_Greenbuildingsupply.txt
#
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "AFM SafeChoice",
#   "Company Website": "N/A",
#   "Phone Number": "800.405.0222",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is about a carpet seal product from AFM SafeChoice. There is no information indicating that AFM SafeChoice is an injection molding company or would purchase nylon6,6 material."
# }
# ```
#
# The context provided is about a carpet seal product from AFM SafeChoice. There is no information indicating that AFM SafeChoice is an injection molding company or would purchase the nylon6,6 material. So I have predicted that they are "Not likely to purchase" the material.
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "AFM SafeChoice",
#   "Company Website": "N/A",
#   "Phone Number": "800.405.0222",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is about a carpet seal product from AFM SafeChoice. There is no information indicating that AFM SafeChoice is an injection molding company or would purchase nylon6,6 material."
# }
# ```
#
# The context provided is about a carpet seal product from AFM SafeChoice. There is no information indicating that AFM SafeChoice is an injection molding company or would purchase the nylon6,6 material. So I have predicted that they are "Not likely to purchase" the material.
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "AFM SafeChoice",
#   "Company Website": "N/A",
#   "Phone Number": "800.405.0222",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is about a carpet seal product from AFM SafeChoice. There is no information indicating that AFM SafeChoice is an injection molding company or would purchase nylon6,6 material."
# }
# ```
#
# The context provided is about a carpet seal product from AFM SafeChoice. There is no information indicating that AFM SafeChoice is an injection molding company or would purchase the nylon6,6 material. So I have predicted that they are "Not likely to purchase" the material.
# Extracted JSON Part
# {
#   "Company_Name": "AFM SafeChoice",
#   "Company Website": "N/A",
#   "Phone Number": "800.405.0222",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is about a carpet seal product from AFM SafeChoice. There is no information indicating that AFM SafeChoice is an injection molding company or would purchase nylon6,6 material."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 55
# Reading file name: Recycled carpet fibers applications_70_Kdielements.txt
#
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "KDI Elements",
#   "Company Website": "http://www.kdielements.com",
#   "Phone Number": "760.345.9933",
#   "Location": "California, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "KDI Elements is a design center that offers various flooring and surface materials including carpet. The context mentions they use nylon carpet fiber, so they are likely to purchase nylon6,6 material for carpet production."
# }
# ```
#
# To summarize:
# - KDI Elements is a design center in California that offers flooring and surface materials
# - They specifically mention using nylon carpet fiber
# - The material provided is nylon6,6 which is a type of nylon
# - Since they use nylon for carpet production, they are likely to purchase more nylon material like nylon6,6
# The data is not in JSON format.
# Printing data Text:
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "KDI Elements",
#   "Company Website": "http://www.kdielements.com",
#   "Phone Number": "760.345.9933",
#   "Location": "California, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "KDI Elements is a design center that offers various flooring and surface materials including carpet. The context mentions they use nylon carpet fiber, so they are likely to purchase nylon6,6 material for carpet production."
# }
# ```
#
# To summarize:
# - KDI Elements is a design center in California that offers flooring and surface materials
# - They specifically mention using nylon carpet fiber
# - The material provided is nylon6,6 which is a type of nylon
# - Since they use nylon for carpet production, they are likely to purchase more nylon material like nylon6,6
# Printing data after removing backticks:
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "KDI Elements",
#   "Company Website": "http://www.kdielements.com",
#   "Phone Number": "760.345.9933",
#   "Location": "California, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "KDI Elements is a design center that offers various flooring and surface materials including carpet. The context mentions they use nylon carpet fiber, so they are likely to purchase nylon6,6 material for carpet production."
# }
# ```
#
# To summarize:
# - KDI Elements is a design center in California that offers flooring and surface materials
# - They specifically mention using nylon carpet fiber
# - The material provided is nylon6,6 which is a type of nylon
# - Since they use nylon for carpet production, they are likely to purchase more nylon material like nylon6,6
# Extracted JSON Part
# {
#   "Company_Name": "KDI Elements",
#   "Company Website": "http://www.kdielements.com",
#   "Phone Number": "760.345.9933",
#   "Location": "California, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "KDI Elements is a design center that offers various flooring and surface materials including carpet. The context mentions they use nylon carpet fiber, so they are likely to purchase nylon6,6 material for carpet production."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 56
# Reading file name: Recycled carpet fibers applications_21_Pfa.txt
#
#  Here is the extracted information in JSON format:
#
# ```JSON
# {
#   "Company_Name": "Polyurethane Foam Association",
#   "Company Website": "www.pfa.org",
#   "Phone Number": "865-657-9840",
#   "Location": "Loudon, TN, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The Polyurethane Foam Association represents companies that manufacture and use polyurethane foam, including for carpet cushion applications. The context mentions that flexible polyurethane foam makes up 85-90% of the carpet cushion market, so PFA member companies are likely to purchase nylon 6,6 for use in injection molding carpet cushion components."
# }
# ```
#
# To summarize, the Polyurethane Foam Association is likely to purchase nylon 6,6 because the context indicates that polyurethane foam is widely used in carpet cushion applications. As an industry association for polyurethane foam manufacturers and users, the PFA's member companies manufacture carpet cushion and other products using polyurethane foam. Nylon 6,6 can be used for injection molding various components in these products. So there is a high likelihood PFA members will purchase nylon 6,6 resin for their manufacturing processes.
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```JSON
# {
#   "Company_Name": "Polyurethane Foam Association",
#   "Company Website": "www.pfa.org",
#   "Phone Number": "865-657-9840",
#   "Location": "Loudon, TN, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The Polyurethane Foam Association represents companies that manufacture and use polyurethane foam, including for carpet cushion applications. The context mentions that flexible polyurethane foam makes up 85-90% of the carpet cushion market, so PFA member companies are likely to purchase nylon 6,6 for use in injection molding carpet cushion components."
# }
# ```
#
# To summarize, the Polyurethane Foam Association is likely to purchase nylon 6,6 because the context indicates that polyurethane foam is widely used in carpet cushion applications. As an industry association for polyurethane foam manufacturers and users, the PFA's member companies manufacture carpet cushion and other products using polyurethane foam. Nylon 6,6 can be used for injection molding various components in these products. So there is a high likelihood PFA members will purchase nylon 6,6 resin for their manufacturing processes.
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```JSON
# {
#   "Company_Name": "Polyurethane Foam Association",
#   "Company Website": "www.pfa.org",
#   "Phone Number": "865-657-9840",
#   "Location": "Loudon, TN, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The Polyurethane Foam Association represents companies that manufacture and use polyurethane foam, including for carpet cushion applications. The context mentions that flexible polyurethane foam makes up 85-90% of the carpet cushion market, so PFA member companies are likely to purchase nylon 6,6 for use in injection molding carpet cushion components."
# }
# ```
#
# To summarize, the Polyurethane Foam Association is likely to purchase nylon 6,6 because the context indicates that polyurethane foam is widely used in carpet cushion applications. As an industry association for polyurethane foam manufacturers and users, the PFA's member companies manufacture carpet cushion and other products using polyurethane foam. Nylon 6,6 can be used for injection molding various components in these products. So there is a high likelihood PFA members will purchase nylon 6,6 resin for their manufacturing processes.
# Extracted JSON Part
# {
#   "Company_Name": "Polyurethane Foam Association",
#   "Company Website": "www.pfa.org",
#   "Phone Number": "865-657-9840",
#   "Location": "Loudon, TN, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The Polyurethane Foam Association represents companies that manufacture and use polyurethane foam, including for carpet cushion applications. The context mentions that flexible polyurethane foam makes up 85-90% of the carpet cushion market, so PFA member companies are likely to purchase nylon 6,6 for use in injection molding carpet cushion components."
# }
# Data Type after extracting data: <class 'dict'>
#
# Current working directory: /home/ec2-user/SageMaker/AscendNotebook
# ================================
