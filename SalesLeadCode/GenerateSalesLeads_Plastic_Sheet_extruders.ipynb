# %%
# pip install -r "/home/ec2-user/SageMaker/AscendNotebook/ascendrequirements.txt"

# %%
""" To run this script, pass the following two parameters:

Parameter1, Parameter2

Parameter1 accepts one of the following values:
    "Nylon & Polyamide injection molders"
    "Plastic Profile Extruders"
    "Plastic Sheet extruders"
    "Recycled carpet fibers applications"
    "Nylon Compounders & Polyamide Compounders"
    
Parameter2 accept any material that you check whether a company will purchase it or not.

The following is an example command to run it.

# %run SalesLeadClassification.py "Plastic Sheet extruders" "nylon6,6"

"""

# %%
# %run SalesLeadClassification.py "Plastic Sheet extruders" "nylon6,6"
# Out:
# Search Term: Plastic Sheet extruders
# Number of Results to Query: nylon6,6
# Present working directory: /home/ec2-user/SageMaker/AscendNotebook
# Directory to save results: /home/ec2-user/SageMaker/AscendNotebook/CodeExecutionMetrics/
# Directory to save Sales Leads: /home/ec2-user/SageMaker/AscendNotebook/SalesLeadData/
# Starting NER job for Plastic Sheet extruders at: 2024-06-18 21:05:04
# Files Search Directory to Work: Plastic_Sheet_Extruders
# Current working directory: /home/ec2-user/SageMaker/AscendNotebook
#
# Current working directory: /home/ec2-user/SageMaker/AscendNotebook/Plastic_Sheet_Extruders
# ['Plastic Sheet extruders_19_Piedmontplastics.txt', 'Plastic Sheet extruders_56_Thyssenkrupp.txt', 'Plastic Sheet extruders_46_Signode.txt', 'Plastic Sheet extruders_94_Industrialextrusionmachinery.txt', 'Plastic Sheet extruders_84_Ensingerplastics.txt', 'Plastic Sheet extruders_16_Hitachizosen.txt', 'Plastic Sheet extruders_17_Battenfeld.txt', 'Plastic Sheet extruders_77_Envplastics.txt', 'Plastic Sheet extruders_21_Ptiextruders.txt', 'Plastic Sheet extruders_87_Farberplastics.txt', 'Plastic Sheet extruders_11_En.txt', 'Plastic Sheet extruders_67_Plaskolite.txt', 'Plastic Sheet extruders_43_Regal.txt', 'Plastic Sheet extruders_50_Plastic.txt', 'Plastic Sheet extruders_15_Selectplastics.txt', 'Plastic Sheet extruders_40_Simplyplastics.txt', 'Plastic Sheet extruders_14_Totalplastics.txt', 'Plastic Sheet extruders_33_Plasticstoday.txt', 'Plastic Sheet extruders_59_Forum.txt', 'Plastic Sheet extruders_78_Sigmaplasticsgroup.txt', 'Plastic Sheet extruders_49_Waddingtoneurope.txt', 'Plastic Sheet extruders_85_Kraussmaffei.txt', 'Plastic Sheet extruders_18_Dkplastics.txt', 'Plastic Sheet extruders_54_Community.txt', 'Plastic Sheet extruders_9_Apex.txt', 'Plastic Sheet extruders_3_Acmeplastics.txt', 'Plastic Sheet extruders_24_Diamat.txt', 'Plastic Sheet extruders_63_Acplasticsinc.txt', 'Plastic Sheet extruders_12_Highlandplastics.txt', 'Plastic Sheet extruders_45_Yjxplasticmachinery.txt', 'Plastic Sheet extruders_74_Na.txt', 'Plastic Sheet extruders_25_Extrudedplastics.txt', 'Plastic Sheet extruders_8_Goex.txt', 'Plastic Sheet extruders_95_Plastemart.txt', 'Plastic Sheet extruders_68_Uml.txt', 'Plastic Sheet extruders_80_Pennfibre.txt', 'Plastic Sheet extruders_23_Cpchem.txt', 'Plastic Sheet extruders_10_Goodnaturedproducts.txt', 'Plastic Sheet extruders_52_Coolsealusa.txt', 'Plastic Sheet extruders_89_Stcmach.txt', 'Plastic Sheet extruders_5_Acmeplastics.txt', 'Plastic Sheet extruders_13_Fkur.txt', 'Plastic Sheet extruders_55_Extrusionconsultinginc.txt', 'Plastic Sheet extruders_72_Technicmachines.txt', 'Plastic Sheet extruders_69_Sinoplast.txt', 'Plastic Sheet extruders_31_Chinaplasonline.txt', 'Plastic Sheet extruders_81_Europlas.txt', 'Plastic Sheet extruders_42_Alibaba.txt', 'Plastic Sheet extruders_4_Sherwoodind.txt', 'Plastic Sheet extruders_37_Advgauging.txt', 'Plastic Sheet extruders_88_Xometry.txt', 'Plastic Sheet extruders_92_Lesiteweld.txt', 'Plastic Sheet extruders_27_Orionplastics.txt', 'Plastic Sheet extruders_2_Arlingtonmachinery.txt', 'DDS8.pdf', 'Plastic Sheet extruders_20_Primexplastics.txt', 'Plastic Sheet extruders_39_Magazines.txt', 'Plastic Sheet extruders_73_Twi.txt', 'edwards-plastics-extruder-degassing-application-note.pdf', 'Plastic Sheet extruders_32_Plasticsmachinerymanufacturing.txt', 'Plastic Sheet extruders_29_Empirewest.txt', 'Plastic Sheet extruders_93_Plastiwin.txt']
# Reading File: 0
# Reading file name: Plastic Sheet extruders_19_Piedmontplastics.txt
#
#  Based on the context provided, here is the information extracted and response:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context talks about what extruded acrylic is and how it is made. It does not provide any information about an injection molding company that might purchase nylon6,6 material. So there is no data to predict if a company is likely to purchase the material."
# }
# ```
#
# The context provides general information about extruded acrylic and its properties, but does not mention any specific company that might purchase nylon6,6 material. There is no data to extract company details or predict if a company is likely to purchase the material. So I have responded with "N/A" and "Not likely to purchase" accordingly.
# The data is not in JSON format.
# Printing data Text:
#  Based on the context provided, here is the information extracted and response:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context talks about what extruded acrylic is and how it is made. It does not provide any information about an injection molding company that might purchase nylon6,6 material. So there is no data to predict if a company is likely to purchase the material."
# }
# ```
#
# The context provides general information about extruded acrylic and its properties, but does not mention any specific company that might purchase nylon6,6 material. There is no data to extract company details or predict if a company is likely to purchase the material. So I have responded with "N/A" and "Not likely to purchase" accordingly.
# Printing data after removing backticks:
#  Based on the context provided, here is the information extracted and response:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context talks about what extruded acrylic is and how it is made. It does not provide any information about an injection molding company that might purchase nylon6,6 material. So there is no data to predict if a company is likely to purchase the material."
# }
# ```
#
# The context provides general information about extruded acrylic and its properties, but does not mention any specific company that might purchase nylon6,6 material. There is no data to extract company details or predict if a company is likely to purchase the material. So I have responded with "N/A" and "Not likely to purchase" accordingly.
# Extracted JSON Part
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context talks about what extruded acrylic is and how it is made. It does not provide any information about an injection molding company that might purchase nylon6,6 material. So there is no data to predict if a company is likely to purchase the material."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 1
# Reading file name: Plastic Sheet extruders_56_Thyssenkrupp.txt
#
#  Based on the context provided, here is the information extracted in JSON format:
#
# ```json
# {
#   "Company_Name": "thyssenkrupp Engineered Plastics",
#   "Company Website": "https://www.thyssenkrupp-engineered-plastics.com",
#   "Phone Number": "877-246-7700",
#   "Location": "United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company manufactures and provides high-performance plastic materials. The material tag specifies nylon6,6 which is an engineering plastic. So the company is likely to purchase nylon6,6 for manufacturing plastic products."
# }
# ```
#
# To summarize:
# - The company name is thyssenkrupp Engineered Plastics
# - The website and phone number are provided in the context
# - The location can be inferred as United States based on the phone number
# - I predicted "Likely to purchase" as the company specializes in engineered plastics and nylon6,6 is an engineering plastic they may use.
# - The prediction reason explains why I think they are likely to purchase the nylon6,6 material.
# The data is not in JSON format.
# Printing data Text:
#  Based on the context provided, here is the information extracted in JSON format:
#
# ```json
# {
#   "Company_Name": "thyssenkrupp Engineered Plastics",
#   "Company Website": "https://www.thyssenkrupp-engineered-plastics.com",
#   "Phone Number": "877-246-7700",
#   "Location": "United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company manufactures and provides high-performance plastic materials. The material tag specifies nylon6,6 which is an engineering plastic. So the company is likely to purchase nylon6,6 for manufacturing plastic products."
# }
# ```
#
# To summarize:
# - The company name is thyssenkrupp Engineered Plastics
# - The website and phone number are provided in the context
# - The location can be inferred as United States based on the phone number
# - I predicted "Likely to purchase" as the company specializes in engineered plastics and nylon6,6 is an engineering plastic they may use.
# - The prediction reason explains why I think they are likely to purchase the nylon6,6 material.
# Printing data after removing backticks:
#  Based on the context provided, here is the information extracted in JSON format:
#
# ```json
# {
#   "Company_Name": "thyssenkrupp Engineered Plastics",
#   "Company Website": "https://www.thyssenkrupp-engineered-plastics.com",
#   "Phone Number": "877-246-7700",
#   "Location": "United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company manufactures and provides high-performance plastic materials. The material tag specifies nylon6,6 which is an engineering plastic. So the company is likely to purchase nylon6,6 for manufacturing plastic products."
# }
# ```
#
# To summarize:
# - The company name is thyssenkrupp Engineered Plastics
# - The website and phone number are provided in the context
# - The location can be inferred as United States based on the phone number
# - I predicted "Likely to purchase" as the company specializes in engineered plastics and nylon6,6 is an engineering plastic they may use.
# - The prediction reason explains why I think they are likely to purchase the nylon6,6 material.
# Extracted JSON Part
# {
#   "Company_Name": "thyssenkrupp Engineered Plastics",
#   "Company Website": "https://www.thyssenkrupp-engineered-plastics.com",
#   "Phone Number": "877-246-7700",
#   "Location": "United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company manufactures and provides high-performance plastic materials. The material tag specifies nylon6,6 which is an engineering plastic. So the company is likely to purchase nylon6,6 for manufacturing plastic products."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 2
# Reading file name: Plastic Sheet extruders_46_Signode.txt
#
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Signode",
#   "Company Website": "https://www.signode.com",
#   "Phone Number": "1-800-323-2464",
#   "Location": "Tampa, Florida, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company manufactures protective packaging solutions using plastics and other materials. They have capabilities for custom plastic sheet extrusion which indicates they likely use injection molding. Nylon 6,6 would be a good material choice for some of their applications like durable sheets."
# }
# ```
#
# To summarize, Signode seems to manufacture custom plastic sheets and other protective packaging products, so they likely use injection molding and would be interested in purchasing nylon 6,6 material. Their location, contact details, and website are provided in the extracted information. I predicted they are likely to purchase the material because nylon 6,6 has properties like high durability that would be useful for some of their applications.
# The data is not in JSON format.
# Printing data Text:
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Signode",
#   "Company Website": "https://www.signode.com",
#   "Phone Number": "1-800-323-2464",
#   "Location": "Tampa, Florida, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company manufactures protective packaging solutions using plastics and other materials. They have capabilities for custom plastic sheet extrusion which indicates they likely use injection molding. Nylon 6,6 would be a good material choice for some of their applications like durable sheets."
# }
# ```
#
# To summarize, Signode seems to manufacture custom plastic sheets and other protective packaging products, so they likely use injection molding and would be interested in purchasing nylon 6,6 material. Their location, contact details, and website are provided in the extracted information. I predicted they are likely to purchase the material because nylon 6,6 has properties like high durability that would be useful for some of their applications.
# Printing data after removing backticks:
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Signode",
#   "Company Website": "https://www.signode.com",
#   "Phone Number": "1-800-323-2464",
#   "Location": "Tampa, Florida, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company manufactures protective packaging solutions using plastics and other materials. They have capabilities for custom plastic sheet extrusion which indicates they likely use injection molding. Nylon 6,6 would be a good material choice for some of their applications like durable sheets."
# }
# ```
#
# To summarize, Signode seems to manufacture custom plastic sheets and other protective packaging products, so they likely use injection molding and would be interested in purchasing nylon 6,6 material. Their location, contact details, and website are provided in the extracted information. I predicted they are likely to purchase the material because nylon 6,6 has properties like high durability that would be useful for some of their applications.
# Extracted JSON Part
# {
#   "Company_Name": "Signode",
#   "Company Website": "https://www.signode.com",
#   "Phone Number": "1-800-323-2464",
#   "Location": "Tampa, Florida, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company manufactures protective packaging solutions using plastics and other materials. They have capabilities for custom plastic sheet extrusion which indicates they likely use injection molding. Nylon 6,6 would be a good material choice for some of their applications like durable sheets."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 3
# Reading file name: Plastic Sheet extruders_94_Industrialextrusionmachinery.txt
#
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Industrialextrusionmachinery.com",
#   "Company Website": "http://Industrialextrusionmachinery.com",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company manufactures and supplies extrusion machinery and equipment. Since nylon 6,6 is a common extrusion material, it is likely they would purchase it for use in their equipment and machinery."
# }
# ```
#
# The company website and name are provided in the context. Other details like phone number and location are not available. Based on the information that they manufacture and supply extrusion equipment, it seems likely they would purchase nylon 6,6 which is provided as the material tag. Nylon 6,6 is commonly used in extrusion processes so it aligns with their business operations.
# The data is not in JSON format.
# Printing data Text:
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Industrialextrusionmachinery.com",
#   "Company Website": "http://Industrialextrusionmachinery.com",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company manufactures and supplies extrusion machinery and equipment. Since nylon 6,6 is a common extrusion material, it is likely they would purchase it for use in their equipment and machinery."
# }
# ```
#
# The company website and name are provided in the context. Other details like phone number and location are not available. Based on the information that they manufacture and supply extrusion equipment, it seems likely they would purchase nylon 6,6 which is provided as the material tag. Nylon 6,6 is commonly used in extrusion processes so it aligns with their business operations.
# Printing data after removing backticks:
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Industrialextrusionmachinery.com",
#   "Company Website": "http://Industrialextrusionmachinery.com",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company manufactures and supplies extrusion machinery and equipment. Since nylon 6,6 is a common extrusion material, it is likely they would purchase it for use in their equipment and machinery."
# }
# ```
#
# The company website and name are provided in the context. Other details like phone number and location are not available. Based on the information that they manufacture and supply extrusion equipment, it seems likely they would purchase nylon 6,6 which is provided as the material tag. Nylon 6,6 is commonly used in extrusion processes so it aligns with their business operations.
# Extracted JSON Part
# {
#   "Company_Name": "Industrialextrusionmachinery.com",
#   "Company Website": "http://Industrialextrusionmachinery.com",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company manufactures and supplies extrusion machinery and equipment. Since nylon 6,6 is a common extrusion material, it is likely they would purchase it for use in their equipment and machinery."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 4
# Reading file name: Plastic Sheet extruders_84_Ensingerplastics.txt
#
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Ensinger",
#   "Company Website": "https://www.ensingerplastics.com/",
#   "Phone Number": "N/A",
#   "Location": "Multiple locations in Europe, Asia, and the Americas",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Ensinger manufactures and supplies various nylon plastic materials, including nylon 6/6, which matches the material tag provided. As a major supplier of these materials, it is likely they would purchase nylon 6/6 to manufacture additional stock."
# }
# ```
#
# I extracted Ensinger as the company name, provided their website, and listed their multiple international locations. Since they are a large supplier of various nylon materials, I predicted they would likely purchase more nylon 6/6 to manufacture additional stock shapes. I wasn't able to find a specific phone number in the provided context.
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Ensinger",
#   "Company Website": "https://www.ensingerplastics.com/",
#   "Phone Number": "N/A",
#   "Location": "Multiple locations in Europe, Asia, and the Americas",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Ensinger manufactures and supplies various nylon plastic materials, including nylon 6/6, which matches the material tag provided. As a major supplier of these materials, it is likely they would purchase nylon 6/6 to manufacture additional stock."
# }
# ```
#
# I extracted Ensinger as the company name, provided their website, and listed their multiple international locations. Since they are a large supplier of various nylon materials, I predicted they would likely purchase more nylon 6/6 to manufacture additional stock shapes. I wasn't able to find a specific phone number in the provided context.
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Ensinger",
#   "Company Website": "https://www.ensingerplastics.com/",
#   "Phone Number": "N/A",
#   "Location": "Multiple locations in Europe, Asia, and the Americas",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Ensinger manufactures and supplies various nylon plastic materials, including nylon 6/6, which matches the material tag provided. As a major supplier of these materials, it is likely they would purchase nylon 6/6 to manufacture additional stock."
# }
# ```
#
# I extracted Ensinger as the company name, provided their website, and listed their multiple international locations. Since they are a large supplier of various nylon materials, I predicted they would likely purchase more nylon 6/6 to manufacture additional stock shapes. I wasn't able to find a specific phone number in the provided context.
# Extracted JSON Part
# {
#   "Company_Name": "Ensinger",
#   "Company Website": "https://www.ensingerplastics.com/",
#   "Phone Number": "N/A",
#   "Location": "Multiple locations in Europe, Asia, and the Americas",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Ensinger manufactures and supplies various nylon plastic materials, including nylon 6/6, which matches the material tag provided. As a major supplier of these materials, it is likely they would purchase nylon 6/6 to manufacture additional stock."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 5
# Reading file name: Plastic Sheet extruders_16_Hitachizosen.txt
#
#  Here is the extracted information in JSON format:
#
# ```JSON
# {
#   "Company_Name": "Hitachi Zosen Corporation",
#   "Company Website": "https://www.hitachizosen.co.jp/english/",
#   "Phone Number": "N/A",
#   "Location": "Osaka, Japan",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Hitachi Zosen Corporation manufactures plastic film and sheet extruding equipment that can process nylon 6,6. They have capabilities to process high temperature super engineering plastics up to 450°C, which would include nylon 6,6. As a leading equipment manufacturer in this space, they are likely to purchase nylon 6,6 material for testing and improving their equipment."
# }
# ```
#
# To summarize, Hitachi Zosen Corporation is predicted to likely purchase nylon 6,6 because they manufacture plastic extruding equipment capable of processing high temperature engineering plastics like nylon 6,6. As an equipment manufacturer, they would likely test and improve their equipment using such materials. The company location, website and products match the context of a company that would potentially purchase the specified material.
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```JSON
# {
#   "Company_Name": "Hitachi Zosen Corporation",
#   "Company Website": "https://www.hitachizosen.co.jp/english/",
#   "Phone Number": "N/A",
#   "Location": "Osaka, Japan",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Hitachi Zosen Corporation manufactures plastic film and sheet extruding equipment that can process nylon 6,6. They have capabilities to process high temperature super engineering plastics up to 450°C, which would include nylon 6,6. As a leading equipment manufacturer in this space, they are likely to purchase nylon 6,6 material for testing and improving their equipment."
# }
# ```
#
# To summarize, Hitachi Zosen Corporation is predicted to likely purchase nylon 6,6 because they manufacture plastic extruding equipment capable of processing high temperature engineering plastics like nylon 6,6. As an equipment manufacturer, they would likely test and improve their equipment using such materials. The company location, website and products match the context of a company that would potentially purchase the specified material.
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```JSON
# {
#   "Company_Name": "Hitachi Zosen Corporation",
#   "Company Website": "https://www.hitachizosen.co.jp/english/",
#   "Phone Number": "N/A",
#   "Location": "Osaka, Japan",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Hitachi Zosen Corporation manufactures plastic film and sheet extruding equipment that can process nylon 6,6. They have capabilities to process high temperature super engineering plastics up to 450°C, which would include nylon 6,6. As a leading equipment manufacturer in this space, they are likely to purchase nylon 6,6 material for testing and improving their equipment."
# }
# ```
#
# To summarize, Hitachi Zosen Corporation is predicted to likely purchase nylon 6,6 because they manufacture plastic extruding equipment capable of processing high temperature engineering plastics like nylon 6,6. As an equipment manufacturer, they would likely test and improve their equipment using such materials. The company location, website and products match the context of a company that would potentially purchase the specified material.
# Extracted JSON Part
# {
#   "Company_Name": "Hitachi Zosen Corporation",
#   "Company Website": "https://www.hitachizosen.co.jp/english/",
#   "Phone Number": "N/A",
#   "Location": "Osaka, Japan",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Hitachi Zosen Corporation manufactures plastic film and sheet extruding equipment that can process nylon 6,6. They have capabilities to process high temperature super engineering plastics up to 450°C, which would include nylon 6,6. As a leading equipment manufacturer in this space, they are likely to purchase nylon 6,6 material for testing and improving their equipment."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 6
# Reading file name: Plastic Sheet extruders_17_Battenfeld.txt
#
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "battenfeld-cincinnati",
#   "Company Website": "https://www.battenfeld-cincinnati.com",
#   "Phone Number": "N/A",
#   "Location": "Germany",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company battenfeld-cincinnati manufactures extrusion lines and equipment for plastic sheet and board extrusion. They have capabilities for PVC sheet extrusion. Since nylon6,6 can be used to manufacture plastic sheets, the company is likely to purchase nylon6,6 material for their sheet extrusion lines."
# }
# ```
#
# I extracted the company name, website, and location details from the context. The phone number was not provided. Based on the details that battenfeld-cincinnati manufactures extrusion equipment for plastic sheets and has PVC sheet extrusion capabilities, I predicted they are likely to purchase nylon6,6 material which can also be used to manufacture plastic sheets.
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "battenfeld-cincinnati",
#   "Company Website": "https://www.battenfeld-cincinnati.com",
#   "Phone Number": "N/A",
#   "Location": "Germany",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company battenfeld-cincinnati manufactures extrusion lines and equipment for plastic sheet and board extrusion. They have capabilities for PVC sheet extrusion. Since nylon6,6 can be used to manufacture plastic sheets, the company is likely to purchase nylon6,6 material for their sheet extrusion lines."
# }
# ```
#
# I extracted the company name, website, and location details from the context. The phone number was not provided. Based on the details that battenfeld-cincinnati manufactures extrusion equipment for plastic sheets and has PVC sheet extrusion capabilities, I predicted they are likely to purchase nylon6,6 material which can also be used to manufacture plastic sheets.
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "battenfeld-cincinnati",
#   "Company Website": "https://www.battenfeld-cincinnati.com",
#   "Phone Number": "N/A",
#   "Location": "Germany",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company battenfeld-cincinnati manufactures extrusion lines and equipment for plastic sheet and board extrusion. They have capabilities for PVC sheet extrusion. Since nylon6,6 can be used to manufacture plastic sheets, the company is likely to purchase nylon6,6 material for their sheet extrusion lines."
# }
# ```
#
# I extracted the company name, website, and location details from the context. The phone number was not provided. Based on the details that battenfeld-cincinnati manufactures extrusion equipment for plastic sheets and has PVC sheet extrusion capabilities, I predicted they are likely to purchase nylon6,6 material which can also be used to manufacture plastic sheets.
# Extracted JSON Part
# {
#   "Company_Name": "battenfeld-cincinnati",
#   "Company Website": "https://www.battenfeld-cincinnati.com",
#   "Phone Number": "N/A",
#   "Location": "Germany",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company battenfeld-cincinnati manufactures extrusion lines and equipment for plastic sheet and board extrusion. They have capabilities for PVC sheet extrusion. Since nylon6,6 can be used to manufacture plastic sheets, the company is likely to purchase nylon6,6 material for their sheet extrusion lines."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 7
# Reading file name: Plastic Sheet extruders_77_Envplastics.txt
#
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Envision Plastics & Design",
#   "Company Website": "https://www.envisionplastics.com/",
#   "Phone Number": "(651) 765-6730",
#   "Location": "White Bear Lake, MN 55110",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Envision Plastics & Design is a plastic fabrication company that manufactures custom plastic enclosures and parts. They have capabilities in CNC milling, bending, welding, etc. which indicates they likely use plastics like nylon6,6 for their fabrication processes. Being a plastics manufacturer, they are likely to purchase raw plastic materials like nylon6,6."
# }
# ```
#
# The key information that indicates Envision Plastics & Design is likely to purchase nylon6,6:
#
# - They specialize in custom plastic enclosures and parts fabrication using processes like CNC milling, bending, welding etc.
# - They manufacture the enclosures from raw plastic materials, so would need to purchase plastics like nylon6,6.
# - As a plastics fabricator, they are likely to use engineering grades plastics like nylon6,6 that have good mechanical properties.
# The data is not in JSON format.
# Printing data Text:
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Envision Plastics & Design",
#   "Company Website": "https://www.envisionplastics.com/",
#   "Phone Number": "(651) 765-6730",
#   "Location": "White Bear Lake, MN 55110",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Envision Plastics & Design is a plastic fabrication company that manufactures custom plastic enclosures and parts. They have capabilities in CNC milling, bending, welding, etc. which indicates they likely use plastics like nylon6,6 for their fabrication processes. Being a plastics manufacturer, they are likely to purchase raw plastic materials like nylon6,6."
# }
# ```
#
# The key information that indicates Envision Plastics & Design is likely to purchase nylon6,6:
#
# - They specialize in custom plastic enclosures and parts fabrication using processes like CNC milling, bending, welding etc.
# - They manufacture the enclosures from raw plastic materials, so would need to purchase plastics like nylon6,6.
# - As a plastics fabricator, they are likely to use engineering grades plastics like nylon6,6 that have good mechanical properties.
# Printing data after removing backticks:
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Envision Plastics & Design",
#   "Company Website": "https://www.envisionplastics.com/",
#   "Phone Number": "(651) 765-6730",
#   "Location": "White Bear Lake, MN 55110",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Envision Plastics & Design is a plastic fabrication company that manufactures custom plastic enclosures and parts. They have capabilities in CNC milling, bending, welding, etc. which indicates they likely use plastics like nylon6,6 for their fabrication processes. Being a plastics manufacturer, they are likely to purchase raw plastic materials like nylon6,6."
# }
# ```
#
# The key information that indicates Envision Plastics & Design is likely to purchase nylon6,6:
#
# - They specialize in custom plastic enclosures and parts fabrication using processes like CNC milling, bending, welding etc.
# - They manufacture the enclosures from raw plastic materials, so would need to purchase plastics like nylon6,6.
# - As a plastics fabricator, they are likely to use engineering grades plastics like nylon6,6 that have good mechanical properties.
# Extracted JSON Part
# {
#   "Company_Name": "Envision Plastics & Design",
#   "Company Website": "https://www.envisionplastics.com/",
#   "Phone Number": "(651) 765-6730",
#   "Location": "White Bear Lake, MN 55110",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Envision Plastics & Design is a plastic fabrication company that manufactures custom plastic enclosures and parts. They have capabilities in CNC milling, bending, welding, etc. which indicates they likely use plastics like nylon6,6 for their fabrication processes. Being a plastics manufacturer, they are likely to purchase raw plastic materials like nylon6,6."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 8
# Reading file name: Plastic Sheet extruders_21_Ptiextruders.txt
#
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Processing Technologies International, LLC",
#   "Company Website": "https://www.ptiextruders.com",
#   "Phone Number": "630.585.5800",
#   "Location": "Aurora, Illinois, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "PTi specializes in plastic sheet extrusion machinery and equipment. Nylon 6,6 is a common plastic material used in injection molding and extrusion applications. As a manufacturer of extrusion equipment, PTi would likely purchase nylon 6,6 for testing and development purposes."
# }
# ```
#
# To summarize:
# - PTi is a manufacturer of plastic sheet extrusion machinery
# - Nylon 6,6 is a common plastic used in injection molding and extrusion
# - As an extrusion equipment company, PTi would likely purchase nylon 6,6 to use for testing and development of their equipment
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Processing Technologies International, LLC",
#   "Company Website": "https://www.ptiextruders.com",
#   "Phone Number": "630.585.5800",
#   "Location": "Aurora, Illinois, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "PTi specializes in plastic sheet extrusion machinery and equipment. Nylon 6,6 is a common plastic material used in injection molding and extrusion applications. As a manufacturer of extrusion equipment, PTi would likely purchase nylon 6,6 for testing and development purposes."
# }
# ```
#
# To summarize:
# - PTi is a manufacturer of plastic sheet extrusion machinery
# - Nylon 6,6 is a common plastic used in injection molding and extrusion
# - As an extrusion equipment company, PTi would likely purchase nylon 6,6 to use for testing and development of their equipment
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Processing Technologies International, LLC",
#   "Company Website": "https://www.ptiextruders.com",
#   "Phone Number": "630.585.5800",
#   "Location": "Aurora, Illinois, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "PTi specializes in plastic sheet extrusion machinery and equipment. Nylon 6,6 is a common plastic material used in injection molding and extrusion applications. As a manufacturer of extrusion equipment, PTi would likely purchase nylon 6,6 for testing and development purposes."
# }
# ```
#
# To summarize:
# - PTi is a manufacturer of plastic sheet extrusion machinery
# - Nylon 6,6 is a common plastic used in injection molding and extrusion
# - As an extrusion equipment company, PTi would likely purchase nylon 6,6 to use for testing and development of their equipment
# Extracted JSON Part
# {
#   "Company_Name": "Processing Technologies International, LLC",
#   "Company Website": "https://www.ptiextruders.com",
#   "Phone Number": "630.585.5800",
#   "Location": "Aurora, Illinois, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "PTi specializes in plastic sheet extrusion machinery and equipment. Nylon 6,6 is a common plastic material used in injection molding and extrusion applications. As a manufacturer of extrusion equipment, PTi would likely purchase nylon 6,6 for testing and development purposes."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 9
# Reading file name: Plastic Sheet extruders_87_Farberplastics.txt
#
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "Farber Plastics, Inc.",
#   "Company Website": "www.farberplastics.com",
#   "Phone Number": "(516) 378-4860",
#   "Location": "Freeport, NY, United States",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The company specializes in manufacturing PET and HIPS plastic films and sheets. There is no indication they use nylon6,6 material. They seem focused on their core PET and HIPS products rather than exploring new materials."
# }
# ```
#
# To summarize, Farber Plastics specializes in PET and HIPS plastic films and sheets. They do not seem to manufacture products with nylon6,6 based on the information provided. As a result, I have predicted they are not likely to purchase nylon6,6 material. My reason is that they appear focused on their core PET and HIPS products rather than exploring new materials. Please let me know if you need any clarification or have additional information to add.
# The data is not in JSON format.
# Printing data Text:
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "Farber Plastics, Inc.",
#   "Company Website": "www.farberplastics.com",
#   "Phone Number": "(516) 378-4860",
#   "Location": "Freeport, NY, United States",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The company specializes in manufacturing PET and HIPS plastic films and sheets. There is no indication they use nylon6,6 material. They seem focused on their core PET and HIPS products rather than exploring new materials."
# }
# ```
#
# To summarize, Farber Plastics specializes in PET and HIPS plastic films and sheets. They do not seem to manufacture products with nylon6,6 based on the information provided. As a result, I have predicted they are not likely to purchase nylon6,6 material. My reason is that they appear focused on their core PET and HIPS products rather than exploring new materials. Please let me know if you need any clarification or have additional information to add.
# Printing data after removing backticks:
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "Farber Plastics, Inc.",
#   "Company Website": "www.farberplastics.com",
#   "Phone Number": "(516) 378-4860",
#   "Location": "Freeport, NY, United States",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The company specializes in manufacturing PET and HIPS plastic films and sheets. There is no indication they use nylon6,6 material. They seem focused on their core PET and HIPS products rather than exploring new materials."
# }
# ```
#
# To summarize, Farber Plastics specializes in PET and HIPS plastic films and sheets. They do not seem to manufacture products with nylon6,6 based on the information provided. As a result, I have predicted they are not likely to purchase nylon6,6 material. My reason is that they appear focused on their core PET and HIPS products rather than exploring new materials. Please let me know if you need any clarification or have additional information to add.
# Extracted JSON Part
# {
#   "Company_Name": "Farber Plastics, Inc.",
#   "Company Website": "www.farberplastics.com",
#   "Phone Number": "(516) 378-4860",
#   "Location": "Freeport, NY, United States",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The company specializes in manufacturing PET and HIPS plastic films and sheets. There is no indication they use nylon6,6 material. They seem focused on their core PET and HIPS products rather than exploring new materials."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 10
# Reading file name: Plastic Sheet extruders_11_En.txt
#
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is a Wikipedia article about plastic extrusion processes. It does not contain any information about a specific company that might purchase nylon6,6 material. There are no details provided about an injection molding company to evaluate if they would likely purchase the material."
# }
# ```
#
# The context tag contains a general Wikipedia article about plastic extrusion processes. It does not mention any specific company details that could be used to determine if a company is likely to purchase the nylon6,6 material provided in the material tag. Without more specific company information, I cannot make a prediction on whether a company would purchase the material. So my prediction is "Not likely to purchase" along with the reasoning that there is insufficient company data in the context. The other response fields are set to "N/A" since no relevant company details are provided.
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is a Wikipedia article about plastic extrusion processes. It does not contain any information about a specific company that might purchase nylon6,6 material. There are no details provided about an injection molding company to evaluate if they would likely purchase the material."
# }
# ```
#
# The context tag contains a general Wikipedia article about plastic extrusion processes. It does not mention any specific company details that could be used to determine if a company is likely to purchase the nylon6,6 material provided in the material tag. Without more specific company information, I cannot make a prediction on whether a company would purchase the material. So my prediction is "Not likely to purchase" along with the reasoning that there is insufficient company data in the context. The other response fields are set to "N/A" since no relevant company details are provided.
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is a Wikipedia article about plastic extrusion processes. It does not contain any information about a specific company that might purchase nylon6,6 material. There are no details provided about an injection molding company to evaluate if they would likely purchase the material."
# }
# ```
#
# The context tag contains a general Wikipedia article about plastic extrusion processes. It does not mention any specific company details that could be used to determine if a company is likely to purchase the nylon6,6 material provided in the material tag. Without more specific company information, I cannot make a prediction on whether a company would purchase the material. So my prediction is "Not likely to purchase" along with the reasoning that there is insufficient company data in the context. The other response fields are set to "N/A" since no relevant company details are provided.
# Extracted JSON Part
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is a Wikipedia article about plastic extrusion processes. It does not contain any information about a specific company that might purchase nylon6,6 material. There are no details provided about an injection molding company to evaluate if they would likely purchase the material."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 11
# Reading file name: Plastic Sheet extruders_67_Plaskolite.txt
#
#  Based on the context provided, here is the information extracted and likelihood of the company purchasing nylon6,6 material:
#
# ```json
# {
#   "Company_Name": "Plaskolite",
#   "Company Website": "https://www.plaskolite.com",
#   "Phone Number": "800-848-9124",
#   "Location": "Columbus, Ohio, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Plaskolite manufactures and provides thermoplastic sheets, polymers, and other plastic materials. They likely use nylon6,6 for injection molding of their products."
# }
# ```
#
# I have predicted that Plaskolite is likely to purchase nylon6,6 because they manufacture thermoplastic sheets, polymers, and other plastic materials. Nylon6,6 is a common engineering thermoplastic used for injection molding, so it aligns well with Plaskolite's offerings. Additionally, the context mentions they provide custom profiles, sheets, and polymers in over 150 grades. So they likely have use for nylon6,6 in their manufacturing and product lines.
# The data is not in JSON format.
# Printing data Text:
#  Based on the context provided, here is the information extracted and likelihood of the company purchasing nylon6,6 material:
#
# ```json
# {
#   "Company_Name": "Plaskolite",
#   "Company Website": "https://www.plaskolite.com",
#   "Phone Number": "800-848-9124",
#   "Location": "Columbus, Ohio, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Plaskolite manufactures and provides thermoplastic sheets, polymers, and other plastic materials. They likely use nylon6,6 for injection molding of their products."
# }
# ```
#
# I have predicted that Plaskolite is likely to purchase nylon6,6 because they manufacture thermoplastic sheets, polymers, and other plastic materials. Nylon6,6 is a common engineering thermoplastic used for injection molding, so it aligns well with Plaskolite's offerings. Additionally, the context mentions they provide custom profiles, sheets, and polymers in over 150 grades. So they likely have use for nylon6,6 in their manufacturing and product lines.
# Printing data after removing backticks:
#  Based on the context provided, here is the information extracted and likelihood of the company purchasing nylon6,6 material:
#
# ```json
# {
#   "Company_Name": "Plaskolite",
#   "Company Website": "https://www.plaskolite.com",
#   "Phone Number": "800-848-9124",
#   "Location": "Columbus, Ohio, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Plaskolite manufactures and provides thermoplastic sheets, polymers, and other plastic materials. They likely use nylon6,6 for injection molding of their products."
# }
# ```
#
# I have predicted that Plaskolite is likely to purchase nylon6,6 because they manufacture thermoplastic sheets, polymers, and other plastic materials. Nylon6,6 is a common engineering thermoplastic used for injection molding, so it aligns well with Plaskolite's offerings. Additionally, the context mentions they provide custom profiles, sheets, and polymers in over 150 grades. So they likely have use for nylon6,6 in their manufacturing and product lines.
# Extracted JSON Part
# {
#   "Company_Name": "Plaskolite",
#   "Company Website": "https://www.plaskolite.com",
#   "Phone Number": "800-848-9124",
# ...
# Extracted JSON Part
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The given context does not provide any information about a specific company. It is an informational article explaining the plastic extrusion process. There is no data to determine if a company is likely to purchase nylon6,6 material."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 58
# Reading file name: edwards-plastics-extruder-degassing-application-note.pdf
#
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The context talks in detail about various extrusion processes like pipe & tubing extrusion, film & sheet extrusion etc. that use nylon6,6 material. It also mentions how degassing is an important part of these processes which improves the quality of the end product. Since the context focuses on usage and applications of nylon6,6 in injection molding processes, companies doing such extrusion work are likely to purchase nylon6,6 material."
# }
# ```
#
# The context does not provide any specific company name, website, phone number or location details. So I have put "N/A" for those fields. But based on the detailed description of how nylon6,6 is used in various injection molding processes, I think companies doing such work are likely to purchase nylon6,6 material. Hence I have predicted "Likely to purchase" and provided the reasoning for my prediction.
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The context talks in detail about various extrusion processes like pipe & tubing extrusion, film & sheet extrusion etc. that use nylon6,6 material. It also mentions how degassing is an important part of these processes which improves the quality of the end product. Since the context focuses on usage and applications of nylon6,6 in injection molding processes, companies doing such extrusion work are likely to purchase nylon6,6 material."
# }
# ```
#
# The context does not provide any specific company name, website, phone number or location details. So I have put "N/A" for those fields. But based on the detailed description of how nylon6,6 is used in various injection molding processes, I think companies doing such work are likely to purchase nylon6,6 material. Hence I have predicted "Likely to purchase" and provided the reasoning for my prediction.
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The context talks in detail about various extrusion processes like pipe & tubing extrusion, film & sheet extrusion etc. that use nylon6,6 material. It also mentions how degassing is an important part of these processes which improves the quality of the end product. Since the context focuses on usage and applications of nylon6,6 in injection molding processes, companies doing such extrusion work are likely to purchase nylon6,6 material."
# }
# ```
#
# The context does not provide any specific company name, website, phone number or location details. So I have put "N/A" for those fields. But based on the detailed description of how nylon6,6 is used in various injection molding processes, I think companies doing such work are likely to purchase nylon6,6 material. Hence I have predicted "Likely to purchase" and provided the reasoning for my prediction.
# Extracted JSON Part
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The context talks in detail about various extrusion processes like pipe & tubing extrusion, film & sheet extrusion etc. that use nylon6,6 material. It also mentions how degassing is an important part of these processes which improves the quality of the end product. Since the context focuses on usage and applications of nylon6,6 in injection molding processes, companies doing such extrusion work are likely to purchase nylon6,6 material."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 59
# Reading file name: Plastic Sheet extruders_32_Plasticsmachinerymanufacturing.txt
#
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```JSON
# {
#   "Company_Name": "Processing Technologies International (PTi) LLC",
#   "Company Website": "www.ptiextruders.com",
#   "Phone Number": "630-585-5800",
#   "Location": "Aurora, Ill",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "PTi manufactures extruders that can process nylon 6,6. The article describes their new high-speed sheet extruder model SGHS3500-36D that can process a variety of resins including PP and PET. As an extruder manufacturer, they are likely to purchase nylon 6,6 to use in testing and developing their equipment."
# }
# ```
#
# To summarize, PTi is an extruder manufacturer that can process a variety of resins. Since nylon 6,6 is a common resin used in extrusion applications, it is likely that PTi would purchase some to test in their equipment as part of the development process. The location and contact details were also extracted from the context.
# The data is not in JSON format.
# Printing data Text:
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```JSON
# {
#   "Company_Name": "Processing Technologies International (PTi) LLC",
#   "Company Website": "www.ptiextruders.com",
#   "Phone Number": "630-585-5800",
#   "Location": "Aurora, Ill",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "PTi manufactures extruders that can process nylon 6,6. The article describes their new high-speed sheet extruder model SGHS3500-36D that can process a variety of resins including PP and PET. As an extruder manufacturer, they are likely to purchase nylon 6,6 to use in testing and developing their equipment."
# }
# ```
#
# To summarize, PTi is an extruder manufacturer that can process a variety of resins. Since nylon 6,6 is a common resin used in extrusion applications, it is likely that PTi would purchase some to test in their equipment as part of the development process. The location and contact details were also extracted from the context.
# Printing data after removing backticks:
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```JSON
# {
#   "Company_Name": "Processing Technologies International (PTi) LLC",
#   "Company Website": "www.ptiextruders.com",
#   "Phone Number": "630-585-5800",
#   "Location": "Aurora, Ill",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "PTi manufactures extruders that can process nylon 6,6. The article describes their new high-speed sheet extruder model SGHS3500-36D that can process a variety of resins including PP and PET. As an extruder manufacturer, they are likely to purchase nylon 6,6 to use in testing and developing their equipment."
# }
# ```
#
# To summarize, PTi is an extruder manufacturer that can process a variety of resins. Since nylon 6,6 is a common resin used in extrusion applications, it is likely that PTi would purchase some to test in their equipment as part of the development process. The location and contact details were also extracted from the context.
# Extracted JSON Part
# {
#   "Company_Name": "Processing Technologies International (PTi) LLC",
#   "Company Website": "www.ptiextruders.com",
#   "Phone Number": "630-585-5800",
#   "Location": "Aurora, Ill",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "PTi manufactures extruders that can process nylon 6,6. The article describes their new high-speed sheet extruder model SGHS3500-36D that can process a variety of resins including PP and PET. As an extruder manufacturer, they are likely to purchase nylon 6,6 to use in testing and developing their equipment."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 60
# Reading file name: Plastic Sheet extruders_29_Empirewest.txt
#
#  Based on the context provided, here is the information extracted in JSON format:
#
# ```json
# {
#   "Company_Name": "Empire West Inc.",
#   "Company Website": "https://www.empirewest.com",
#   "Phone Number": "1-800-521-4261",
#   "Location": "United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Empire West Inc. specializes in thermoforming and extrusion processes for plastics. The material provided, nylon6,6, is a common plastic used in injection molding and extrusion. Since Empire West works with plastics and extrusion, they are likely to purchase nylon6,6 for use in their manufacturing processes."
# }
# ```
#
# The key information that indicates Empire West is likely to purchase nylon6,6 is:
#
# - They specialize in thermoforming and extrusion of plastics
# - Nylon6,6 is a common plastic used in injection molding and extrusion
# - Their core business involves working with plastics for manufacturing
#
# Therefore, I have predicted "Likely to purchase" along with the reasoning that nylon6,6 aligns with their business operations and expertise.
# The data is not in JSON format.
# Printing data Text:
#  Based on the context provided, here is the information extracted in JSON format:
#
# ```json
# {
#   "Company_Name": "Empire West Inc.",
#   "Company Website": "https://www.empirewest.com",
#   "Phone Number": "1-800-521-4261",
#   "Location": "United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Empire West Inc. specializes in thermoforming and extrusion processes for plastics. The material provided, nylon6,6, is a common plastic used in injection molding and extrusion. Since Empire West works with plastics and extrusion, they are likely to purchase nylon6,6 for use in their manufacturing processes."
# }
# ```
#
# The key information that indicates Empire West is likely to purchase nylon6,6 is:
#
# - They specialize in thermoforming and extrusion of plastics
# - Nylon6,6 is a common plastic used in injection molding and extrusion
# - Their core business involves working with plastics for manufacturing
#
# Therefore, I have predicted "Likely to purchase" along with the reasoning that nylon6,6 aligns with their business operations and expertise.
# Printing data after removing backticks:
#  Based on the context provided, here is the information extracted in JSON format:
#
# ```json
# {
#   "Company_Name": "Empire West Inc.",
#   "Company Website": "https://www.empirewest.com",
#   "Phone Number": "1-800-521-4261",
#   "Location": "United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Empire West Inc. specializes in thermoforming and extrusion processes for plastics. The material provided, nylon6,6, is a common plastic used in injection molding and extrusion. Since Empire West works with plastics and extrusion, they are likely to purchase nylon6,6 for use in their manufacturing processes."
# }
# ```
#
# The key information that indicates Empire West is likely to purchase nylon6,6 is:
#
# - They specialize in thermoforming and extrusion of plastics
# - Nylon6,6 is a common plastic used in injection molding and extrusion
# - Their core business involves working with plastics for manufacturing
#
# Therefore, I have predicted "Likely to purchase" along with the reasoning that nylon6,6 aligns with their business operations and expertise.
# Extracted JSON Part
# {
#   "Company_Name": "Empire West Inc.",
#   "Company Website": "https://www.empirewest.com",
#   "Phone Number": "1-800-521-4261",
#   "Location": "United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Empire West Inc. specializes in thermoforming and extrusion processes for plastics. The material provided, nylon6,6, is a common plastic used in injection molding and extrusion. Since Empire West works with plastics and extrusion, they are likely to purchase nylon6,6 for use in their manufacturing processes."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 61
# Reading file name: Plastic Sheet extruders_93_Plastiwin.txt
#
#  Based on the context provided, here is the information extracted in JSON format:
#
# ```json
# {
#   "Company_Name": "PlastiWin Capital Equipment LLC",
#   "Company Website": "https://www.plastiwin.com/",
#   "Phone Number": "(330) 998-6738",
#   "Location": "Twinsburg, OH, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company sells used plastic extrusion equipment and extruders. Since nylon6,6 is a material that can be extruded, it is likely they would purchase it to resell extruders that can process this material."
# }
# ```
#
# To summarize, PlastiWin Capital Equipment LLC is a company that sells used plastic extrusion equipment, including extruders. Since nylon6,6 is an extrudable plastic material, it is likely that PlastiWin would purchase nylon6,6 to resell extruders that can process this type of material. The company is located in Twinsburg, OH, USA.
# The data is not in JSON format.
# Printing data Text:
#  Based on the context provided, here is the information extracted in JSON format:
#
# ```json
# {
#   "Company_Name": "PlastiWin Capital Equipment LLC",
#   "Company Website": "https://www.plastiwin.com/",
#   "Phone Number": "(330) 998-6738",
#   "Location": "Twinsburg, OH, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company sells used plastic extrusion equipment and extruders. Since nylon6,6 is a material that can be extruded, it is likely they would purchase it to resell extruders that can process this material."
# }
# ```
#
# To summarize, PlastiWin Capital Equipment LLC is a company that sells used plastic extrusion equipment, including extruders. Since nylon6,6 is an extrudable plastic material, it is likely that PlastiWin would purchase nylon6,6 to resell extruders that can process this type of material. The company is located in Twinsburg, OH, USA.
# Printing data after removing backticks:
#  Based on the context provided, here is the information extracted in JSON format:
#
# ```json
# {
#   "Company_Name": "PlastiWin Capital Equipment LLC",
#   "Company Website": "https://www.plastiwin.com/",
#   "Phone Number": "(330) 998-6738",
#   "Location": "Twinsburg, OH, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company sells used plastic extrusion equipment and extruders. Since nylon6,6 is a material that can be extruded, it is likely they would purchase it to resell extruders that can process this material."
# }
# ```
#
# To summarize, PlastiWin Capital Equipment LLC is a company that sells used plastic extrusion equipment, including extruders. Since nylon6,6 is an extrudable plastic material, it is likely that PlastiWin would purchase nylon6,6 to resell extruders that can process this type of material. The company is located in Twinsburg, OH, USA.
# Extracted JSON Part
# {
#   "Company_Name": "PlastiWin Capital Equipment LLC",
#   "Company Website": "https://www.plastiwin.com/",
#   "Phone Number": "(330) 998-6738",
#   "Location": "Twinsburg, OH, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company sells used plastic extrusion equipment and extruders. Since nylon6,6 is a material that can be extruded, it is likely they would purchase it to resell extruders that can process this material."
# }
# Data Type after extracting data: <class 'dict'>
#
# Current working directory: /home/ec2-user/SageMaker/AscendNotebook
# ================================
