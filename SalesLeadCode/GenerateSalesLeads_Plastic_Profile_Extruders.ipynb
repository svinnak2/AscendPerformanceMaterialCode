# %%
# pip install -r "/home/ec2-user/SageMaker/AscendNotebook/ascendrequirements.txt"

# %%
""" To run this script, pass the following two parameters:

Parameter1, Parameter2

Parameter1 accepts one of the following values:
    "Nylon & Polyamide injection molders"
    "Plastic Profile Extruders"
    "Plastic Sheet extruders"
    "Recycled carpet fibers applications"
    "Nylon Compounders & Polyamide Compounders"
    
Parameter2 accept any material that you check whether a company will purchase it or not.

The following is an example command to run it.

# %run SalesLeadClassification.py "Plastic Profile Extruders" "nylon6,6"

"""

# %%
# %run SalesLeadClassification.py "Plastic Profile Extruders" "nylon6,6"
# Out:
# Search Term: Plastic Profile Extruders
# Number of Results to Query: nylon6,6
# Present working directory: /home/ec2-user/SageMaker/AscendNotebook
# Directory to save results: /home/ec2-user/SageMaker/AscendNotebook/CodeExecutionMetrics/
# Directory to save Sales Leads: /home/ec2-user/SageMaker/AscendNotebook/SalesLeadData/
# Starting NER job for Plastic Profile Extruders at: 2024-06-18 20:59:00
# Files Search Directory to Work: Plastic_Profile_Extruders
# Current working directory: /home/ec2-user/SageMaker/AscendNotebook
#
# Current working directory: /home/ec2-user/SageMaker/AscendNotebook/Plastic_Profile_Extruders
# ['Plastic Profile Extruders_54_Industrialextrusionmachinery.txt', 'Plastic Profile Extruders_53_Euroextrusions.txt', 'Plastic Profile Extruders_85_Gshindustries.txt', 'Plastic Profile Extruders_79_Plastiwin.txt', 'Plastic Profile Extruders_84_Cooperstandard.txt', 'Plastic Profile Extruders_7_Extrudedplastics.txt', 'Plastic Profile Extruders_87_Garlandmfg.txt', 'Plastic Profile Extruders_11_Sfrindustries.txt', 'Plastic Profile Extruders_90_Dir.txt', 'Plastic Profile Extruders_74_Extrunet.txt', 'Plastic Profile Extruders_49_Oke.txt', 'Plastic Profile Extruders_96_Pixargus.txt', 'Plastic Profile Extruders_56_Plastixportal.txt', 'Plastic Profile Extruders_34_Tubewaysales.txt', 'Plastic Profile Extruders_60_Magazines.txt', 'Plastic Profile Extruders_35_Astroplastics.txt', 'Plastic Profile Extruders_21_Intekplastics.txt', 'Plastic Profile Extruders_5_Lomont.txt', 'Plastic Profile Extruders_78_Ultrafab.txt', 'Plastic Profile Extruders_9_Northlandplastics.txt', 'Plastic Profile Extruders_64_Plasticprofiles.txt', 'Plastic Profile Extruders_38_Primo.txt', 'Plastic Profile Extruders_24_Hudsonextrusions.txt', 'Plastic Profile Extruders_28_Petroextrusion.txt', 'Plastic Profile Extruders_55_Genplex.txt', 'Plastic Profile Extruders_69_Jwellextrusions.txt', 'Plastic Profile Extruders_15_Northlandplastics.txt', 'Plastic Profile Extruders_27_Exelliq.txt', 'Plastic Profile Extruders_93_Magnaplastics.txt', 'Plastic Profile Extruders_86_Pemusa.txt', 'Plastic Profile Extruders_13_Inplexllc.txt', 'Plastic Profile Extruders_82_Waykenrm.txt', 'Plastic Profile Extruders_88_Ace.txt', 'Plastic Profile Extruders_68_Condaleplastics.txt', 'Plastic Profile Extruders_36_Wiplastic.txt', 'Plastic Profile Extruders_3_Roechling.txt', 'Plastic Profile Extruders_48_Fukuvi.txt', 'Plastic Profile Extruders_72_Omegaplastics.txt', 'Plastic Profile Extruders_31_Mkmplastics.txt', 'Plastic Profile Extruders_25_Preferredplastics.txt', 'Plastic Profile Extruders_75_Ppextrusions.txt', 'Plastic Profile Extruders_46_Plastiprofile.txt', 'Plastic Profile Extruders_16_Inplexllc.txt', 'Plastic Profile Extruders_52_Profilefilms.txt', 'Plastic Profile Extruders_30_Outwater.txt', 'Plastic Profile Extruders_76_Beiermanplas.txt', 'Plastic Profile Extruders_77_Plasticstoday.txt', 'Plastic Profile Extruders_45_Bausano.txt', 'Plastic Profile Extruders_70_Worthyhardware.txt', 'Plastic Profile Extruders_67_Iqsdirectory.txt', 'Plastic Profile Extruders_89_Cyframe.txt', 'Plastic Profile Extruders_41_Formtech.txt', 'Plastic Profile Extruders_26_Linkedin.txt', 'Plastic Profile Extruders_61_Allianceplasticscorp.txt', 'Plastic Profile Extruders_33_En.txt']
# Reading File: 0
# Reading file name: Plastic Profile Extruders_54_Industrialextrusionmachinery.txt
#
#  Based on the context provided, here is the analysis:
#
# {
#   "Company_Name": "Industrialextrusionmachinery.com",
#   "Company Website": "Industrialextrusionmachinery.com",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company manufactures and supplies plastic extrusion machines and equipment. Since nylon 6,6 is a common plastic extrusion material, it is likely they would purchase it or recommend it to their customers."
# }
#
# The key information that indicates this company is likely to purchase nylon 6,6:
#
# - They specialize in plastic extrusion equipment and materials
# - Nylon 6,6 is commonly used as an extrusion material
# - They provide information on extrusion materials and applications on their website
#
# So I have predicted they are likely to purchase nylon 6,6 and given the logical reasons why. Let me know if you need any clarification or have additional questions!
# The data is not in JSON format.
# Printing data Text:
#  Based on the context provided, here is the analysis:
#
# {
#   "Company_Name": "Industrialextrusionmachinery.com",
#   "Company Website": "Industrialextrusionmachinery.com",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company manufactures and supplies plastic extrusion machines and equipment. Since nylon 6,6 is a common plastic extrusion material, it is likely they would purchase it or recommend it to their customers."
# }
#
# The key information that indicates this company is likely to purchase nylon 6,6:
#
# - They specialize in plastic extrusion equipment and materials
# - Nylon 6,6 is commonly used as an extrusion material
# - They provide information on extrusion materials and applications on their website
#
# So I have predicted they are likely to purchase nylon 6,6 and given the logical reasons why. Let me know if you need any clarification or have additional questions!
# Printing data after removing backticks:
#  Based on the context provided, here is the analysis:
#
# {
#   "Company_Name": "Industrialextrusionmachinery.com",
#   "Company Website": "Industrialextrusionmachinery.com",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company manufactures and supplies plastic extrusion machines and equipment. Since nylon 6,6 is a common plastic extrusion material, it is likely they would purchase it or recommend it to their customers."
# }
#
# The key information that indicates this company is likely to purchase nylon 6,6:
#
# - They specialize in plastic extrusion equipment and materials
# - Nylon 6,6 is commonly used as an extrusion material
# - They provide information on extrusion materials and applications on their website
#
# So I have predicted they are likely to purchase nylon 6,6 and given the logical reasons why. Let me know if you need any clarification or have additional questions!
# Extracted JSON Part
# {
#   "Company_Name": "Industrialextrusionmachinery.com",
#   "Company Website": "Industrialextrusionmachinery.com",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company manufactures and supplies plastic extrusion machines and equipment. Since nylon 6,6 is a common plastic extrusion material, it is likely they would purchase it or recommend it to their customers."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 1
# Reading file name: Plastic Profile Extruders_53_Euroextrusions.txt
#
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Euro Extrusions Ltd",
#   "Company Website": "https://www.euroextrusions.com",
#   "Phone Number": "01254 886662",
#   "Location": "Great Harwood, Lancashire, United Kingdom",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Euro Extrusions Ltd is a plastic extrusion company that manufactures thermoplastic sheets and pipes. The context mentions they use raw materials like polypropylene, polyethylene etc. So they are likely to purchase nylon6,6 material for their extrusion processes."
# }
# ```
#
# To summarize:
#
# - The company name is Euro Extrusions Ltd
# - Their website is https://www.euroextrusions.com
# - Their phone number is 01254 886662
# - They are located in Great Harwood, Lancashire, United Kingdom
# - They are likely to purchase nylon6,6 because they are a plastic extrusion company that uses thermoplastics like polypropylene and polyethylene. Nylon6,6 can be used as a raw material for their extrusion processes.
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Euro Extrusions Ltd",
#   "Company Website": "https://www.euroextrusions.com",
#   "Phone Number": "01254 886662",
#   "Location": "Great Harwood, Lancashire, United Kingdom",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Euro Extrusions Ltd is a plastic extrusion company that manufactures thermoplastic sheets and pipes. The context mentions they use raw materials like polypropylene, polyethylene etc. So they are likely to purchase nylon6,6 material for their extrusion processes."
# }
# ```
#
# To summarize:
#
# - The company name is Euro Extrusions Ltd
# - Their website is https://www.euroextrusions.com
# - Their phone number is 01254 886662
# - They are located in Great Harwood, Lancashire, United Kingdom
# - They are likely to purchase nylon6,6 because they are a plastic extrusion company that uses thermoplastics like polypropylene and polyethylene. Nylon6,6 can be used as a raw material for their extrusion processes.
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Euro Extrusions Ltd",
#   "Company Website": "https://www.euroextrusions.com",
#   "Phone Number": "01254 886662",
#   "Location": "Great Harwood, Lancashire, United Kingdom",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Euro Extrusions Ltd is a plastic extrusion company that manufactures thermoplastic sheets and pipes. The context mentions they use raw materials like polypropylene, polyethylene etc. So they are likely to purchase nylon6,6 material for their extrusion processes."
# }
# ```
#
# To summarize:
#
# - The company name is Euro Extrusions Ltd
# - Their website is https://www.euroextrusions.com
# - Their phone number is 01254 886662
# - They are located in Great Harwood, Lancashire, United Kingdom
# - They are likely to purchase nylon6,6 because they are a plastic extrusion company that uses thermoplastics like polypropylene and polyethylene. Nylon6,6 can be used as a raw material for their extrusion processes.
# Extracted JSON Part
# {
#   "Company_Name": "Euro Extrusions Ltd",
#   "Company Website": "https://www.euroextrusions.com",
#   "Phone Number": "01254 886662",
#   "Location": "Great Harwood, Lancashire, United Kingdom",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Euro Extrusions Ltd is a plastic extrusion company that manufactures thermoplastic sheets and pipes. The context mentions they use raw materials like polypropylene, polyethylene etc. So they are likely to purchase nylon6,6 material for their extrusion processes."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 2
# Reading file name: Plastic Profile Extruders_85_Gshindustries.txt
#
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "GSH Industries",
#   "Company Website": "https://www.gshindustries.com/",
#   "Phone Number": "440-238-3009",
#   "Location": "Strongsville, Ohio, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "GSH Industries is a custom plastic, aluminum and rubber extrusion company that does injection molding. They use a variety of plastics including ABS, nylon, PVC and polyethylene. Since nylon6,6 is a common plastic for injection molding, it is likely they would purchase it."
# }
# ```
#
# To summarize, GSH Industries is an injection molding company located in Ohio, USA. Based on the context, they use various plastics including ABS, PVC, polyethylene and nylon for custom extrusions and molding. Since nylon6,6 is a popular plastic for injection molding, it is likely they would purchase it. So I have predicted "Likely to purchase" along with the reasoning.
# The data is not in JSON format.
# Printing data Text:
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "GSH Industries",
#   "Company Website": "https://www.gshindustries.com/",
#   "Phone Number": "440-238-3009",
#   "Location": "Strongsville, Ohio, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "GSH Industries is a custom plastic, aluminum and rubber extrusion company that does injection molding. They use a variety of plastics including ABS, nylon, PVC and polyethylene. Since nylon6,6 is a common plastic for injection molding, it is likely they would purchase it."
# }
# ```
#
# To summarize, GSH Industries is an injection molding company located in Ohio, USA. Based on the context, they use various plastics including ABS, PVC, polyethylene and nylon for custom extrusions and molding. Since nylon6,6 is a popular plastic for injection molding, it is likely they would purchase it. So I have predicted "Likely to purchase" along with the reasoning.
# Printing data after removing backticks:
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "GSH Industries",
#   "Company Website": "https://www.gshindustries.com/",
#   "Phone Number": "440-238-3009",
#   "Location": "Strongsville, Ohio, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "GSH Industries is a custom plastic, aluminum and rubber extrusion company that does injection molding. They use a variety of plastics including ABS, nylon, PVC and polyethylene. Since nylon6,6 is a common plastic for injection molding, it is likely they would purchase it."
# }
# ```
#
# To summarize, GSH Industries is an injection molding company located in Ohio, USA. Based on the context, they use various plastics including ABS, PVC, polyethylene and nylon for custom extrusions and molding. Since nylon6,6 is a popular plastic for injection molding, it is likely they would purchase it. So I have predicted "Likely to purchase" along with the reasoning.
# Extracted JSON Part
# {
#   "Company_Name": "GSH Industries",
#   "Company Website": "https://www.gshindustries.com/",
#   "Phone Number": "440-238-3009",
#   "Location": "Strongsville, Ohio, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "GSH Industries is a custom plastic, aluminum and rubber extrusion company that does injection molding. They use a variety of plastics including ABS, nylon, PVC and polyethylene. Since nylon6,6 is a common plastic for injection molding, it is likely they would purchase it."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 3
# Reading file name: Plastic Profile Extruders_79_Plastiwin.txt
#
#  Based on the context provided, here is the information extracted in JSON format:
#
# ```json
# {
#   "Company_Name": "PlastiWin Capital Equipment LLC",
#   "Company Website": "https://www.plastiwin.com/",
#   "Phone Number": "(330) 998-6738",
#   "Location": "Twinsburg, OH, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company sells used plastic extrusion equipment and extruders. Since nylon6,6 is a material that can be extruded, it is likely they would purchase it to resell extruders that can process this material."
# }
# ```
#
# To summarize, PlastiWin Capital Equipment LLC is a company that buys and sells used plastic processing equipment, including extruders. Since nylon6,6 is an extrudable plastic material, it is likely that PlastiWin would purchase nylon6,6 to resell extruders capable of processing that material. The company details like name, website, phone number, and location were extracted from the context.
# The data is not in JSON format.
# Printing data Text:
#  Based on the context provided, here is the information extracted in JSON format:
#
# ```json
# {
#   "Company_Name": "PlastiWin Capital Equipment LLC",
#   "Company Website": "https://www.plastiwin.com/",
#   "Phone Number": "(330) 998-6738",
#   "Location": "Twinsburg, OH, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company sells used plastic extrusion equipment and extruders. Since nylon6,6 is a material that can be extruded, it is likely they would purchase it to resell extruders that can process this material."
# }
# ```
#
# To summarize, PlastiWin Capital Equipment LLC is a company that buys and sells used plastic processing equipment, including extruders. Since nylon6,6 is an extrudable plastic material, it is likely that PlastiWin would purchase nylon6,6 to resell extruders capable of processing that material. The company details like name, website, phone number, and location were extracted from the context.
# Printing data after removing backticks:
#  Based on the context provided, here is the information extracted in JSON format:
#
# ```json
# {
#   "Company_Name": "PlastiWin Capital Equipment LLC",
#   "Company Website": "https://www.plastiwin.com/",
#   "Phone Number": "(330) 998-6738",
#   "Location": "Twinsburg, OH, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company sells used plastic extrusion equipment and extruders. Since nylon6,6 is a material that can be extruded, it is likely they would purchase it to resell extruders that can process this material."
# }
# ```
#
# To summarize, PlastiWin Capital Equipment LLC is a company that buys and sells used plastic processing equipment, including extruders. Since nylon6,6 is an extrudable plastic material, it is likely that PlastiWin would purchase nylon6,6 to resell extruders capable of processing that material. The company details like name, website, phone number, and location were extracted from the context.
# Extracted JSON Part
# {
#   "Company_Name": "PlastiWin Capital Equipment LLC",
#   "Company Website": "https://www.plastiwin.com/",
#   "Phone Number": "(330) 998-6738",
#   "Location": "Twinsburg, OH, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company sells used plastic extrusion equipment and extruders. Since nylon6,6 is a material that can be extruded, it is likely they would purchase it to resell extruders that can process this material."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 4
# Reading file name: Plastic Profile Extruders_84_Cooperstandard.txt
#
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Cooper Standard",
#   "Company Website": "https://www.cooperstandard.com/",
#   "Phone Number": "N/A",
#   "Location": "Northville, Michigan, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Cooper Standard specializes in materials science and produces custom plastic extrusions. They have capabilities in rigid and flexible plastics, plastic co-extrusion, plastic fabrication, and various value-added services that indicate they are an injection molding company. Since they work with nylon materials for the automotive industry, they are likely to purchase nylon6,6 material."
# }
# ```
#
# To summarize, Cooper Standard is identified as an injection molding company that is likely to purchase nylon6,6 material based on their expertise and capabilities in custom plastic extrusions across industries like automotive and construction, their strength in materials science and polymers, and their offerings that align with injection molding production. The context provides extensive details on their services that demonstrate they are the type of company that would purchase nylon6,6 material.
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Cooper Standard",
#   "Company Website": "https://www.cooperstandard.com/",
#   "Phone Number": "N/A",
#   "Location": "Northville, Michigan, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Cooper Standard specializes in materials science and produces custom plastic extrusions. They have capabilities in rigid and flexible plastics, plastic co-extrusion, plastic fabrication, and various value-added services that indicate they are an injection molding company. Since they work with nylon materials for the automotive industry, they are likely to purchase nylon6,6 material."
# }
# ```
#
# To summarize, Cooper Standard is identified as an injection molding company that is likely to purchase nylon6,6 material based on their expertise and capabilities in custom plastic extrusions across industries like automotive and construction, their strength in materials science and polymers, and their offerings that align with injection molding production. The context provides extensive details on their services that demonstrate they are the type of company that would purchase nylon6,6 material.
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Cooper Standard",
#   "Company Website": "https://www.cooperstandard.com/",
#   "Phone Number": "N/A",
#   "Location": "Northville, Michigan, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Cooper Standard specializes in materials science and produces custom plastic extrusions. They have capabilities in rigid and flexible plastics, plastic co-extrusion, plastic fabrication, and various value-added services that indicate they are an injection molding company. Since they work with nylon materials for the automotive industry, they are likely to purchase nylon6,6 material."
# }
# ```
#
# To summarize, Cooper Standard is identified as an injection molding company that is likely to purchase nylon6,6 material based on their expertise and capabilities in custom plastic extrusions across industries like automotive and construction, their strength in materials science and polymers, and their offerings that align with injection molding production. The context provides extensive details on their services that demonstrate they are the type of company that would purchase nylon6,6 material.
# Extracted JSON Part
# {
#   "Company_Name": "Cooper Standard",
#   "Company Website": "https://www.cooperstandard.com/",
#   "Phone Number": "N/A",
#   "Location": "Northville, Michigan, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Cooper Standard specializes in materials science and produces custom plastic extrusions. They have capabilities in rigid and flexible plastics, plastic co-extrusion, plastic fabrication, and various value-added services that indicate they are an injection molding company. Since they work with nylon materials for the automotive industry, they are likely to purchase nylon6,6 material."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 5
# Reading file name: Plastic Profile Extruders_7_Extrudedplastics.txt
#
#  Unfortunately, I could not extract enough relevant information from the context to provide a prediction on whether this company is likely to purchase the given material (nylon6,6). The context contains information about plastic extrusion manufacturers and suppliers in general, but does not mention any specific company that I could analyze. As a result, my responses for all fields will be "N/A":
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "N/A",
#   "Prediction_Reason": "N/A"
# }
# ```
#
# I apologize that I could not provide more useful information in this case. The context simply did not contain enough specific details about a company to determine if they would likely purchase the given material. Please feel free to provide additional context, and I would be happy to try again.
# The data is not in JSON format.
# Printing data Text:
#  Unfortunately, I could not extract enough relevant information from the context to provide a prediction on whether this company is likely to purchase the given material (nylon6,6). The context contains information about plastic extrusion manufacturers and suppliers in general, but does not mention any specific company that I could analyze. As a result, my responses for all fields will be "N/A":
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "N/A",
#   "Prediction_Reason": "N/A"
# }
# ```
#
# I apologize that I could not provide more useful information in this case. The context simply did not contain enough specific details about a company to determine if they would likely purchase the given material. Please feel free to provide additional context, and I would be happy to try again.
# Printing data after removing backticks:
#  Unfortunately, I could not extract enough relevant information from the context to provide a prediction on whether this company is likely to purchase the given material (nylon6,6). The context contains information about plastic extrusion manufacturers and suppliers in general, but does not mention any specific company that I could analyze. As a result, my responses for all fields will be "N/A":
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "N/A",
#   "Prediction_Reason": "N/A"
# }
# ```
#
# I apologize that I could not provide more useful information in this case. The context simply did not contain enough specific details about a company to determine if they would likely purchase the given material. Please feel free to provide additional context, and I would be happy to try again.
# Extracted JSON Part
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "N/A",
#   "Prediction_Reason": "N/A"
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 6
# Reading file name: Plastic Profile Extruders_87_Garlandmfg.txt
#
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "Garland Manufacturing Company",
#   "Company Website": "https://www.garlandmfg.com",
#   "Phone Number": "207-283-3693",
#   "Location": "Saco, Maine, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Garland Manufacturing Company manufactures and sells UHMW plastic products like profile extrusions. Since they already work with UHMW plastic, they are likely to purchase more nylon6,6 material for additional products."
# }
# ```
#
# To summarize, Garland Manufacturing Company is predicted to likely purchase nylon6,6 material because:
#
# - They manufacture and sell UHMW plastic products like profile extrusions
# - Since they already work with plastics like UHMW, they have the capability and demand to utilize more nylon6,6 material
# - As a plastics manufacturer and seller, purchasing more material aligns with their business operations
#
# Let me know if you need any clarification or have additional questions!
# The data is not in JSON format.
# Printing data Text:
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "Garland Manufacturing Company",
#   "Company Website": "https://www.garlandmfg.com",
#   "Phone Number": "207-283-3693",
#   "Location": "Saco, Maine, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Garland Manufacturing Company manufactures and sells UHMW plastic products like profile extrusions. Since they already work with UHMW plastic, they are likely to purchase more nylon6,6 material for additional products."
# }
# ```
#
# To summarize, Garland Manufacturing Company is predicted to likely purchase nylon6,6 material because:
#
# - They manufacture and sell UHMW plastic products like profile extrusions
# - Since they already work with plastics like UHMW, they have the capability and demand to utilize more nylon6,6 material
# - As a plastics manufacturer and seller, purchasing more material aligns with their business operations
#
# Let me know if you need any clarification or have additional questions!
# Printing data after removing backticks:
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "Garland Manufacturing Company",
#   "Company Website": "https://www.garlandmfg.com",
#   "Phone Number": "207-283-3693",
#   "Location": "Saco, Maine, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Garland Manufacturing Company manufactures and sells UHMW plastic products like profile extrusions. Since they already work with UHMW plastic, they are likely to purchase more nylon6,6 material for additional products."
# }
# ```
#
# To summarize, Garland Manufacturing Company is predicted to likely purchase nylon6,6 material because:
#
# - They manufacture and sell UHMW plastic products like profile extrusions
# - Since they already work with plastics like UHMW, they have the capability and demand to utilize more nylon6,6 material
# - As a plastics manufacturer and seller, purchasing more material aligns with their business operations
#
# Let me know if you need any clarification or have additional questions!
# Extracted JSON Part
# {
#   "Company_Name": "Garland Manufacturing Company",
#   "Company Website": "https://www.garlandmfg.com",
#   "Phone Number": "207-283-3693",
#   "Location": "Saco, Maine, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Garland Manufacturing Company manufactures and sells UHMW plastic products like profile extrusions. Since they already work with UHMW plastic, they are likely to purchase more nylon6,6 material for additional products."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 7
# Reading file name: Plastic Profile Extruders_11_Sfrindustries.txt
#
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "SFR Industries",
#   "Company Website": "https://www.sfrindustries.com/",
#   "Phone Number": "1-800-369-9410",
#   "Location": "Cadott, WI, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "SFR Industries is a plastic extrusion company that provides custom plastic profile extrusions. They have expertise working with a variety of plastics including nylon6,6 which is the material provided. As an injection molding company, they are likely to purchase nylon6,6 for use in their manufacturing processes."
# }
# ```
#
# To summarize, I predicted that SFR Industries is likely to purchase the provided material nylon6,6 because they are a plastic extrusion company with expertise working with plastics like nylon. As an injection molding company, it is likely they would purchase nylon to use in their manufacturing of custom plastic profile extrusions.
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "SFR Industries",
#   "Company Website": "https://www.sfrindustries.com/",
#   "Phone Number": "1-800-369-9410",
#   "Location": "Cadott, WI, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "SFR Industries is a plastic extrusion company that provides custom plastic profile extrusions. They have expertise working with a variety of plastics including nylon6,6 which is the material provided. As an injection molding company, they are likely to purchase nylon6,6 for use in their manufacturing processes."
# }
# ```
#
# To summarize, I predicted that SFR Industries is likely to purchase the provided material nylon6,6 because they are a plastic extrusion company with expertise working with plastics like nylon. As an injection molding company, it is likely they would purchase nylon to use in their manufacturing of custom plastic profile extrusions.
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "SFR Industries",
#   "Company Website": "https://www.sfrindustries.com/",
#   "Phone Number": "1-800-369-9410",
#   "Location": "Cadott, WI, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "SFR Industries is a plastic extrusion company that provides custom plastic profile extrusions. They have expertise working with a variety of plastics including nylon6,6 which is the material provided. As an injection molding company, they are likely to purchase nylon6,6 for use in their manufacturing processes."
# }
# ```
#
# To summarize, I predicted that SFR Industries is likely to purchase the provided material nylon6,6 because they are a plastic extrusion company with expertise working with plastics like nylon. As an injection molding company, it is likely they would purchase nylon to use in their manufacturing of custom plastic profile extrusions.
# Extracted JSON Part
# {
#   "Company_Name": "SFR Industries",
#   "Company Website": "https://www.sfrindustries.com/",
#   "Phone Number": "1-800-369-9410",
#   "Location": "Cadott, WI, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "SFR Industries is a plastic extrusion company that provides custom plastic profile extrusions. They have expertise working with a variety of plastics including nylon6,6 which is the material provided. As an injection molding company, they are likely to purchase nylon6,6 for use in their manufacturing processes."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 8
# Reading file name: Plastic Profile Extruders_90_Dir.txt
#
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```JSON
# {
#   "Company_Name": "Solution 4U",
#   "Company Website": "N/A",
#   "Phone Number": "+91-8048973897",
#   "Location": "Andheri west, Mumbai - 400058, Dist. Mumbai, Maharashtra",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company Solution 4U is located in Mumbai and deals in new plastic extruded profiles. Since the material provided is nylon6,6 which is a type of plastic, it is likely that this injection molding company would be interested in purchasing this material."
# }
# ```
#
# The key information I extracted:
# - Company name: Solution 4U
# - Phone number: +91-8048973897
# - Location: Andheri west, Mumbai
# - They deal in new plastic extruded profiles
# - Material provided is nylon6,6 which is a type of plastic
#
# Based on this, I predicted they are likely to purchase the material and provided reasoning to support my prediction.
# The data is not in JSON format.
# Printing data Text:
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```JSON
# {
#   "Company_Name": "Solution 4U",
#   "Company Website": "N/A",
#   "Phone Number": "+91-8048973897",
#   "Location": "Andheri west, Mumbai - 400058, Dist. Mumbai, Maharashtra",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company Solution 4U is located in Mumbai and deals in new plastic extruded profiles. Since the material provided is nylon6,6 which is a type of plastic, it is likely that this injection molding company would be interested in purchasing this material."
# }
# ```
#
# The key information I extracted:
# - Company name: Solution 4U
# - Phone number: +91-8048973897
# - Location: Andheri west, Mumbai
# - They deal in new plastic extruded profiles
# - Material provided is nylon6,6 which is a type of plastic
#
# Based on this, I predicted they are likely to purchase the material and provided reasoning to support my prediction.
# Printing data after removing backticks:
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```JSON
# {
#   "Company_Name": "Solution 4U",
#   "Company Website": "N/A",
#   "Phone Number": "+91-8048973897",
#   "Location": "Andheri west, Mumbai - 400058, Dist. Mumbai, Maharashtra",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company Solution 4U is located in Mumbai and deals in new plastic extruded profiles. Since the material provided is nylon6,6 which is a type of plastic, it is likely that this injection molding company would be interested in purchasing this material."
# }
# ```
#
# The key information I extracted:
# - Company name: Solution 4U
# - Phone number: +91-8048973897
# - Location: Andheri west, Mumbai
# - They deal in new plastic extruded profiles
# - Material provided is nylon6,6 which is a type of plastic
#
# Based on this, I predicted they are likely to purchase the material and provided reasoning to support my prediction.
# Extracted JSON Part
# {
#   "Company_Name": "Solution 4U",
#   "Company Website": "N/A",
#   "Phone Number": "+91-8048973897",
#   "Location": "Andheri west, Mumbai - 400058, Dist. Mumbai, Maharashtra",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company Solution 4U is located in Mumbai and deals in new plastic extruded profiles. Since the material provided is nylon6,6 which is a type of plastic, it is likely that this injection molding company would be interested in purchasing this material."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 9
# Reading file name: Plastic Profile Extruders_74_Extrunet.txt
#
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "extrunet",
#   "Company Website": "https://www.extrunet.com/",
#   "Phone Number": "+43 570 580 2",
#   "Location": "Gewerbepark D, Gewerbestrasse 5, 4653 Eberstalzell, Austria",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "extrunet is a manufacturer of extrusion lines and equipment. Based on the website, they produce machinery and tools for plastic profile extrusion. Since nylon6,6 is a common plastic material used in injection molding and profile extrusion, it is likely that extrunet purchases nylon6,6 for testing out their equipment or even using it in their extrusion lines that they manufacture."
# }
# ```
#
# To summarize:
#
# - extrunet is identified as an extrusion equipment manufacturer based on the context provided.
# - They manufacture machinery and tools for plastic profile extrusion.
# - Nylon6,6 is a common plastic used in injection molding and extrusion applications.
# - So it is likely that extrunet purchases nylon6,6 resin either for testing out their equipment or even using it in the extrusion lines they manufacture.
#
# Therefore, I have predicted "Likely to purchase" along with a logical reasoning. Let me know if you need any other details!
# The data is not in JSON format.
# Printing data Text:
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "extrunet",
#   "Company Website": "https://www.extrunet.com/",
#   "Phone Number": "+43 570 580 2",
#   "Location": "Gewerbepark D, Gewerbestrasse 5, 4653 Eberstalzell, Austria",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "extrunet is a manufacturer of extrusion lines and equipment. Based on the website, they produce machinery and tools for plastic profile extrusion. Since nylon6,6 is a common plastic material used in injection molding and profile extrusion, it is likely that extrunet purchases nylon6,6 for testing out their equipment or even using it in their extrusion lines that they manufacture."
# }
# ```
#
# To summarize:
#
# - extrunet is identified as an extrusion equipment manufacturer based on the context provided.
# - They manufacture machinery and tools for plastic profile extrusion.
# - Nylon6,6 is a common plastic used in injection molding and extrusion applications.
# - So it is likely that extrunet purchases nylon6,6 resin either for testing out their equipment or even using it in the extrusion lines they manufacture.
#
# Therefore, I have predicted "Likely to purchase" along with a logical reasoning. Let me know if you need any other details!
# Printing data after removing backticks:
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "extrunet",
#   "Company Website": "https://www.extrunet.com/",
#   "Phone Number": "+43 570 580 2",
#   "Location": "Gewerbepark D, Gewerbestrasse 5, 4653 Eberstalzell, Austria",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "extrunet is a manufacturer of extrusion lines and equipment. Based on the website, they produce machinery and tools for plastic profile extrusion. Since nylon6,6 is a common plastic material used in injection molding and profile extrusion, it is likely that extrunet purchases nylon6,6 for testing out their equipment or even using it in their extrusion lines that they manufacture."
# }
# ```
#
# To summarize:
#
# - extrunet is identified as an extrusion equipment manufacturer based on the context provided.
# - They manufacture machinery and tools for plastic profile extrusion.
# - Nylon6,6 is a common plastic used in injection molding and extrusion applications.
# - So it is likely that extrunet purchases nylon6,6 resin either for testing out their equipment or even using it in the extrusion lines they manufacture.
#
# Therefore, I have predicted "Likely to purchase" along with a logical reasoning. Let me know if you need any other details!
# Extracted JSON Part
# {
#   "Company_Name": "extrunet",
#   "Company Website": "https://www.extrunet.com/",
#   "Phone Number": "+43 570 580 2",
#   "Location": "Gewerbepark D, Gewerbestrasse 5, 4653 Eberstalzell, Austria",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "extrunet is a manufacturer of extrusion lines and equipment. Based on the website, they produce machinery and tools for plastic profile extrusion. Since nylon6,6 is a common plastic material used in injection molding and profile extrusion, it is likely that extrunet purchases nylon6,6 for testing out their equipment or even using it in their extrusion lines that they manufacture."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 10
# Reading file name: Plastic Profile Extruders_49_Oke.txt
#
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "OKE Group GmbH",
#   "Company Website": "https://www.oke-group.com",
#   "Phone Number": "+49 5459/914-0",
#   "Location": "Hörstel, Germany",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "OKE Group is an injection molding company that manufactures plastic components for the automotive, furniture, and electronics industries. The context mentions they have expertise in injection molding and extrusion processes and use materials like nylon6,6. So they are likely to purchase more nylon6,6 material for their production needs."
# }
# ```
#
# To summarize, OKE Group GmbH is predicted to likely purchase more nylon6,6 material because:
#
# - They are an injection molding company specializing in automotive, furniture, and electronics components
# - The context mentions their expertise in injection molding and extrusion using materials like nylon6,6
# - As a manufacturer, they would need to continually purchase more raw materials like nylon6,6 for ongoing production
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "OKE Group GmbH",
#   "Company Website": "https://www.oke-group.com",
#   "Phone Number": "+49 5459/914-0",
#   "Location": "Hörstel, Germany",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "OKE Group is an injection molding company that manufactures plastic components for the automotive, furniture, and electronics industries. The context mentions they have expertise in injection molding and extrusion processes and use materials like nylon6,6. So they are likely to purchase more nylon6,6 material for their production needs."
# }
# ```
#
# To summarize, OKE Group GmbH is predicted to likely purchase more nylon6,6 material because:
#
# - They are an injection molding company specializing in automotive, furniture, and electronics components
# - The context mentions their expertise in injection molding and extrusion using materials like nylon6,6
# - As a manufacturer, they would need to continually purchase more raw materials like nylon6,6 for ongoing production
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "OKE Group GmbH",
#   "Company Website": "https://www.oke-group.com",
#   "Phone Number": "+49 5459/914-0",
#   "Location": "Hörstel, Germany",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "OKE Group is an injection molding company that manufactures plastic components for the automotive, furniture, and electronics industries. The context mentions they have expertise in injection molding and extrusion processes and use materials like nylon6,6. So they are likely to purchase more nylon6,6 material for their production needs."
# }
# ```
#
# To summarize, OKE Group GmbH is predicted to likely purchase more nylon6,6 material because:
#
# - They are an injection molding company specializing in automotive, furniture, and electronics components
# - The context mentions their expertise in injection molding and extrusion using materials like nylon6,6
# - As a manufacturer, they would need to continually purchase more raw materials like nylon6,6 for ongoing production
# Extracted JSON Part
# {
#   "Company_Name": "OKE Group GmbH",
#   "Company Website": "https://www.oke-group.com",
#   "Phone Number": "+49 5459/914-0",
#   "Location": "Hörstel, Germany",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "OKE Group is an injection molding company that manufactures plastic components for the automotive, furniture, and electronics industries. The context mentions they have expertise in injection molding and extrusion processes and use materials like nylon6,6. So they are likely to purchase more nylon6,6 material for their production needs."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 11
# Reading file name: Plastic Profile Extruders_96_Pixargus.txt
#
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "PIXARGUS GmbH",
#   "Company Website": "https://www.pixargus.de/",
#   "Phone Number": "+49 2405 47908-26",
#   "Location": "Monnetstraße 2 D-52146 Würselen Germany",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "PIXARGUS manufactures optical inspection systems for extruded products like profiles, tubes, hoses etc. So they are likely to purchase nylon6,6 material for injection molding their products."
# }
# ```
#
# To summarize:
#
# - The company name is PIXARGUS GmbH based on the contact information provided.
# - The company website is https://www.pixargus.de/ listed on the webpage.
# - The phone number +49 2405 47908-26 is provided for sales inquiries.
# - The location is listed as Monnetstraße 2 D-52146 Würselen Germany.
# - I predicted "Likely to purchase" as PIXARGUS specializes in inspection systems for extruded products which typically use injection molded plastic components. So they would likely purchase nylon6,6 material.
# - My reason is that they manufacture optical inspection equipment for extruded products, so they likely need nylon6,6 and other materials for injection molding components in their systems.
#
# Let me know if you need any other details!
# The data is not in JSON format.
# Printing data Text:
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "PIXARGUS GmbH",
#   "Company Website": "https://www.pixargus.de/",
#   "Phone Number": "+49 2405 47908-26",
#   "Location": "Monnetstraße 2 D-52146 Würselen Germany",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "PIXARGUS manufactures optical inspection systems for extruded products like profiles, tubes, hoses etc. So they are likely to purchase nylon6,6 material for injection molding their products."
# }
# ```
#
# To summarize:
#
# - The company name is PIXARGUS GmbH based on the contact information provided.
# - The company website is https://www.pixargus.de/ listed on the webpage.
# - The phone number +49 2405 47908-26 is provided for sales inquiries.
# - The location is listed as Monnetstraße 2 D-52146 Würselen Germany.
# - I predicted "Likely to purchase" as PIXARGUS specializes in inspection systems for extruded products which typically use injection molded plastic components. So they would likely purchase nylon6,6 material.
# - My reason is that they manufacture optical inspection equipment for extruded products, so they likely need nylon6,6 and other materials for injection molding components in their systems.
#
# Let me know if you need any other details!
# Printing data after removing backticks:
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "PIXARGUS GmbH",
#   "Company Website": "https://www.pixargus.de/",
#   "Phone Number": "+49 2405 47908-26",
#   "Location": "Monnetstraße 2 D-52146 Würselen Germany",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "PIXARGUS manufactures optical inspection systems for extruded products like profiles, tubes, hoses etc. So they are likely to purchase nylon6,6 material for injection molding their products."
# }
# ```
#
# To summarize:
#
# - The company name is PIXARGUS GmbH based on the contact information provided.
# - The company website is https://www.pixargus.de/ listed on the webpage.
# - The phone number +49 2405 47908-26 is provided for sales inquiries.
# - The location is listed as Monnetstraße 2 D-52146 Würselen Germany.
# ...
# {
#   "Company_Name": "Formtech Enterprises, Inc.",
#   "Company Website": "https://www.formtech.com/",
#   "Phone Number": "(706) 543-2428",
#   "Location": "Bogart, GA, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Formtech Enterprises is a manufacturer of custom plastic profile extrusions. Based on the context, they use a variety of plastic materials including nylon for injection molding and extrusion processes. Since nylon6,6 was provided as the material tag, it is likely that Formtech would purchase this material."
# }
# ```
#
# The key information I extracted:
# - Company name: Formtech Enterprises, Inc.
# - Company website: https://www.formtech.com/ (extracted from context)
# - Phone number: (706) 543-2428 (extracted from context)
# - Location: Bogart, GA, United States (extracted from context)
# - Prediction: Likely to purchase
# - Prediction reason: They manufacture custom plastic extrusions using various plastics including nylon, so they would likely purchase nylon6,6 which was provided as the material tag.
#
# I provided the information in the requested JSON format with the specified fields. Please let me know if you need any clarification or have additional questions!
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Formtech Enterprises, Inc.",
#   "Company Website": "https://www.formtech.com/",
#   "Phone Number": "(706) 543-2428",
#   "Location": "Bogart, GA, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Formtech Enterprises is a manufacturer of custom plastic profile extrusions. Based on the context, they use a variety of plastic materials including nylon for injection molding and extrusion processes. Since nylon6,6 was provided as the material tag, it is likely that Formtech would purchase this material."
# }
# ```
#
# The key information I extracted:
# - Company name: Formtech Enterprises, Inc.
# - Company website: https://www.formtech.com/ (extracted from context)
# - Phone number: (706) 543-2428 (extracted from context)
# - Location: Bogart, GA, United States (extracted from context)
# - Prediction: Likely to purchase
# - Prediction reason: They manufacture custom plastic extrusions using various plastics including nylon, so they would likely purchase nylon6,6 which was provided as the material tag.
#
# I provided the information in the requested JSON format with the specified fields. Please let me know if you need any clarification or have additional questions!
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Formtech Enterprises, Inc.",
#   "Company Website": "https://www.formtech.com/",
#   "Phone Number": "(706) 543-2428",
#   "Location": "Bogart, GA, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Formtech Enterprises is a manufacturer of custom plastic profile extrusions. Based on the context, they use a variety of plastic materials including nylon for injection molding and extrusion processes. Since nylon6,6 was provided as the material tag, it is likely that Formtech would purchase this material."
# }
# ```
#
# The key information I extracted:
# - Company name: Formtech Enterprises, Inc.
# - Company website: https://www.formtech.com/ (extracted from context)
# - Phone number: (706) 543-2428 (extracted from context)
# - Location: Bogart, GA, United States (extracted from context)
# - Prediction: Likely to purchase
# - Prediction reason: They manufacture custom plastic extrusions using various plastics including nylon, so they would likely purchase nylon6,6 which was provided as the material tag.
#
# I provided the information in the requested JSON format with the specified fields. Please let me know if you need any clarification or have additional questions!
# Extracted JSON Part
# {
#   "Company_Name": "Formtech Enterprises, Inc.",
#   "Company Website": "https://www.formtech.com/",
#   "Phone Number": "(706) 543-2428",
#   "Location": "Bogart, GA, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Formtech Enterprises is a manufacturer of custom plastic profile extrusions. Based on the context, they use a variety of plastic materials including nylon for injection molding and extrusion processes. Since nylon6,6 was provided as the material tag, it is likely that Formtech would purchase this material."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 52
# Reading file name: Plastic Profile Extruders_26_Linkedin.txt
#
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Custom Profile",
#   "Company Website": "https://www.custom-profile.com",
#   "Phone Number": "N/A",
#   "Location": "Michigan, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Custom Profile is an injection molding company that specializes in plastic profile extrusion, tubing extrusion, assembly, and finishing. The material provided is nylon6,6 which is a type of plastic. Since Custom Profile works with plastics and extrusion, they are likely to purchase nylon6,6 material."
# }
# ```
#
# I extracted the company name, website, and location from the LinkedIn profile context. The phone number was not provided. Based on the capabilities and services listed, I predicted Custom Profile is likely to purchase the nylon6,6 material for their injection molding and extrusion operations. I provided the reasoning that they specialize in plastics and the material is a type of plastic they could use.
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Custom Profile",
#   "Company Website": "https://www.custom-profile.com",
#   "Phone Number": "N/A",
#   "Location": "Michigan, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Custom Profile is an injection molding company that specializes in plastic profile extrusion, tubing extrusion, assembly, and finishing. The material provided is nylon6,6 which is a type of plastic. Since Custom Profile works with plastics and extrusion, they are likely to purchase nylon6,6 material."
# }
# ```
#
# I extracted the company name, website, and location from the LinkedIn profile context. The phone number was not provided. Based on the capabilities and services listed, I predicted Custom Profile is likely to purchase the nylon6,6 material for their injection molding and extrusion operations. I provided the reasoning that they specialize in plastics and the material is a type of plastic they could use.
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Custom Profile",
#   "Company Website": "https://www.custom-profile.com",
#   "Phone Number": "N/A",
#   "Location": "Michigan, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Custom Profile is an injection molding company that specializes in plastic profile extrusion, tubing extrusion, assembly, and finishing. The material provided is nylon6,6 which is a type of plastic. Since Custom Profile works with plastics and extrusion, they are likely to purchase nylon6,6 material."
# }
# ```
#
# I extracted the company name, website, and location from the LinkedIn profile context. The phone number was not provided. Based on the capabilities and services listed, I predicted Custom Profile is likely to purchase the nylon6,6 material for their injection molding and extrusion operations. I provided the reasoning that they specialize in plastics and the material is a type of plastic they could use.
# Extracted JSON Part
# {
#   "Company_Name": "Custom Profile",
#   "Company Website": "https://www.custom-profile.com",
#   "Phone Number": "N/A",
#   "Location": "Michigan, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Custom Profile is an injection molding company that specializes in plastic profile extrusion, tubing extrusion, assembly, and finishing. The material provided is nylon6,6 which is a type of plastic. Since Custom Profile works with plastics and extrusion, they are likely to purchase nylon6,6 material."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 53
# Reading file name: Plastic Profile Extruders_61_Allianceplasticscorp.txt
#
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "Alliance Plastics Corp.",
#   "Company Website": "https://www.alliance-plastics.com",
#   "Phone Number": "(715) 288-6323",
#   "Location": "Chippewa Falls, WI, USA",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Alliance Plastics Corp. is a premier plastic extrusion company specializing in custom plastic extrusion profiles. Since they use plastics for extrusion, it is likely they would purchase nylon6,6 material for their extrusion processes."
# }
# ```
#
# To summarize, Alliance Plastics Corp. is identified as a plastic extrusion company located in Chippewa Falls, WI. Given they specialize in custom plastic extrusions and use plastic materials, it is likely they would purchase nylon6,6, the material provided, for their extrusion processes. Therefore, I have predicted "Likely to purchase" along with an explanation of why I believe they would purchase the nylon6,6 material.
# The data is not in JSON format.
# Printing data Text:
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "Alliance Plastics Corp.",
#   "Company Website": "https://www.alliance-plastics.com",
#   "Phone Number": "(715) 288-6323",
#   "Location": "Chippewa Falls, WI, USA",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Alliance Plastics Corp. is a premier plastic extrusion company specializing in custom plastic extrusion profiles. Since they use plastics for extrusion, it is likely they would purchase nylon6,6 material for their extrusion processes."
# }
# ```
#
# To summarize, Alliance Plastics Corp. is identified as a plastic extrusion company located in Chippewa Falls, WI. Given they specialize in custom plastic extrusions and use plastic materials, it is likely they would purchase nylon6,6, the material provided, for their extrusion processes. Therefore, I have predicted "Likely to purchase" along with an explanation of why I believe they would purchase the nylon6,6 material.
# Printing data after removing backticks:
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "Alliance Plastics Corp.",
#   "Company Website": "https://www.alliance-plastics.com",
#   "Phone Number": "(715) 288-6323",
#   "Location": "Chippewa Falls, WI, USA",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Alliance Plastics Corp. is a premier plastic extrusion company specializing in custom plastic extrusion profiles. Since they use plastics for extrusion, it is likely they would purchase nylon6,6 material for their extrusion processes."
# }
# ```
#
# To summarize, Alliance Plastics Corp. is identified as a plastic extrusion company located in Chippewa Falls, WI. Given they specialize in custom plastic extrusions and use plastic materials, it is likely they would purchase nylon6,6, the material provided, for their extrusion processes. Therefore, I have predicted "Likely to purchase" along with an explanation of why I believe they would purchase the nylon6,6 material.
# Extracted JSON Part
# {
#   "Company_Name": "Alliance Plastics Corp.",
#   "Company Website": "https://www.alliance-plastics.com",
#   "Phone Number": "(715) 288-6323",
#   "Location": "Chippewa Falls, WI, USA",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Alliance Plastics Corp. is a premier plastic extrusion company specializing in custom plastic extrusion profiles. Since they use plastics for extrusion, it is likely they would purchase nylon6,6 material for their extrusion processes."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 54
# Reading file name: Plastic Profile Extruders_33_En.txt
#
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is a Wikipedia article about plastic extrusion processes. It does not contain any information about a specific company that might purchase nylon6,6 material. There are no details provided about an injection molding company to evaluate if they would likely purchase the material."
# }
# ```
#
# The context tag contains a general Wikipedia article about plastic extrusion processes. It does not mention any specific company details that could be used to determine if a company is likely to purchase the nylon6,6 material provided in the material tag. Without more specific company information, I cannot make a prediction on whether a company would purchase the material. So my prediction is "Not likely to purchase" along with the reasoning that there is insufficient company data in the context. The other response fields are set to "N/A" since no relevant company details are provided.
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is a Wikipedia article about plastic extrusion processes. It does not contain any information about a specific company that might purchase nylon6,6 material. There are no details provided about an injection molding company to evaluate if they would likely purchase the material."
# }
# ```
#
# The context tag contains a general Wikipedia article about plastic extrusion processes. It does not mention any specific company details that could be used to determine if a company is likely to purchase the nylon6,6 material provided in the material tag. Without more specific company information, I cannot make a prediction on whether a company would purchase the material. So my prediction is "Not likely to purchase" along with the reasoning that there is insufficient company data in the context. The other response fields are set to "N/A" since no relevant company details are provided.
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is a Wikipedia article about plastic extrusion processes. It does not contain any information about a specific company that might purchase nylon6,6 material. There are no details provided about an injection molding company to evaluate if they would likely purchase the material."
# }
# ```
#
# The context tag contains a general Wikipedia article about plastic extrusion processes. It does not mention any specific company details that could be used to determine if a company is likely to purchase the nylon6,6 material provided in the material tag. Without more specific company information, I cannot make a prediction on whether a company would purchase the material. So my prediction is "Not likely to purchase" along with the reasoning that there is insufficient company data in the context. The other response fields are set to "N/A" since no relevant company details are provided.
# Extracted JSON Part
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The context provided is a Wikipedia article about plastic extrusion processes. It does not contain any information about a specific company that might purchase nylon6,6 material. There are no details provided about an injection molding company to evaluate if they would likely purchase the material."
# }
# Data Type after extracting data: <class 'dict'>
#
# Current working directory: /home/ec2-user/SageMaker/AscendNotebook
# ================================
