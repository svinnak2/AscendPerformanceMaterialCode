# %%
# pip install -r "/home/ec2-user/SageMaker/AscendNotebook/ascendrequirements.txt"

# %%
""" To run this script, pass the following two parameters:

Parameter1, Parameter2

Parameter1 accepts one of the following values:
    "Nylon & Polyamide injection molders"
    "Plastic Profile Extruders"
    "Plastic Sheet extruders"
    "Recycled carpet fibers applications"
    "Nylon Compounders & Polyamide Compounders"
    
Parameter2 accept any material that you check whether a company will purchase it or not.

The following is an example command to run it.

e.g.: %run SalesLeadClassification.py "Nylon & Polyamide injection molders" "nylon6,6"

"""

# %%
# %run SalesLeadClassification.py "Nylon & Polyamide injection molders" "nylon6,6"
# Out:
# Search Term: Nylon & Polyamide injection molders
# Number of Results to Query: nylon6,6
# Present working directory: /home/ec2-user/SageMaker/AscendNotebook
# Directory to save results: /home/ec2-user/SageMaker/AscendNotebook/CodeExecutionMetrics/
# Directory to save Sales Leads: /home/ec2-user/SageMaker/AscendNotebook/SalesLeadData/
# Starting NER job for Nylon & Polyamide injection molders at: 2024-06-18 20:42:58
# Files Search Directory to Work: Nylon_Polyamide_injection_molders
# Current working directory: /home/ec2-user/SageMaker/AscendNotebook
#
# Current working directory: /home/ec2-user/SageMaker/AscendNotebook/Nylon_Polyamide_injection_molders
# ['Nylon & Polyamide injection molders_30_Immould.txt', 'Nylon & Polyamide injection molders_67_Bpf.txt', 'Nylon & Polyamide injection molders_29_Pmcplastics.txt', 'Nylon & Polyamide injection molders_1_Texasinjectionmolding.txt', 'Nylon & Polyamide injection molders_80_Pollen.txt', 'Nylon & Polyamide injection molders_78_Nylene.txt', 'Nylon & Polyamide injection molders_53_Resinzone.txt', 'Nylon & Polyamide injection molders_47_Radicigroup.txt', 'Nylon & Polyamide injection molders_12_Xometry.txt', 'Nylon & Polyamide injection molders_49_Polymermolding.txt', 'Nylon & Polyamide injection molders_62_Mfpseals.txt', 'Nylon & Polyamide injection molders_9_Midstatemold.txt', 'Nylon & Polyamide injection molders_85_Emsgrivory.txt', 'Nylon & Polyamide injection molders_13_Ensinger.txt', 'Nylon & Polyamide injection molders_34_Viewmold.txt', 'Nylon & Polyamide injection molders_48_Arkema.txt', 'Nylon & Polyamide injection molders_71_Stratasys.txt', 'Nylon & Polyamide injection molders_8_Sositarmould.txt', 'Nylon & Polyamide injection molders_40_Injectionmould.txt', 'Nylon & Polyamide injection molders_55_Pubmed.txt', 'Nylon & Polyamide injection molders_60_Echosupply.txt', 'Nylon & Polyamide injection molders_96_Formlabs.txt', 'Nylon & Polyamide injection molders_63_Boedeker.txt', 'Nylon & Polyamide injection molders_91_Abtecinc.txt', 'Nylon & Polyamide injection molders_37_Protolabs.txt', 'Nylon & Polyamide injection molders_43_Zdcpu.txt', 'Nylon & Polyamide injection molders_74_Hpp.txt', 'Nylon & Polyamide injection molders_42_Rutlandplastics.txt', 'Nylon & Polyamide injection molders_6_Cnczone.txt', 'Nylon & Polyamide injection molders_10_Vem.txt', 'Nylon & Polyamide injection molders_35_Publishing.txt', 'Nylon & Polyamide injection molders_57_Precisionmoldedplastics.txt', 'Nylon & Polyamide injection molders_16_Rockwestcomposites.txt', 'Nylon & Polyamide injection molders_21_Matweb.txt', 'Nylon & Polyamide injection molders_72_Vsmolding.txt', 'Nylon & Polyamide injection molders_19_Cpielgin.txt', 'Nylon & Polyamide injection molders_83_Essentracomponents.txt', 'Nylon & Polyamide injection molders_51_Zetarmold.txt', 'Nylon & Polyamide injection molders_22_Sybridge.txt', 'Nylon & Polyamide injection molders_58_Plastics.txt', 'Nylon & Polyamide injection molders_25_Omnexus.txt', 'Nylon & Polyamide injection molders_2_Prototool.txt', 'Nylon & Polyamide injection molders_28_Seaskymedical.txt', 'Nylon & Polyamide injection molders_4_Ecomolding.txt', 'Durethan_PA_Injection_Molding_Guide.pdf?docId=79275', 'Nylon & Polyamide injection molders_86_Amcopolymers.txt', 'Nylon & Polyamide injection molders_64_Goodfellow.txt', 'Nylon & Polyamide injection molders_77_Tainstruments.txt', 'Nylon & Polyamide injection molders_68_Aipprecision.txt', 'Nylon & Polyamide injection molders_20_Sybridge.txt', 'Nylon & Polyamide injection molders_59_Spauldingcom.txt', 'Nylon & Polyamide injection molders_69_Waykenrm.txt', 'Nylon & Polyamide injection molders_84_Linkedin.txt', 'Nylon & Polyamide injection molders_82_Advansix.txt', 'Nylon & Polyamide injection molders_46_Alinecomponents.txt', 'Nylon & Polyamide injection molders_50_Resmart.txt', 'Nylon & Polyamide injection molders_0_Retlawindustries.txt', 'Nylon & Polyamide injection molders_3_Ensingerplastics.txt', 'Nylon & Polyamide injection molders_33_Aquafil.txt', 'Nylon & Polyamide injection molders_41_Moldplasticinjection.txt', 'Nylon & Polyamide injection molders_17_Rebling.txt', 'Nylon & Polyamide injection molders_31_Globenewswire.txt', 'Nylon & Polyamide injection molders_89_Vestamid.txt', 'Nylon & Polyamide injection molders_61_Mgc.txt', 'Nylon & Polyamide injection molders_95_Mapnylon.txt', 'Nylon & Polyamide injection molders_66_Entecpolymers.txt', 'Nylon & Polyamide injection molders_39_Cavitymold.txt', 'Nylon & Polyamide injection molders_15_Ensinger.txt']
# Reading File: 0
# Reading file name: Nylon & Polyamide injection molders_30_Immould.txt
#
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "FOW Mould",
#   "Company Website": "http://www.fowmould.com",
#   "Phone Number": "0086-576-84288218",
#   "Location": "No.328 Xiaoliqiao Village, Beiyang Town, Huangyan, Taizhou, Zhejiang, 318024, China",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "FOW Mould is an injection molding company based in China that manufactures plastic injection molds. The material provided is nylon6,6 which is a common material used in injection molding. The context mentions that nylon is used for its strength, heat resistance, and durability in injection molds. Since FOW Mould specializes in injection molding and works with materials like nylon, they are likely to purchase nylon6,6 for their injection molding operations."
# }
# ```
#
# The key information that indicates FOW Mould is likely to purchase nylon6,6:
#
# - They are an injection molding company that manufactures plastic injection molds.
# - The context mentions nylon is commonly used in injection molds for its advantageous properties.
# - As an injection molding company, they are likely to use materials like nylon6,6 that are well-suited for injection molding applications.
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "FOW Mould",
#   "Company Website": "http://www.fowmould.com",
#   "Phone Number": "0086-576-84288218",
#   "Location": "No.328 Xiaoliqiao Village, Beiyang Town, Huangyan, Taizhou, Zhejiang, 318024, China",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "FOW Mould is an injection molding company based in China that manufactures plastic injection molds. The material provided is nylon6,6 which is a common material used in injection molding. The context mentions that nylon is used for its strength, heat resistance, and durability in injection molds. Since FOW Mould specializes in injection molding and works with materials like nylon, they are likely to purchase nylon6,6 for their injection molding operations."
# }
# ```
#
# The key information that indicates FOW Mould is likely to purchase nylon6,6:
#
# - They are an injection molding company that manufactures plastic injection molds.
# - The context mentions nylon is commonly used in injection molds for its advantageous properties.
# - As an injection molding company, they are likely to use materials like nylon6,6 that are well-suited for injection molding applications.
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "FOW Mould",
#   "Company Website": "http://www.fowmould.com",
#   "Phone Number": "0086-576-84288218",
#   "Location": "No.328 Xiaoliqiao Village, Beiyang Town, Huangyan, Taizhou, Zhejiang, 318024, China",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "FOW Mould is an injection molding company based in China that manufactures plastic injection molds. The material provided is nylon6,6 which is a common material used in injection molding. The context mentions that nylon is used for its strength, heat resistance, and durability in injection molds. Since FOW Mould specializes in injection molding and works with materials like nylon, they are likely to purchase nylon6,6 for their injection molding operations."
# }
# ```
#
# The key information that indicates FOW Mould is likely to purchase nylon6,6:
#
# - They are an injection molding company that manufactures plastic injection molds.
# - The context mentions nylon is commonly used in injection molds for its advantageous properties.
# - As an injection molding company, they are likely to use materials like nylon6,6 that are well-suited for injection molding applications.
# Extracted JSON Part
# {
#   "Company_Name": "FOW Mould",
#   "Company Website": "http://www.fowmould.com",
#   "Phone Number": "0086-576-84288218",
#   "Location": "No.328 Xiaoliqiao Village, Beiyang Town, Huangyan, Taizhou, Zhejiang, 318024, China",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "FOW Mould is an injection molding company based in China that manufactures plastic injection molds. The material provided is nylon6,6 which is a common material used in injection molding. The context mentions that nylon is used for its strength, heat resistance, and durability in injection molds. Since FOW Mould specializes in injection molding and works with materials like nylon, they are likely to purchase nylon6,6 for their injection molding operations."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 1
# Reading file name: Nylon & Polyamide injection molders_67_Bpf.txt
#
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "No company name or contact details are provided in the given context. The context talks about properties, types, applications etc. of nylon material but does not indicate any specific company that might purchase nylon6,6 material."
# }
# ```
#
# I could not identify any injection molding company details that might purchase nylon6,6 material from the given context. The context provides general information about nylon materials but does not mention any potential buyers. Since there is insufficient information to predict if a company is likely to purchase, I have returned "Not likely to purchase" for Prediction and provided the reason that no company details are present. The other fields have "N/A" entered accordingly.
# The data is not in JSON format.
# Printing data Text:
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "No company name or contact details are provided in the given context. The context talks about properties, types, applications etc. of nylon material but does not indicate any specific company that might purchase nylon6,6 material."
# }
# ```
#
# I could not identify any injection molding company details that might purchase nylon6,6 material from the given context. The context provides general information about nylon materials but does not mention any potential buyers. Since there is insufficient information to predict if a company is likely to purchase, I have returned "Not likely to purchase" for Prediction and provided the reason that no company details are present. The other fields have "N/A" entered accordingly.
# Printing data after removing backticks:
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "No company name or contact details are provided in the given context. The context talks about properties, types, applications etc. of nylon material but does not indicate any specific company that might purchase nylon6,6 material."
# }
# ```
#
# I could not identify any injection molding company details that might purchase nylon6,6 material from the given context. The context provides general information about nylon materials but does not mention any potential buyers. Since there is insufficient information to predict if a company is likely to purchase, I have returned "Not likely to purchase" for Prediction and provided the reason that no company details are present. The other fields have "N/A" entered accordingly.
# Extracted JSON Part
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "No company name or contact details are provided in the given context. The context talks about properties, types, applications etc. of nylon material but does not indicate any specific company that might purchase nylon6,6 material."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 2
# Reading file name: Nylon & Polyamide injection molders_29_Pmcplastics.txt
#
#  Based on the context, here is the relevant information extracted in JSON format:
#
# ```json
# {
#   "Company_Name": "Plastic Molded Concepts, Inc.",
#   "Company Website": "https://www.plasticmoldedconcepts.com/",
#   "Phone Number": "(262) 594-5050",
#   "Location": "Eagle, WI, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company Plastic Molded Concepts specializes in injection molding using engineered resins like glass filled nylon. The article discusses the benefits of glass filled nylon for injection molded parts that need high strength and heat resistance. Since PMC has expertise working with these materials, they are likely to purchase nylon6,6 for their injection molding applications."
# }
# ```
#
# The key information showing Plastic Molded Concepts is likely to purchase nylon6,6:
#
# - They specialize in injection molding using engineered resins
# - The article discusses using glass filled nylon, an engineered resin
# - Nylon6,6 is also an engineered resin that can be used for injection molding
# - PMC has expertise working with these types of materials
#
# Therefore, I predicted they are likely to purchase nylon6,6 based on their capabilities and focus on engineered resins.
# The data is not in JSON format.
# Printing data Text:
#  Based on the context, here is the relevant information extracted in JSON format:
#
# ```json
# {
#   "Company_Name": "Plastic Molded Concepts, Inc.",
#   "Company Website": "https://www.plasticmoldedconcepts.com/",
#   "Phone Number": "(262) 594-5050",
#   "Location": "Eagle, WI, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company Plastic Molded Concepts specializes in injection molding using engineered resins like glass filled nylon. The article discusses the benefits of glass filled nylon for injection molded parts that need high strength and heat resistance. Since PMC has expertise working with these materials, they are likely to purchase nylon6,6 for their injection molding applications."
# }
# ```
#
# The key information showing Plastic Molded Concepts is likely to purchase nylon6,6:
#
# - They specialize in injection molding using engineered resins
# - The article discusses using glass filled nylon, an engineered resin
# - Nylon6,6 is also an engineered resin that can be used for injection molding
# - PMC has expertise working with these types of materials
#
# Therefore, I predicted they are likely to purchase nylon6,6 based on their capabilities and focus on engineered resins.
# Printing data after removing backticks:
#  Based on the context, here is the relevant information extracted in JSON format:
#
# ```json
# {
#   "Company_Name": "Plastic Molded Concepts, Inc.",
#   "Company Website": "https://www.plasticmoldedconcepts.com/",
#   "Phone Number": "(262) 594-5050",
#   "Location": "Eagle, WI, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company Plastic Molded Concepts specializes in injection molding using engineered resins like glass filled nylon. The article discusses the benefits of glass filled nylon for injection molded parts that need high strength and heat resistance. Since PMC has expertise working with these materials, they are likely to purchase nylon6,6 for their injection molding applications."
# }
# ```
#
# The key information showing Plastic Molded Concepts is likely to purchase nylon6,6:
#
# - They specialize in injection molding using engineered resins
# - The article discusses using glass filled nylon, an engineered resin
# - Nylon6,6 is also an engineered resin that can be used for injection molding
# - PMC has expertise working with these types of materials
#
# Therefore, I predicted they are likely to purchase nylon6,6 based on their capabilities and focus on engineered resins.
# Extracted JSON Part
# {
#   "Company_Name": "Plastic Molded Concepts, Inc.",
#   "Company Website": "https://www.plasticmoldedconcepts.com/",
#   "Phone Number": "(262) 594-5050",
#   "Location": "Eagle, WI, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company Plastic Molded Concepts specializes in injection molding using engineered resins like glass filled nylon. The article discusses the benefits of glass filled nylon for injection molded parts that need high strength and heat resistance. Since PMC has expertise working with these materials, they are likely to purchase nylon6,6 for their injection molding applications."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 3
# Reading file name: Nylon & Polyamide injection molders_1_Texasinjectionmolding.txt
#
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "Texas Injection Molding",
#   "Company Website": "texasinjectionmolding.com",
#   "Phone Number": "281-489-4292",
#   "Location": "Houston, TX, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Texas Injection Molding is an injection molding company that manufactures plastic parts. The context mentions they process nylon through injection molding procedures and form thin- and thick-walled parts. Since they work with nylon and have injection molding capabilities, they are likely to purchase nylon6,6 material."
# }
# ```
#
# To summarize, Texas Injection Molding is predicted to likely purchase nylon6,6 because:
#
# - They are an injection molding company that manufactures plastic parts
# - They specifically process nylon through injection molding
# - They form thin- and thick-walled nylon parts
# - The material provided, nylon6,6, is a type of nylon they would use in their injection molding applications
#
# Therefore, they have the capabilities and use case to purchase nylon6,6 material.
# The data is not in JSON format.
# Printing data Text:
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "Texas Injection Molding",
#   "Company Website": "texasinjectionmolding.com",
#   "Phone Number": "281-489-4292",
#   "Location": "Houston, TX, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Texas Injection Molding is an injection molding company that manufactures plastic parts. The context mentions they process nylon through injection molding procedures and form thin- and thick-walled parts. Since they work with nylon and have injection molding capabilities, they are likely to purchase nylon6,6 material."
# }
# ```
#
# To summarize, Texas Injection Molding is predicted to likely purchase nylon6,6 because:
#
# - They are an injection molding company that manufactures plastic parts
# - They specifically process nylon through injection molding
# - They form thin- and thick-walled nylon parts
# - The material provided, nylon6,6, is a type of nylon they would use in their injection molding applications
#
# Therefore, they have the capabilities and use case to purchase nylon6,6 material.
# Printing data after removing backticks:
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "Texas Injection Molding",
#   "Company Website": "texasinjectionmolding.com",
#   "Phone Number": "281-489-4292",
#   "Location": "Houston, TX, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Texas Injection Molding is an injection molding company that manufactures plastic parts. The context mentions they process nylon through injection molding procedures and form thin- and thick-walled parts. Since they work with nylon and have injection molding capabilities, they are likely to purchase nylon6,6 material."
# }
# ```
#
# To summarize, Texas Injection Molding is predicted to likely purchase nylon6,6 because:
#
# - They are an injection molding company that manufactures plastic parts
# - They specifically process nylon through injection molding
# - They form thin- and thick-walled nylon parts
# - The material provided, nylon6,6, is a type of nylon they would use in their injection molding applications
#
# Therefore, they have the capabilities and use case to purchase nylon6,6 material.
# Extracted JSON Part
# {
#   "Company_Name": "Texas Injection Molding",
#   "Company Website": "texasinjectionmolding.com",
#   "Phone Number": "281-489-4292",
#   "Location": "Houston, TX, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Texas Injection Molding is an injection molding company that manufactures plastic parts. The context mentions they process nylon through injection molding procedures and form thin- and thick-walled parts. Since they work with nylon and have injection molding capabilities, they are likely to purchase nylon6,6 material."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 4
# Reading file name: Nylon & Polyamide injection molders_80_Pollen.txt
#
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Pollen AM",
#   "Company Website": "https://www.pollen.am",
#   "Phone Number": "+33 (0)1 58 46 20 52",
#   "Location": "France",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The company Pollen AM manufactures their own 3D printers and materials. They do not seem to be an injection molding company that would purchase nylon6,6 material. Instead, they produce their own materials for use in their 3D printers."
# }
# ```
#
# To summarize:
# - Pollen AM is a 3D printer and materials manufacturer, not an injection molding company
# - They produce their own materials like PA-12 rather than purchasing nylon6,6
# - So they are not likely to purchase the given nylon6,6 material
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Pollen AM",
#   "Company Website": "https://www.pollen.am",
#   "Phone Number": "+33 (0)1 58 46 20 52",
#   "Location": "France",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The company Pollen AM manufactures their own 3D printers and materials. They do not seem to be an injection molding company that would purchase nylon6,6 material. Instead, they produce their own materials for use in their 3D printers."
# }
# ```
#
# To summarize:
# - Pollen AM is a 3D printer and materials manufacturer, not an injection molding company
# - They produce their own materials like PA-12 rather than purchasing nylon6,6
# - So they are not likely to purchase the given nylon6,6 material
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Pollen AM",
#   "Company Website": "https://www.pollen.am",
#   "Phone Number": "+33 (0)1 58 46 20 52",
#   "Location": "France",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The company Pollen AM manufactures their own 3D printers and materials. They do not seem to be an injection molding company that would purchase nylon6,6 material. Instead, they produce their own materials for use in their 3D printers."
# }
# ```
#
# To summarize:
# - Pollen AM is a 3D printer and materials manufacturer, not an injection molding company
# - They produce their own materials like PA-12 rather than purchasing nylon6,6
# - So they are not likely to purchase the given nylon6,6 material
# Extracted JSON Part
# {
#   "Company_Name": "Pollen AM",
#   "Company Website": "https://www.pollen.am",
#   "Phone Number": "+33 (0)1 58 46 20 52",
#   "Location": "France",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "The company Pollen AM manufactures their own 3D printers and materials. They do not seem to be an injection molding company that would purchase nylon6,6 material. Instead, they produce their own materials for use in their 3D printers."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 5
# Reading file name: Nylon & Polyamide injection molders_78_Nylene.txt
#
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```JSON
# {
#   "Company_Name": "Nylene Specialty Nylon",
#   "Company Website": "https://www.nylene.com",
#   "Phone Number": "973-694-3549",
#   "Location": "North America",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Nylene Specialty Nylon manufactures and supplies various nylon products including nylon 6,6. They have capabilities for custom compounding and offer technical services. As they work with nylon 6,6, it is likely they will purchase more to use in their manufacturing and compounding processes."
# }
# ```
#
# To summarize:
# - Nylene Specialty Nylon is a company that manufactures and supplies nylon products
# - They specifically work with nylon 6,6, which is the material tag provided
# - They have custom compounding and technical services capabilities
# - As they utilize nylon 6,6 in their operations, it is likely they will purchase more to use as feedstock for their manufacturing and compounding
#
# Therefore, I predicted "Likely to purchase" along with a reason explaining why they would likely purchase more nylon 6,6. Let me know if you need any clarification or have additional questions!
# The data is not in JSON format.
# Printing data Text:
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```JSON
# {
#   "Company_Name": "Nylene Specialty Nylon",
#   "Company Website": "https://www.nylene.com",
#   "Phone Number": "973-694-3549",
#   "Location": "North America",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Nylene Specialty Nylon manufactures and supplies various nylon products including nylon 6,6. They have capabilities for custom compounding and offer technical services. As they work with nylon 6,6, it is likely they will purchase more to use in their manufacturing and compounding processes."
# }
# ```
#
# To summarize:
# - Nylene Specialty Nylon is a company that manufactures and supplies nylon products
# - They specifically work with nylon 6,6, which is the material tag provided
# - They have custom compounding and technical services capabilities
# - As they utilize nylon 6,6 in their operations, it is likely they will purchase more to use as feedstock for their manufacturing and compounding
#
# Therefore, I predicted "Likely to purchase" along with a reason explaining why they would likely purchase more nylon 6,6. Let me know if you need any clarification or have additional questions!
# Printing data after removing backticks:
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```JSON
# {
#   "Company_Name": "Nylene Specialty Nylon",
#   "Company Website": "https://www.nylene.com",
#   "Phone Number": "973-694-3549",
#   "Location": "North America",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Nylene Specialty Nylon manufactures and supplies various nylon products including nylon 6,6. They have capabilities for custom compounding and offer technical services. As they work with nylon 6,6, it is likely they will purchase more to use in their manufacturing and compounding processes."
# }
# ```
#
# To summarize:
# - Nylene Specialty Nylon is a company that manufactures and supplies nylon products
# - They specifically work with nylon 6,6, which is the material tag provided
# - They have custom compounding and technical services capabilities
# - As they utilize nylon 6,6 in their operations, it is likely they will purchase more to use as feedstock for their manufacturing and compounding
#
# Therefore, I predicted "Likely to purchase" along with a reason explaining why they would likely purchase more nylon 6,6. Let me know if you need any clarification or have additional questions!
# Extracted JSON Part
# {
#   "Company_Name": "Nylene Specialty Nylon",
#   "Company Website": "https://www.nylene.com",
#   "Phone Number": "973-694-3549",
#   "Location": "North America",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Nylene Specialty Nylon manufactures and supplies various nylon products including nylon 6,6. They have capabilities for custom compounding and offer technical services. As they work with nylon 6,6, it is likely they will purchase more to use in their manufacturing and compounding processes."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 6
# Reading file name: Nylon & Polyamide injection molders_53_Resinzone.txt
#
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "ResinZone",
#   "Company Website": "https://www.resinzone.com",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "ResinZone is an online store that sells various plastic resins, including nylon6,6 which is the material tag provided. As they specialize in selling plastic resins, it is likely they would purchase nylon6,6 to resell on their website."
# }
# ```
#
# To summarize:
#
# - ResinZone is identified as the company name based on the website URL resinzone.com provided in the context.
# - No phone number or location details are provided, so I have put "N/A".
# - I predicted "Likely to purchase" as ResinZone specializes in selling plastic resins, including nylons, so they would likely purchase nylon6,6 to resell on their site.
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "ResinZone",
#   "Company Website": "https://www.resinzone.com",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "ResinZone is an online store that sells various plastic resins, including nylon6,6 which is the material tag provided. As they specialize in selling plastic resins, it is likely they would purchase nylon6,6 to resell on their website."
# }
# ```
#
# To summarize:
#
# - ResinZone is identified as the company name based on the website URL resinzone.com provided in the context.
# - No phone number or location details are provided, so I have put "N/A".
# - I predicted "Likely to purchase" as ResinZone specializes in selling plastic resins, including nylons, so they would likely purchase nylon6,6 to resell on their site.
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "ResinZone",
#   "Company Website": "https://www.resinzone.com",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "ResinZone is an online store that sells various plastic resins, including nylon6,6 which is the material tag provided. As they specialize in selling plastic resins, it is likely they would purchase nylon6,6 to resell on their website."
# }
# ```
#
# To summarize:
#
# - ResinZone is identified as the company name based on the website URL resinzone.com provided in the context.
# - No phone number or location details are provided, so I have put "N/A".
# - I predicted "Likely to purchase" as ResinZone specializes in selling plastic resins, including nylons, so they would likely purchase nylon6,6 to resell on their site.
# Extracted JSON Part
# {
#   "Company_Name": "ResinZone",
#   "Company Website": "https://www.resinzone.com",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "ResinZone is an online store that sells various plastic resins, including nylon6,6 which is the material tag provided. As they specialize in selling plastic resins, it is likely they would purchase nylon6,6 to resell on their website."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 7
# Reading file name: Nylon & Polyamide injection molders_47_Radicigroup.txt
#
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "RadiciGroup",
#   "Company Website": "https://www.radicigroup.com",
#   "Phone Number": "N/A",
#   "Location": "Italy",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "RadiciGroup manufactures a variety of plastic and synthetic materials including nylon6,6 which is the material tag provided. As a major manufacturer and supplier of these materials, it is likely they would purchase more nylon6,6 to use in their own production processes."
# }
# ```
#
# To summarize:
# - RadiciGroup is a major manufacturer of plastics and synthetic materials including nylon6,6
# - As they produce materials like nylon6,6 themselves, it is likely they would purchase more to use as input for their production processes
# - No phone number or specific location beyond Italy were provided in the context
#
# Let me know if you need any clarification or have additional questions!
# The data is not in JSON format.
# Printing data Text:
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "RadiciGroup",
#   "Company Website": "https://www.radicigroup.com",
#   "Phone Number": "N/A",
#   "Location": "Italy",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "RadiciGroup manufactures a variety of plastic and synthetic materials including nylon6,6 which is the material tag provided. As a major manufacturer and supplier of these materials, it is likely they would purchase more nylon6,6 to use in their own production processes."
# }
# ```
#
# To summarize:
# - RadiciGroup is a major manufacturer of plastics and synthetic materials including nylon6,6
# - As they produce materials like nylon6,6 themselves, it is likely they would purchase more to use as input for their production processes
# - No phone number or specific location beyond Italy were provided in the context
#
# Let me know if you need any clarification or have additional questions!
# Printing data after removing backticks:
#  Here is the analysis in JSON format:
#
# ```json
# {
#   "Company_Name": "RadiciGroup",
#   "Company Website": "https://www.radicigroup.com",
#   "Phone Number": "N/A",
#   "Location": "Italy",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "RadiciGroup manufactures a variety of plastic and synthetic materials including nylon6,6 which is the material tag provided. As a major manufacturer and supplier of these materials, it is likely they would purchase more nylon6,6 to use in their own production processes."
# }
# ```
#
# To summarize:
# - RadiciGroup is a major manufacturer of plastics and synthetic materials including nylon6,6
# - As they produce materials like nylon6,6 themselves, it is likely they would purchase more to use as input for their production processes
# - No phone number or specific location beyond Italy were provided in the context
#
# Let me know if you need any clarification or have additional questions!
# Extracted JSON Part
# {
#   "Company_Name": "RadiciGroup",
#   "Company Website": "https://www.radicigroup.com",
#   "Phone Number": "N/A",
#   "Location": "Italy",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "RadiciGroup manufactures a variety of plastic and synthetic materials including nylon6,6 which is the material tag provided. As a major manufacturer and supplier of these materials, it is likely they would purchase more nylon6,6 to use in their own production processes."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 8
# Reading file name: Nylon & Polyamide injection molders_12_Xometry.txt
#
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "No company name, website, phone number or location was provided in the context to determine if they are an injection molding company that might purchase the nylon6,6 material."
# }
# ```
#
# The context talks about the differences between polyamides and nylons, but does not provide any information about a specific company that might purchase the nylon6,6 material. As such, I have responded with "N/A" for the company details and "Not likely to purchase" for the prediction, along with a reason explaining why there is not enough information to make a determination.
# The data is not in JSON format.
# Printing data Text:
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "No company name, website, phone number or location was provided in the context to determine if they are an injection molding company that might purchase the nylon6,6 material."
# }
# ```
#
# The context talks about the differences between polyamides and nylons, but does not provide any information about a specific company that might purchase the nylon6,6 material. As such, I have responded with "N/A" for the company details and "Not likely to purchase" for the prediction, along with a reason explaining why there is not enough information to make a determination.
# Printing data after removing backticks:
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "No company name, website, phone number or location was provided in the context to determine if they are an injection molding company that might purchase the nylon6,6 material."
# }
# ```
#
# The context talks about the differences between polyamides and nylons, but does not provide any information about a specific company that might purchase the nylon6,6 material. As such, I have responded with "N/A" for the company details and "Not likely to purchase" for the prediction, along with a reason explaining why there is not enough information to make a determination.
# Extracted JSON Part
# {
#   "Company_Name": "N/A",
#   "Company Website": "N/A",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Not likely to purchase",
#   "Prediction_Reason": "No company name, website, phone number or location was provided in the context to determine if they are an injection molding company that might purchase the nylon6,6 material."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 9
# Reading file name: Nylon & Polyamide injection molders_49_Polymermolding.txt
#
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Polymer Molding Inc.",
#   "Company Website": "https://www.polymermolding.com/",
#   "Phone Number": "800.344.7584",
#   "Location": "Erie, PA, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company Polymer Molding Inc. is an injection molding company that manufactures custom plastic parts. The context mentions they use materials like nylon, polypropylene etc. for injection molding. Since they use nylon for injection molding applications, they are likely to purchase the given material nylon6,6."
# }
# ```
#
# To summarize:
#
# - The company name is Polymer Molding Inc.
# - Their website is https://www.polymermolding.com/
# - Their phone number is 800.344.7584
# - They are located in Erie, PA, United States
# - They are likely to purchase the given nylon6,6 material because they manufacture custom injection molded plastic parts using nylon and other plastics. So they have applications where nylon6,6 could be used.
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Polymer Molding Inc.",
#   "Company Website": "https://www.polymermolding.com/",
#   "Phone Number": "800.344.7584",
#   "Location": "Erie, PA, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company Polymer Molding Inc. is an injection molding company that manufactures custom plastic parts. The context mentions they use materials like nylon, polypropylene etc. for injection molding. Since they use nylon for injection molding applications, they are likely to purchase the given material nylon6,6."
# }
# ```
#
# To summarize:
#
# - The company name is Polymer Molding Inc.
# - Their website is https://www.polymermolding.com/
# - Their phone number is 800.344.7584
# - They are located in Erie, PA, United States
# - They are likely to purchase the given nylon6,6 material because they manufacture custom injection molded plastic parts using nylon and other plastics. So they have applications where nylon6,6 could be used.
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Polymer Molding Inc.",
#   "Company Website": "https://www.polymermolding.com/",
#   "Phone Number": "800.344.7584",
#   "Location": "Erie, PA, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company Polymer Molding Inc. is an injection molding company that manufactures custom plastic parts. The context mentions they use materials like nylon, polypropylene etc. for injection molding. Since they use nylon for injection molding applications, they are likely to purchase the given material nylon6,6."
# }
# ```
#
# To summarize:
#
# - The company name is Polymer Molding Inc.
# - Their website is https://www.polymermolding.com/
# - Their phone number is 800.344.7584
# - They are located in Erie, PA, United States
# - They are likely to purchase the given nylon6,6 material because they manufacture custom injection molded plastic parts using nylon and other plastics. So they have applications where nylon6,6 could be used.
# Extracted JSON Part
# {
#   "Company_Name": "Polymer Molding Inc.",
#   "Company Website": "https://www.polymermolding.com/",
#   "Phone Number": "800.344.7584",
#   "Location": "Erie, PA, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The company Polymer Molding Inc. is an injection molding company that manufactures custom plastic parts. The context mentions they use materials like nylon, polypropylene etc. for injection molding. Since they use nylon for injection molding applications, they are likely to purchase the given material nylon6,6."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 10
# Reading file name: Nylon & Polyamide injection molders_62_Mfpseals.txt
#
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Martin Fluid Power",
#   "Company Website": "www.mfpseals.com",
#   "Phone Number": "(248) 585-8170",
#   "Location": "Madison Heights, MI, USA",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Martin Fluid Power specializes in plastic injection molding and manufactures custom injection molded parts. They have capabilities for insert molding, overmolding, tight tolerances, complex shapes, etc. They work with a variety of moldable materials including nylon6,6. So they are likely to purchase nylon6,6 material for their injection molding manufacturing."
# }
# ```
#
# I extracted the company name, website, phone number, and location from the context. Based on the details provided that Martin Fluid Power specializes in plastic injection molding and works with various materials including nylons, I predicted they are likely to purchase the nylon6,6 material. My reason is that they have the capabilities and expertise to manufacture custom injection molded parts using nylon6,6.
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Martin Fluid Power",
#   "Company Website": "www.mfpseals.com",
#   "Phone Number": "(248) 585-8170",
#   "Location": "Madison Heights, MI, USA",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Martin Fluid Power specializes in plastic injection molding and manufactures custom injection molded parts. They have capabilities for insert molding, overmolding, tight tolerances, complex shapes, etc. They work with a variety of moldable materials including nylon6,6. So they are likely to purchase nylon6,6 material for their injection molding manufacturing."
# }
# ```
#
# I extracted the company name, website, phone number, and location from the context. Based on the details provided that Martin Fluid Power specializes in plastic injection molding and works with various materials including nylons, I predicted they are likely to purchase the nylon6,6 material. My reason is that they have the capabilities and expertise to manufacture custom injection molded parts using nylon6,6.
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Martin Fluid Power",
#   "Company Website": "www.mfpseals.com",
#   "Phone Number": "(248) 585-8170",
#   "Location": "Madison Heights, MI, USA",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Martin Fluid Power specializes in plastic injection molding and manufactures custom injection molded parts. They have capabilities for insert molding, overmolding, tight tolerances, complex shapes, etc. They work with a variety of moldable materials including nylon6,6. So they are likely to purchase nylon6,6 material for their injection molding manufacturing."
# }
# ```
#
# I extracted the company name, website, phone number, and location from the context. Based on the details provided that Martin Fluid Power specializes in plastic injection molding and works with various materials including nylons, I predicted they are likely to purchase the nylon6,6 material. My reason is that they have the capabilities and expertise to manufacture custom injection molded parts using nylon6,6.
# Extracted JSON Part
# {
#   "Company_Name": "Martin Fluid Power",
#   "Company Website": "www.mfpseals.com",
#   "Phone Number": "(248) 585-8170",
#   "Location": "Madison Heights, MI, USA",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Martin Fluid Power specializes in plastic injection molding and manufactures custom injection molded parts. They have capabilities for insert molding, overmolding, tight tolerances, complex shapes, etc. They work with a variety of moldable materials including nylon6,6. So they are likely to purchase nylon6,6 material for their injection molding manufacturing."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 11
# Reading file name: Nylon & Polyamide injection molders_9_Midstatemold.txt
#
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Midstate Mold & Engineering",
#   "Company Website": "https://www.midstatemold.com",
#   "Phone Number": "+1.508-520-0011",
#   "Location": "Franklin, MA, USA",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Midstate Mold & Engineering is an injection molding company that manufactures precision plastic parts. The context mentions they have experience working with thermoplastics like polyamide (nylon 6,6). Since nylon 6,6 is a common material used in injection molding, and Midstate Mold specializes in injection molding, they are likely to purchase nylon 6,6 for their manufacturing processes."
# }
# ```
#
# The key information I extracted:
#
# - Company Name: Midstate Mold & Engineering
# - Company Website: https://www.midstatemold.com
# - Phone Number: +1.508-520-0011
# - Location: Franklin, MA, USA
# - Prediction: Likely to purchase
# - Prediction Reason: They are an injection molding company with experience using thermoplastics like nylon 6,6, so they would likely purchase more nylon 6,6 for their injection molding manufacturing.
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Midstate Mold & Engineering",
#   "Company Website": "https://www.midstatemold.com",
#   "Phone Number": "+1.508-520-0011",
#   "Location": "Franklin, MA, USA",
#   "Prediction": "Likely to purchase",
# ...
# The data is not in JSON format.
# Printing data Text:
#  Based on the context provided, here is the information I extracted:
#
# ```json
# {
#   "Company_Name": "MGC Advanced Polymers, Inc. (MAP)",
#   "Company Website": "https://www.mgcpolymer.com",
#   "Phone Number": "(804) 520-7800",
#   "Location": "Colonial Heights, VA, USA",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "MGC Advanced Polymers is an injection molding company that manufactures high performance plastics and polymers. The material provided is nylon6,6 which is a type of polymer. Since MGC Advanced Polymers specializes in working with polymers and plastics, it is likely they would purchase nylon6,6 to use in their injection molding and manufacturing processes."
# }
# ```
#
# The key reasons I predicted MGC Advanced Polymers is likely to purchase nylon6,6:
#
# - They specialize in high performance plastics and polymers
# - Nylon6,6 is a polymer material they may use in their injection molding applications
# - Their website and capabilities match well with potential uses for nylon6,6
#
# Please let me know if you need any other information or have additional context to provide. I'm happy to re-evaluate my prediction.
# Printing data after removing backticks:
#  Based on the context provided, here is the information I extracted:
#
# ```json
# {
#   "Company_Name": "MGC Advanced Polymers, Inc. (MAP)",
#   "Company Website": "https://www.mgcpolymer.com",
#   "Phone Number": "(804) 520-7800",
#   "Location": "Colonial Heights, VA, USA",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "MGC Advanced Polymers is an injection molding company that manufactures high performance plastics and polymers. The material provided is nylon6,6 which is a type of polymer. Since MGC Advanced Polymers specializes in working with polymers and plastics, it is likely they would purchase nylon6,6 to use in their injection molding and manufacturing processes."
# }
# ```
#
# The key reasons I predicted MGC Advanced Polymers is likely to purchase nylon6,6:
#
# - They specialize in high performance plastics and polymers
# - Nylon6,6 is a polymer material they may use in their injection molding applications
# - Their website and capabilities match well with potential uses for nylon6,6
#
# Please let me know if you need any other information or have additional context to provide. I'm happy to re-evaluate my prediction.
# Extracted JSON Part
# {
#   "Company_Name": "MGC Advanced Polymers, Inc. (MAP)",
#   "Company Website": "https://www.mgcpolymer.com",
#   "Phone Number": "(804) 520-7800",
#   "Location": "Colonial Heights, VA, USA",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "MGC Advanced Polymers is an injection molding company that manufactures high performance plastics and polymers. The material provided is nylon6,6 which is a type of polymer. Since MGC Advanced Polymers specializes in working with polymers and plastics, it is likely they would purchase nylon6,6 to use in their injection molding and manufacturing processes."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 65
# Reading file name: Nylon & Polyamide injection molders_66_Entecpolymers.txt
#
#  Based on the context, here is the information I extracted:
#
# ```json
# {
#   "Company_Name": "Entec Polymers",
#   "Company Website": "https://entecpolymers.com/",
#   "Phone Number": "N/A",
#   "Location": "Orlando, FL, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Entec Polymers is an injection molding company that offers nylon resins, including nylon 6/12 copolymer, for various applications like tubing, so they are likely to purchase more nylon 6,6 to use in their injection molding manufacturing."
# }
# ```
#
# To summarize, Entec Polymers is an injection molding company located in Orlando, FL that works with various nylon resins. Since they already use nylon resins like nylon 6/12 copolymer for injection molding applications, it is likely they would also purchase nylon 6,6 to use as a material for injection molding different products. I provided their company name, website, and location in Florida. Their phone number was not available. My prediction reason explains why I think they would likely purchase more nylon 6,6 based on their current use of similar nylon resins.
# The data is not in JSON format.
# Printing data Text:
#  Based on the context, here is the information I extracted:
#
# ```json
# {
#   "Company_Name": "Entec Polymers",
#   "Company Website": "https://entecpolymers.com/",
#   "Phone Number": "N/A",
#   "Location": "Orlando, FL, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Entec Polymers is an injection molding company that offers nylon resins, including nylon 6/12 copolymer, for various applications like tubing, so they are likely to purchase more nylon 6,6 to use in their injection molding manufacturing."
# }
# ```
#
# To summarize, Entec Polymers is an injection molding company located in Orlando, FL that works with various nylon resins. Since they already use nylon resins like nylon 6/12 copolymer for injection molding applications, it is likely they would also purchase nylon 6,6 to use as a material for injection molding different products. I provided their company name, website, and location in Florida. Their phone number was not available. My prediction reason explains why I think they would likely purchase more nylon 6,6 based on their current use of similar nylon resins.
# Printing data after removing backticks:
#  Based on the context, here is the information I extracted:
#
# ```json
# {
#   "Company_Name": "Entec Polymers",
#   "Company Website": "https://entecpolymers.com/",
#   "Phone Number": "N/A",
#   "Location": "Orlando, FL, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Entec Polymers is an injection molding company that offers nylon resins, including nylon 6/12 copolymer, for various applications like tubing, so they are likely to purchase more nylon 6,6 to use in their injection molding manufacturing."
# }
# ```
#
# To summarize, Entec Polymers is an injection molding company located in Orlando, FL that works with various nylon resins. Since they already use nylon resins like nylon 6/12 copolymer for injection molding applications, it is likely they would also purchase nylon 6,6 to use as a material for injection molding different products. I provided their company name, website, and location in Florida. Their phone number was not available. My prediction reason explains why I think they would likely purchase more nylon 6,6 based on their current use of similar nylon resins.
# Extracted JSON Part
# {
#   "Company_Name": "Entec Polymers",
#   "Company Website": "https://entecpolymers.com/",
#   "Phone Number": "N/A",
#   "Location": "Orlando, FL, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Entec Polymers is an injection molding company that offers nylon resins, including nylon 6/12 copolymer, for various applications like tubing, so they are likely to purchase more nylon 6,6 to use in their injection molding manufacturing."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 66
# Reading file name: Nylon & Polyamide injection molders_39_Cavitymold.txt
#
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```JSON
# {
#   "Company_Name": "Cavity Mold",
#   "Company Website": "https://www.cavitymold.com/",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The article discusses the properties and applications of nylon and ABS plastics in injection molding. It mentions that the company Cavity Mold offers injection molding services for various plastics including nylon and ABS. Since they have experience working with nylon, they are likely to purchase nylon material for injection molding projects."
# }
# ```
#
# To summarize:
# - The company name Cavity Mold is clearly identified
# - Their website is listed in the context
# - No phone number is provided, so I put "N/A"
# - No specific location beyond the website is given, so location is "N/A"
# - I predicted they are likely to purchase nylon material because the article states they have experience injection molding nylon products
# - My reason for the prediction is that their experience working with nylon makes them a good candidate to purchase more nylon material
# The data is not in JSON format.
# Printing data Text:
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```JSON
# {
#   "Company_Name": "Cavity Mold",
#   "Company Website": "https://www.cavitymold.com/",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The article discusses the properties and applications of nylon and ABS plastics in injection molding. It mentions that the company Cavity Mold offers injection molding services for various plastics including nylon and ABS. Since they have experience working with nylon, they are likely to purchase nylon material for injection molding projects."
# }
# ```
#
# To summarize:
# - The company name Cavity Mold is clearly identified
# - Their website is listed in the context
# - No phone number is provided, so I put "N/A"
# - No specific location beyond the website is given, so location is "N/A"
# - I predicted they are likely to purchase nylon material because the article states they have experience injection molding nylon products
# - My reason for the prediction is that their experience working with nylon makes them a good candidate to purchase more nylon material
# Printing data after removing backticks:
#  Based on the context provided, here is the extracted information in JSON format:
#
# ```JSON
# {
#   "Company_Name": "Cavity Mold",
#   "Company Website": "https://www.cavitymold.com/",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The article discusses the properties and applications of nylon and ABS plastics in injection molding. It mentions that the company Cavity Mold offers injection molding services for various plastics including nylon and ABS. Since they have experience working with nylon, they are likely to purchase nylon material for injection molding projects."
# }
# ```
#
# To summarize:
# - The company name Cavity Mold is clearly identified
# - Their website is listed in the context
# - No phone number is provided, so I put "N/A"
# - No specific location beyond the website is given, so location is "N/A"
# - I predicted they are likely to purchase nylon material because the article states they have experience injection molding nylon products
# - My reason for the prediction is that their experience working with nylon makes them a good candidate to purchase more nylon material
# Extracted JSON Part
# {
#   "Company_Name": "Cavity Mold",
#   "Company Website": "https://www.cavitymold.com/",
#   "Phone Number": "N/A",
#   "Location": "N/A",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "The article discusses the properties and applications of nylon and ABS plastics in injection molding. It mentions that the company Cavity Mold offers injection molding services for various plastics including nylon and ABS. Since they have experience working with nylon, they are likely to purchase nylon material for injection molding projects."
# }
# Data Type after extracting data: <class 'dict'>
#
# Reading File: 67
# Reading file name: Nylon & Polyamide injection molders_15_Ensinger.txt
#
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Ensinger Precision Components",
#   "Company Website": "https://www.ensingerplastics.com/",
#   "Phone Number": "(704) 992-8100, (860) 928-7911",
#   "Location": "Huntersville, NC, Putnam, CT, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Ensinger Precision Components is an injection molding and advanced manufacturing company that uses high performance thermoplastics. The material provided, 30% glass filled nylon 6/6, is a high performance thermoplastic that is well-suited for injection molding. Therefore, Ensinger Precision Components is likely to purchase this material."
# }
# ```
#
# The key information I extracted:
#
# - Company Name: Ensinger Precision Components
# - Company Website: https://www.ensingerplastics.com/
# - Phone Numbers: (704) 992-8100, (860) 928-7911
# - Locations: Huntersville, NC and Putnam, CT, United States
# - Prediction: Likely to purchase
# - Prediction Reason: Ensinger does injection molding and manufactures plastic components. The material, 30% glass filled nylon 6/6, is a high performance thermoplastic suitable for injection molding. So Ensinger is likely to purchase this material.
# The data is not in JSON format.
# Printing data Text:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Ensinger Precision Components",
#   "Company Website": "https://www.ensingerplastics.com/",
#   "Phone Number": "(704) 992-8100, (860) 928-7911",
#   "Location": "Huntersville, NC, Putnam, CT, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Ensinger Precision Components is an injection molding and advanced manufacturing company that uses high performance thermoplastics. The material provided, 30% glass filled nylon 6/6, is a high performance thermoplastic that is well-suited for injection molding. Therefore, Ensinger Precision Components is likely to purchase this material."
# }
# ```
#
# The key information I extracted:
#
# - Company Name: Ensinger Precision Components
# - Company Website: https://www.ensingerplastics.com/
# - Phone Numbers: (704) 992-8100, (860) 928-7911
# - Locations: Huntersville, NC and Putnam, CT, United States
# - Prediction: Likely to purchase
# - Prediction Reason: Ensinger does injection molding and manufactures plastic components. The material, 30% glass filled nylon 6/6, is a high performance thermoplastic suitable for injection molding. So Ensinger is likely to purchase this material.
# Printing data after removing backticks:
#  Here is the extracted information in JSON format:
#
# ```json
# {
#   "Company_Name": "Ensinger Precision Components",
#   "Company Website": "https://www.ensingerplastics.com/",
#   "Phone Number": "(704) 992-8100, (860) 928-7911",
#   "Location": "Huntersville, NC, Putnam, CT, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Ensinger Precision Components is an injection molding and advanced manufacturing company that uses high performance thermoplastics. The material provided, 30% glass filled nylon 6/6, is a high performance thermoplastic that is well-suited for injection molding. Therefore, Ensinger Precision Components is likely to purchase this material."
# }
# ```
#
# The key information I extracted:
#
# - Company Name: Ensinger Precision Components
# - Company Website: https://www.ensingerplastics.com/
# - Phone Numbers: (704) 992-8100, (860) 928-7911
# - Locations: Huntersville, NC and Putnam, CT, United States
# - Prediction: Likely to purchase
# - Prediction Reason: Ensinger does injection molding and manufactures plastic components. The material, 30% glass filled nylon 6/6, is a high performance thermoplastic suitable for injection molding. So Ensinger is likely to purchase this material.
# Extracted JSON Part
# {
#   "Company_Name": "Ensinger Precision Components",
#   "Company Website": "https://www.ensingerplastics.com/",
#   "Phone Number": "(704) 992-8100, (860) 928-7911",
#   "Location": "Huntersville, NC, Putnam, CT, United States",
#   "Prediction": "Likely to purchase",
#   "Prediction_Reason": "Ensinger Precision Components is an injection molding and advanced manufacturing company that uses high performance thermoplastics. The material provided, 30% glass filled nylon 6/6, is a high performance thermoplastic that is well-suited for injection molding. Therefore, Ensinger Precision Components is likely to purchase this material."
# }
# Data Type after extracting data: <class 'dict'>
#
# Current working directory: /home/ec2-user/SageMaker/AscendNotebook
# ================================
